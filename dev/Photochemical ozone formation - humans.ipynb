# %%
from bw_recipe_2016 import (
    OzoneFormationHumans,
    get_biosphere_database, 
    extract_recipe,
)
from bw_recipe_2016.chemidplus import ChemIDPlus, Multiple, Missing

# %%
c = ChemIDPlus()

# %%
data = extract_recipe()[5]

# %%
biosphere = get_biosphere_database()

# %%
gw = OzoneFormationHumans(data, biosphere)

# %%
gw.apply_strategies()
# Out:
# Applying strategy: generic_reformat
# Applying strategy: fix_unit_string
# Applying strategy: name_matcher
# Applying strategy: add_air_category
# Applying strategy: drop_last_name_component
# Applying strategy: match_multiple
# Applying strategy: match_cas_number
# Applying strategy: chemid_name_mapping
# Applying strategy: match_multiple
# Applying strategy: chemid_cas_to_name_mapping
# Applying strategy: match_multiple
# Applied 11 strategies in 0.14 seconds

# %%
gw.data[0]
# Out:
# {'name': ('ReCiPe 2016', 'v1.1 (20180117)', 'HOFP', 'I'),
#  'unit': 'kg NOx-eq/kg',
#  'filename': 'ReCiPe2016_CFs_v1.1_20180117.xlsx',
#  'description': '',
#  'exchanges': [{'CAS number': 'NOx',
#    'name': 'nitrogen oxides (as nitrogen dioxide)',
#    'dummy': 'air',
#    'amount': 1.0,
#    'categories': ('air',)},
#   {'CAS number': 'NMVOC (non-methane volatile organic chemicals)',
#    'name': 'NMVOC (non-methane volatile organic chemicals)',
#    'dummy': 'air',
#    'amount': 0.18,
#    'categories': ('air',)},
#   {'CAS number': '',
#    'name': 'NO',
#    'dummy': 'air',
#    'amount': 1.53,
#    'categories': ('air',)},
#   {'CAS number': '',
#    'name': 'NO3',
#    'dummy': 'air',
#    'amount': 0.74,
#    'categories': ('air',)},
#   {'CAS number': 75285.0,
#    'name': 'i-Butane',
#    'dummy': 'air',
#    'amount': 0.10154359767921492,
#    'categories': ('air',),
#    'input': ('biosphere3', '3dba0484-8e84-4a42-ad11-665d589b56bc')},
#   {'CAS number': 78784.0,
#    'name': 'i-Pentane',
#    'dummy': 'air',
#    'amount': 0.12330294003904668,
#    'categories': ('air',)},
#   {'CAS number': 463821.0,
#    'name': 'Neopentane',
#    'dummy': 'air',
#    'amount': 0.0652780270794953,
#    'categories': ('air',)},
#   {'CAS number': 107835.0,
#    'name': '2-Methylpentane',
#    'dummy': 'air',
#    'amount': 0.14868883945885036,
#    'categories': ('air',)},
#   {'CAS number': 96140.0,
#    'name': '3-Methylpentane',
#    'dummy': 'air',
#    'amount': 0.1559419535787943,
#    'categories': ('air',),
#    'input': ('biosphere3', 'd25a3860-4be0-4fb3-ae03-2a4f04d2aa6f')},
#   {'CAS number': 75832.0,
#    'name': '2,2-Dimethylbutane',
#    'dummy': 'air',
#    'amount': 0.07978425531938313,
#    'categories': ('air',)},
#   {'CAS number': 79298.0,
#    'name': '2,3-Dimethylbutane',
#    'dummy': 'air',
#    'amount': 0.18132785299859805,
#    'categories': ('air',)},
#   {'CAS number': 591764.0,
#    'name': '2-Methylhexane',
#    'dummy': 'air',
#    'amount': 0.11604982591910275,
#    'categories': ('air',)},
#   {'CAS number': 589344.0,
#    'name': '3-Methylhexane',
#    'dummy': 'air',
#    'amount': 0.15231539651882234,
#    'categories': ('air',)},
#   {'CAS number': 111659.0,
#    'name': 'Octane',
#    'dummy': 'air',
#    'amount': 0.12330294003904668,
#    'categories': ('air',)},
#   {'CAS number': 592278.0,
#    'name': '2-Methylheptane',
#    'dummy': 'air',
#    'amount': 0.12330294003904668,
#    'categories': ('air',)},
#   {'CAS number': 589811.0,
#    'name': '3-Methylheptane',
#    'dummy': 'air',
#    'amount': 0.13418261121896255,
#    'categories': ('air',)},
#   {'CAS number': 111842.0,
#    'name': 'Nonane',
#    'dummy': 'air',
#    'amount': 0.12330294003904668,
#    'categories': ('air',)},
#   {'CAS number': '',
#    'name': '2-Methyloctane',
#    'dummy': 'air',
#    'amount': 0.12330294003904668,
#    'categories': ('air',)},
#   {'CAS number': '',
#    'name': '3-Methyloctane',
#    'dummy': 'air',
#    'amount': 0.12330294003904668,
#    'categories': ('air',)},
#   {'CAS number': '',
#    'name': '4-Methyloctane',
#    'dummy': 'air',
#    'amount': 0.13418261121896255,
#    'categories': ('air',)},
#   {'CAS number': '',
#    'name': '3,4-Dimethylheptane',
#    'dummy': 'air',
#    'amount': 0.1305560541589906,
#    'categories': ('air',)},
#   {'CAS number': 124185.0,
#    'name': 'Decane',
#    'dummy': 'air',
#    'amount': 0.1305560541589906,
#    'categories': ('air',)},
#   {'CAS number': '',
#    'name': '2-Methylnonane',
#    'dummy': 'air',
#    'amount': 0.12692949709901863,
#    'categories': ('air',)},
#   {'CAS number': '',
#    'name': '3-Methylnonane',
#    'dummy': 'air',
#    'amount': 0.14143572533890647,
#    'categories': ('air',)},
#   {'CAS number': '',
#    'name': '4-Methylnonane',
#    'dummy': 'air',
#    'amount': 0.12692949709901863,
#    'categories': ('air',)},
#   {'CAS number': '',
#    'name': '2,5-Dimethyloctane',
#    'dummy': 'air',
#    'amount': 0.1378091682789345,
#    'categories': ('air',)},
#   {'CAS number': '',
#    'name': '2,6-Dimethyloctane',
#    'dummy': 'air',
#    'amount': 0.1305560541589906,
#    'categories': ('air',)},
#   {'CAS number': '',
#    'name': '2-Methyl-3-ethylheptane',
#    'dummy': 'air',
#    'amount': 0.12330294003904668,
#    'categories': ('air',)},
#   {'CAS number': '',
#    'name': '2,2-Dimethyl-3,3-dimethylhexane',
#    'dummy': 'air',
#    'amount': 0.06890458413946725,
#    'categories': ('air',)},
#   {'CAS number': 1120214.0,
#    'name': 'Undecane',
#    'dummy': 'air',
#    'amount': 0.1305560541589906,
#    'categories': ('air',)},
#   {'CAS number': '',
#    'name': '2-Methyldecane',
#    'dummy': 'air',
#    'amount': 0.12330294003904668,
#    'categories': ('air',)},
#   {'CAS number': '',
#    'name': '3-Methyldecane',
#    'dummy': 'air',
#    'amount': 0.1305560541589906,
#    'categories': ('air',)},
#   {'CAS number': '',
#    'name': '4-Methyldecane',
#    'dummy': 'air',
#    'amount': 0.1305560541589906,
#    'categories': ('air',)},
#   {'CAS number': '',
#    'name': '5-Methyldecane',
#    'dummy': 'air',
#    'amount': 0.12692949709901863,
#    'categories': ('air',)},
#   {'CAS number': 112403.0,
#    'name': 'Dodecane',
#    'dummy': 'air',
#    'amount': 0.11967638297907472,
#    'categories': ('air',)},
#   {'CAS number': 629505.0,
#    'name': 'Tridecane',
#    'dummy': 'air',
#    'amount': 0.15231539651882234,
#    'categories': ('air',)},
#   {'CAS number': 629594.0,
#    'name': 'Tetradecane',
#    'dummy': 'air',
#    'amount': 0.1668216247587102,
#    'categories': ('air',)},
#   {'CAS number': 96377.0,
#    'name': 'Methylcyclopentane',
#    'dummy': 'air',
#    'amount': 0.17770129593862607,
#    'categories': ('air',)},
#   {'CAS number': 108872.0,
#    'name': 'Methylcyclohexane',
#    'dummy': 'air',
#    'amount': 0.23572620889817747,
#    'categories': ('air',)},
#   {'CAS number': '',
#    'name': 'Ethylcyclohexane',
#    'dummy': 'air',
#    'amount': 0.22847309477823355,
#    'categories': ('air',)},
#   {'CAS number': '',
#    'name': 'Propylcyclohexane',
#    'dummy': 'air',
#    'amount': 0.21759342359831765,
#    'categories': ('air',)},
#   {'CAS number': '',
#    'name': '1,2,3-Trimethylcyclohexane',
#    'dummy': 'air',
#    'amount': 0.20671375241840176,
#    'categories': ('air',)},
#   {'CAS number': '',
#    'name': 'i-Propylcyclohexane',
#    'dummy': 'air',
#    'amount': 0.21759342359831765,
#    'categories': ('air',)},
#   {'CAS number': '',
#    'name': 'Butylcyclohexane',
#    'dummy': 'air',
#    'amount': 0.21396686653834568,
#    'categories': ('air',)},
#   {'CAS number': '',
#    'name': 'i-Butylcyclohexane',
#    'dummy': 'air',
#    'amount': 0.21396686653834568,
#    'categories': ('air',)},
#   {'CAS number': '',
#    'name': '1-Methyl-3-propylcyclohexane',
#    'dummy': 'air',
#    'amount': 0.21759342359831765,
#    'categories': ('air',)},
#   {'CAS number': '',
#    'name': '1-Methyl-4-propylcyclohexane',
#    'dummy': 'air',
#    'amount': 0.20308719535842984,
#    'categories': ('air',)},
#   {'CAS number': '',
#    'name': 'Pentylcyclohexane',
#    'dummy': 'air',
#    'amount': 0.20308719535842984,
#    'categories': ('air',)},
#   {'CAS number': '',
#    'name': 'Hexylcyclohexane',
#    'dummy': 'air',
#    'amount': 0.20308719535842984,
#    'categories': ('air',)},
#   {'CAS number': 115071.0,
#    'name': 'Propylene',
#    'dummy': 'air',
#    'amount': 0.42430717601671936,
#    'categories': ('air',),
#    'input': ('biosphere3', 'b0cdbc78-e226-4e8b-97ff-3a557ab7ab55')},
#   {'CAS number': 106989.0,
#    'name': 'But-1-ene',
#    'dummy': 'air',
#    'amount': 0.37716193423708394,
#    'categories': ('air',)},
#   {'CAS number': '',
#    'name': 'Cis-but-2-ene',
#    'dummy': 'air',
#    'amount': 0.4098009477768315,
#    'categories': ('air',)},
#   {'CAS number': '',
#    'name': 'Trans-but-2-ene',
#    'dummy': 'air',
#    'amount': 0.4206806189567474,
#    'categories': ('air',)},
#   {'CAS number': '',
#    'name': 'Butylene',
#    'dummy': 'air',
#    'amount': 0.22847309477823355,
#    'categories': ('air',)},
#   {'CAS number': 106990.0,
#    'name': '1,3-Butadiene',
#    'dummy': 'air',
#    'amount': 0.3227635783375045,
#    'categories': ('air',),
#    'input': ('biosphere3', '0315d855-dff2-44af-bb37-1b855df53d69')},
#   {'CAS number': '',
#    'name': 'Cis-pent-2-ene',
#    'dummy': 'air',
#    'amount': 0.39529471953694373,
#    'categories': ('air',)},
#   {'CAS number': '',
#    'name': 'Trans-pent-2-ene',
#    'dummy': 'air',
#    'amount': 0.4025478336568877,
#    'categories': ('air',)},
#   {'CAS number': 563462.0,
#    'name': '2-Methylbut-1-ene',
#    'dummy': 'air',
#    'amount': 0.27199177949789705,
#    'categories': ('air',)},
#   {'CAS number': 563451.0,
#    'name': '3-Methylbut-1-ene',
#    'dummy': 'air',
#    'amount': 0.26473866537795315,
#    'categories': ('air',)},
#   {'CAS number': 513359.0,
#    'name': '2-Methylbut-2-ene',
#    'dummy': 'air',
#    'amount': 0.2973776789177007,
#    'categories': ('air',),
#    'input': ('biosphere3', 'b5a8e697-f5ac-413f-828c-51f6aace2e36')},
#   {'CAS number': 592416.0,
#    'name': 'Hex-1-ene',
#    'dummy': 'air',
#    'amount': 0.3191370212775325,
#    'categories': ('air',)},
#   {'CAS number': '',
#    'name': 'Cis-hex-2-ene',
#    'dummy': 'air',
#    'amount': 0.37716193423708394,
#    'categories': ('air',)},
#   {'CAS number': '',
#    'name': 'Trans-hex-2-ene',
#    'dummy': 'air',
#    'amount': 0.36990882011714,
#    'categories': ('air',)},
#   {'CAS number': '',
#    'name': 'Alpha-pinene',
#    'dummy': 'air',
#    'amount': 0.24660588007809336,
#    'categories': ('air',)},
#   {'CAS number': '',
#    'name': 'Beta-pinene',
#    'dummy': 'air',
#    'amount': 0.11967638297907472,
#    'categories': ('air',)},
#   {'CAS number': 138863.0,
#    'name': 'Limonene',
#    'dummy': 'air',
#    'amount': 0.2574855512580092,
#    'categories': ('air',)},
#   {'CAS number': '',
#    'name': '2-Methyl-3-butenol',
#    'dummy': 'air',
#    'amount': -0.007253114119943922,
#    'categories': ('air',)},
#   {'CAS number': 106423.0,
#    'name': 'p-Xylene',
#    'dummy': 'air',
#    'amount': 0.2611121083179812,
#    'categories': ('air',)},
#   {'CAS number': 100414.0,
#    'name': 'Ethylbenzene',
#    'dummy': 'air',
#    'amount': 0.1668216247587102,
#    'categories': ('air',),
#    'input': ('biosphere3', 'e4ef0139-8f7a-4541-a2fb-8316558eb296')},
#   {'CAS number': '',
#    'name': 'Propylbenzene',
#    'dummy': 'air',
#    'amount': 0.1378091682789345,
#    'categories': ('air',)},
#   {'CAS number': 98828.0,
#    'name': 'i-Propylbenzene',
#    'dummy': 'air',
#    'amount': 0.11604982591910275,
#    'categories': ('air',),
#    'input': ('biosphere3', 'a192f5ac-fb5d-4e14-ac11-3c38283da9d0')},
#   {'CAS number': 526738.0,
#    'name': '1,2,3-Trimethylbenzene',
#    'dummy': 'air',
#    'amount': 0.3807884912970559,
#    'categories': ('air',)},
#   {'CAS number': 95636.0,
#    'name': '1,2,4-Trimethylbenzene',
#    'dummy': 'air',
#    'amount': 0.39892127659691573,
#    'categories': ('air',)},
#   {'CAS number': 108678.0,
#    'name': '1,3,5-Trimethylbenzene',
#    'dummy': 'air',
#    'amount': 0.3880416054169998,
#    'categories': ('air',)},
#   {'CAS number': 611143.0,
#    'name': 'o-Ethyltoluene',
#    'dummy': 'air',
#    'amount': 0.26473866537795315,
#    'categories': ('air',)},
#   {'CAS number': 620144.0,
#    'name': 'm-Ethyltoluene',
#    'dummy': 'air',
#    'amount': 0.28287145067781294,
#    'categories': ('air',)},
#   {'CAS number': 622968.0,
#    'name': 'p-Ethyltoluene',
#    'dummy': 'air',
#    'amount': 0.22847309477823355,
#    'categories': ('air',)},
#   {'CAS number': 29224553.0,
#    'name': '3,5-Dimethylethylbenzene',
#    'dummy': 'air',
#    'amount': 0.37716193423708394,
#    'categories': ('air',)},
#   {'CAS number': 25550134.0,
#    'name': '3,5-Diethyltoluene',
#    'dummy': 'air',
#    'amount': 0.35540259187725215,
#    'categories': ('air',)},
#   {'CAS number': '',
#    'name': '1,2,3,5-Tetramethylbenzene',
#    'dummy': 'air',
#    'amount': 0.37716193423708394,
#    'categories': ('air',)},
#   {'CAS number': '',
#    'name': '1,2,4,5-Tetramethylbenzene',
#    'dummy': 'air',
#    'amount': 0.3626557059971961,
#    'categories': ('air',)},
#   {'CAS number': '',
#    'name': '1-Methyl-4-i-propylbenzene',
#    'dummy': 'air',
#    'amount': 0.27199177949789705,
#    'categories': ('air',)},
#   {'CAS number': '',
#    'name': '1-Methyl-3-i-propylbenzene',
#    'dummy': 'air',
#    'amount': 0.3191370212775325,
#    'categories': ('air',)},
#   {'CAS number': 123386.0,
#    'name': 'Propionaldehyde',
#    'dummy': 'air',
#    'amount': 0.2611121083179812,
#    'categories': ('air',),
#    'input': ('biosphere3', '9033de29-de9e-44b5-aea0-c9edb9ca2dd4')},
#   {'CAS number': '',
#    'name': 'i-Propionaldehyde',
#    'dummy': 'air',
#    'amount': 0.18132785299859805,
#    'categories': ('air',)},
#   {'CAS number': 123728.0,
#    'name': 'Butyraldehyde',
#    'dummy': 'air',
#    'amount': 0.25385899419803726,
#    'categories': ('air',)},
#   {'CAS number': '',
#    'name': 'Pentanal',
#    'dummy': 'air',
#    'amount': 0.2574855512580092,
#    'categories': ('air',)},
#   {'CAS number': '',
#    'name': '3-Methylbutanal',
#    'dummy': 'air',
#    'amount': 0.14868883945885036,
#    'categories': ('air',)},
#   {'CAS number': '',
#    'name': '2-Methylbenzaldehyde',
#    'dummy': 'air',
#    'amount': -0.10154359767921492,
#    'categories': ('air',)},
#   {'CAS number': '',
#    'name': '3-Methylbenzaldehyde',
#    'dummy': 'air',
#    'amount': -0.0652780270794953,
#    'categories': ('air',)},
#   {'CAS number': '',
#    'name': '4-Methylbenzaldehyde',
#    'dummy': 'air',
#    'amount': 0.018132785299859806,
#    'categories': ('air',)},
#   {'CAS number': 67630.0,
#    'name': 'i-Propanol',
#    'dummy': 'air',
#    'amount': 0.0652780270794953,
#    'categories': ('air',),
#    'input': ('biosphere3', '697667f9-d58c-4a64-99e3-30d24d7f91a2')},
#   {'CAS number': 78831.0,
#    'name': 'i-Butanol',
#    'dummy': 'air',
#    'amount': 0.1305560541589906,
#    'categories': ('air',),
#    'input': ('biosphere3', 'e2d860e3-1038-4386-a5f1-25ad75d18bbd')},
#   {'CAS number': 78922.0,
#    'name': 'sec-butanol',
#    'dummy': 'air',
#    'amount': 0.14506228239887844,
#    'categories': ('air',)},
#   {'CAS number': 75650.0,
#    'name': 't-Butanol',
#    'dummy': 'air',
#    'amount': 0.007253114119943922,
#    'categories': ('air',)},
#   {'CAS number': 95487.0,
#    'name': 'o-Cresol',
#    'dummy': 'air',
#    'amount': 0.06890458413946725,
#    'categories': ('air',)},
#   {'CAS number': 95874.0,
#    'name': '2,5-Xylenol',
#    'dummy': 'air',
#    'amount': 0.19946063829845787,
#    'categories': ('air',)},
#   {'CAS number': 105679.0,
#    'name': '2,4-Xylenol',
#    'dummy': 'air',
#    'amount': 0.1958340812384859,
#    'categories': ('air',)},
#   {'CAS number': 526750.0,
#    'name': '2,3-Xylenol',
#    'dummy': 'air',
#    'amount': 0.12330294003904668,
#    'categories': ('air',)},
#   {'CAS number': 108930.0,
#    'name': 'Cyclohexanol',
#    'dummy': 'air',
#    'amount': 0.16319506769873823,
#    'categories': ('air',)},
#   {'CAS number': 123422.0,
#    'name': 'Diacetone alcohol',
#    'dummy': 'air',
#    'amount': 0.10517015473918685,
#    'categories': ('air',)},
#   {'CAS number': 78933.0,
#    'name': 'Methylethylketone',
#    'dummy': 'air',
#    'amount': 0.11604982591910275,
#    'categories': ('air',),
#    'input': ('biosphere3', 'a93012b9-5223-4716-842b-23d4bb53119f')},
#   {'CAS number': 108101.0,
#    'name': 'Methyl-i-butylketone',
#    'dummy': 'air',
#    'amount': 0.18858096711854197,
#    'categories': ('air',),
#    'input': ('biosphere3', 'a6dd536a-5443-4c23-bb5e-60f0fa68af13')},
#   {'CAS number': 108941.0,
#    'name': 'Cyclohexanone',
#    'dummy': 'air',
#    'amount': 0.10517015473918685,
#    'categories': ('air',)},
#   {'CAS number': 107879.0,
#    'name': 'Methylpropylketone',
#    'dummy': 'air',
#    'amount': -0.003626557059971961,
#    'categories': ('air',)},
#   {'CAS number': 108214.0,
#    'name': 'i-Propyl acetate',
#    'dummy': 'air',
#    'amount': 0.07615769825941117,
#    'categories': ('air',)},
#   {'CAS number': '',
#    'name': 'n-Propyl acetate',
#    'dummy': 'air',
#    'amount': 0.08703736943932705,
#    'categories': ('air',)},
#   {'CAS number': 79094.0,
#    'name': 'Propanoic acid',
#    'dummy': 'air',
#    'amount': 0.04714524177963549,
#    'categories': ('air',),
#    'input': ('biosphere3', '0f907765-2a94-48a8-8978-55a2757d3e24')},
#   {'CAS number': 115106.0,
#    'name': 'Dimethylether',
#    'dummy': 'air',
#    'amount': 0.0652780270794953,
#    'categories': ('air',),
#    'input': ('biosphere3', '4f061396-da10-49b3-a7ac-ac1d2eb49fa1')},
#   {'CAS number': 60297.0,
#    'name': 'Diethylether',
#    'dummy': 'air',
#    'amount': 0.1668216247587102,
#    'categories': ('air',),
#    'input': ('biosphere3', '7ae0a943-090b-4da6-899f-8c53a33a1db2')},
#   {'CAS number': 108203.0,
#    'name': 'Di-i-propylether',
#    'dummy': 'air',
#    'amount': 0.15956851063876626,
#    'categories': ('air',)},
#   {'CAS number': 107211.0,
#    'name': 'Ethylene glycol',
#    'dummy': 'air',
#    'amount': 0.11967638297907472,
#    'categories': ('air',)},
#   {'CAS number': 57556.0,
#    'name': 'Propylene glycol',
#    'dummy': 'air',
#    'amount': 0.14143572533890647,
#    'categories': ('air',)},
#   {'CAS number': 111762.0,
#    'name': '2-Butoxyethanol',
#    'dummy': 'air',
#    'amount': 0.16319506769873823,
#    'categories': ('air',)},
#   {'CAS number': 107982.0,
#    'name': '1-Methoxy-2-propanol',
#    'dummy': 'air',
#    'amount': 0.12330294003904668,
#    'categories': ('air',)},
#   {'CAS number': 109864.0,
#    'name': '2-Methoxyethanol',
#    'dummy': 'air',
#    'amount': 0.10517015473918685,
#    'categories': ('air',)},
#   {'CAS number': 110805.0,
#    'name': '2-Ethoxyethanol',
#    'dummy': 'air',
#    'amount': 0.13418261121896255,
#    'categories': ('air',),
#    'input': ('biosphere3', 'fe976683-7080-4a79-8538-810793d21c53')},
#   {'CAS number': 78853.0,
#    'name': 'Methacrolein',
#    'dummy': 'air',
#    'amount': 0.3336432495174204,
#    'categories': ('air',)},
#   {'CAS number': 107222.0,
#    'name': 'Glyoxal',
#    'dummy': 'air',
#    'amount': 0.07978425531938313,
#    'categories': ('air',)},
#   {'CAS number': 78988.0,
#    'name': 'Methylglyoxal',
#    'dummy': 'air',
#    'amount': 0.366282263057168,
#    'categories': ('air',)},
#   {'CAS number': 74862.0,
#    'name': 'Acetylene',
#    'dummy': 'air',
#    'amount': 0.02538589941980373,
#    'categories': ('air',),
#    'input': ('biosphere3', '6c95c917-d232-4c5b-9721-8b2841e6671c')},
#   {'CAS number': 74997.0,
#    'name': 'Propyne',
#    'dummy': 'air',
#    'amount': 0.26473866537795315,
#    'categories': ('air',)},
#   {'CAS number': 75092.0,
#    'name': 'Methylene dichloride',
#    'dummy': 'air',
#    'amount': 0.010879671179915881,
#    'categories': ('air',),
#    'input': ('biosphere3', '432a3326-73f8-4752-bc4d-06b7b4b1243c')},
#   {'CAS number': 75003.0,
#    'name': 'Ethyl chloride',
#    'dummy': 'air',
#    'amount': 0.039892127659691565,
#    'categories': ('air',),
#    'input': ('biosphere3', '10e38581-58c8-4b27-85a4-6db6a83286ba')},
#   {'CAS number': 127184.0,
#    'name': 'Tetrachloroethylene',
#    'dummy': 'air',
#    'amount': 0.003626557059971961,
#    'categories': ('air',),
#    'input': ('biosphere3', '0015315d-a2b8-4b72-8e60-0d34a72e6de8')},
#   {'CAS number': 75343.0,
#    'name': 'Ethylidene dichloride',
#    'dummy': 'air',
#    'amount': 0.1958340812384859,
#    'categories': ('air',)},
#   {'CAS number': 71556.0,
#    'name': 'Methyl chloroform',
#    'dummy': 'air',
#    'amount': -0.003626557059971961,
#    'categories': ('air',),
#    'input': ('biosphere3', 'f84a6dac-bc6e-4efc-bdb0-a0f2a0231d0f')},
#   {'CAS number': 74873.0,
#    'name': 'Methyl chloride',
#    'dummy': 'air',
#    'amount': 0.003626557059971961,
#    'categories': ('air',),
#    'input': ('biosphere3', '246c87af-4495-4977-8d39-eae397c1c8f1')},
#   {'CAS number': 156592.0,
#    'name': 'Cis-dichloroethylene',
#    'dummy': 'air',
#    'amount': 0.0,
#    'categories': ('air',)},
#   {'CAS number': 156605.0,
#    'name': 'Trans-dichloroethylene',
#    'dummy': 'air',
#    'amount': -0.003626557059971961,
#    'categories': ('air',)},
#   {'CAS number': '',
#    'name': 'Carboxylic acids',
#    'dummy': 'air',
#    'amount': 0.00463,
#    'categories': ('air',)},
#   {'CAS number': 74840.0,
#    'name': 'Ethane',
#    'dummy': 'air',
#    'amount': 0.029012456479775687,
#    'categories': ('air',),
#    'input': ('biosphere3', '8e30c990-5ed4-4f94-9d0e-2f5e4ff1a1f9')},
#   {'CAS number': 74840.0,
#    'name': 'Ethane',
#    'dummy': 'air',
#    'amount': 0.029012456479775687,
#    'categories': ('air',),
#    'input': ('biosphere3', '823106de-a29a-481f-8647-728a19b9294d')},
#   {'CAS number': 74840.0,
#    'name': 'Ethane',
#    'dummy': 'air',
#    'amount': 0.029012456479775687,
#    'categories': ('air',),
#    'input': ('biosphere3', '9ea11aea-7cb7-4b38-b936-a42c2a4bac97')},
#   {'CAS number': 74840.0,
#    'name': 'Ethane',
#    'dummy': 'air',
#    'amount': 0.029012456479775687,
#    'categories': ('air',),
#    'input': ('biosphere3', '6cfec9aa-691b-4be2-940d-56e73fda16de')},
#   {'CAS number': 74840.0,
#    'name': 'Ethane',
#    'dummy': 'air',
#    'amount': 0.029012456479775687,
#    'categories': ('air',),
#    'input': ('biosphere3', 'e7e0031e-791d-42f4-b26c-ec322db637bc')},
#   {'CAS number': 74986.0,
#    'name': 'Propane',
#    'dummy': 'air',
#    'amount': 0.05077179883960746,
#    'categories': ('air',),
#    'input': ('biosphere3', 'abb87cf5-9e30-4d02-987c-7643510b7013')},
#   {'CAS number': 74986.0,
#    'name': 'Propane',
#    'dummy': 'air',
#    'amount': 0.05077179883960746,
#    'categories': ('air',),
#    'input': ('biosphere3', '98c66fdb-091d-46e9-a533-686f821e8f6a')},
#   {'CAS number': 74986.0,
#    'name': 'Propane',
#    'dummy': 'air',
#    'amount': 0.05077179883960746,
#    'categories': ('air',),
#    'input': ('biosphere3', 'aec794cd-e559-46f6-a2a0-7f4ef195144c')},
#   {'CAS number': 74986.0,
#    'name': 'Propane',
#    'dummy': 'air',
#    'amount': 0.05077179883960746,
#    'categories': ('air',),
#    'input': ('biosphere3', '3a6c936c-0276-4f11-9d98-1bd011387a6e')},
#   {'CAS number': 74986.0,
#    'name': 'Propane',
#    'dummy': 'air',
#    'amount': 0.05077179883960746,
#    'categories': ('air',),
#    'input': ('biosphere3', '9beb60a3-3a8c-4345-9a0e-107eec2f709f')},
#   {'CAS number': 106978.0,
#    'name': 'Butane',
#    'dummy': 'air',
#    'amount': 0.11242326885913079,
#    'categories': ('air',),
#    'input': ('biosphere3', 'fa5512cf-04a2-4014-8e96-d3e2d137f0df')},
#   {'CAS number': 106978.0,
#    'name': 'Butane',
#    'dummy': 'air',
#    'amount': 0.11242326885913079,
#    'categories': ('air',),
#    'input': ('biosphere3', 'f4a1e10b-ed51-433e-a2f5-2a99f231a5e5')},
#   {'CAS number': 106978.0,
#    'name': 'Butane',
#    'dummy': 'air',
#    'amount': 0.11242326885913079,
#    'categories': ('air',),
#    'input': ('biosphere3', '892f10da-7bf2-42b3-b171-221989661a05')},
#   {'CAS number': 106978.0,
#    'name': 'Butane',
#    'dummy': 'air',
#    'amount': 0.11242326885913079,
#    'categories': ('air',),
#    'input': ('biosphere3', '982b0510-96ac-4bcb-a758-e98006b95f4d')},
#   {'CAS number': 106978.0,
#    'name': 'Butane',
#    'dummy': 'air',
#    'amount': 0.11242326885913079,
#    'categories': ('air',),
#    'input': ('biosphere3', '66ff5d22-17e2-4112-b486-3ea4e0191fba')},
#   {'CAS number': 109660.0,
#    'name': 'Pentane',
#    'dummy': 'air',
#    'amount': 0.14506228239887844,
#    'categories': ('air',),
#    'input': ('biosphere3', '516606eb-99f6-4e8c-b99a-6b439aaed48c')},
#   {'CAS number': 109660.0,
#    'name': 'Pentane',
#    'dummy': 'air',
#    'amount': 0.14506228239887844,
#    'categories': ('air',),
#    'input': ('biosphere3', '2f052025-4072-4d8e-b22d-68d50bfb260c')},
#   {'CAS number': 109660.0,
#    'name': 'Pentane',
#    'dummy': 'air',
#    'amount': 0.14506228239887844,
#    'categories': ('air',),
#    'input': ('biosphere3', 'd9da59f1-695d-465b-959d-1cff9d86d923')},
#   {'CAS number': 109660.0,
#    'name': 'Pentane',
#    'dummy': 'air',
#    'amount': 0.14506228239887844,
#    'categories': ('air',),
#    'input': ('biosphere3', '0b9698ec-8b52-4986-8f9f-ad30915aa00c')},
#   {'CAS number': 109660.0,
#    'name': 'Pentane',
#    'dummy': 'air',
#    'amount': 0.14506228239887844,
#    'categories': ('air',),
#    'input': ('biosphere3', 'eee7f4df-d621-439a-a89a-edf2d761d848')},
#   {'CAS number': 110543.0,
#    'name': 'Hexane',
#    'dummy': 'air',
#    'amount': 0.14506228239887844,
#    'categories': ('air',),
#    'input': ('biosphere3', '41067ac7-bf36-47ef-a19f-683d9b758a28')},
#   {'CAS number': 110543.0,
#    'name': 'Hexane',
#    'dummy': 'air',
#    'amount': 0.14506228239887844,
#    'categories': ('air',),
#    'input': ('biosphere3', '3bbc78d0-08c4-48ef-a863-704e32fddcb3')},
#   {'CAS number': 110543.0,
#    'name': 'Hexane',
#    'dummy': 'air',
#    'amount': 0.14506228239887844,
#    'categories': ('air',),
#    'input': ('biosphere3', '6b248529-b754-4be7-8b1a-91b9756fc2bc')},
#   {'CAS number': 110543.0,
#    'name': 'Hexane',
#    'dummy': 'air',
#    'amount': 0.14506228239887844,
#    'categories': ('air',),
#    'input': ('biosphere3', '5f29e18d-ace2-466c-831e-be1aee84323a')},
#   {'CAS number': 110543.0,
#    'name': 'Hexane',
#    'dummy': 'air',
#    'amount': 0.14506228239887844,
#    'categories': ('air',),
#    'input': ('biosphere3', '77ff1fec-e163-4377-acac-b00c8aa94391')},
#   {'CAS number': 142825.0,
#    'name': 'Heptane',
#    'dummy': 'air',
#    'amount': 0.12692949709901863,
#    'categories': ('air',),
#    'input': ('biosphere3', '248223f5-4e00-4b0d-9652-76a9c39ce414')},
#   {'CAS number': 142825.0,
#    'name': 'Heptane',
#    'dummy': 'air',
#    'amount': 0.12692949709901863,
#    'categories': ('air',),
#    'input': ('biosphere3', '1ec6c4b4-ee5f-4788-8683-c95a84d6d63c')},
#   {'CAS number': 142825.0,
#    'name': 'Heptane',
#    'dummy': 'air',
#    'amount': 0.12692949709901863,
#    'categories': ('air',),
#    'input': ('biosphere3', 'f4bb66f1-c78c-409f-8368-85c1205a3573')},
#   {'CAS number': 142825.0,
#    'name': 'Heptane',
#    'dummy': 'air',
#    'amount': 0.12692949709901863,
#    'categories': ('air',),
#    'input': ('biosphere3', '025fcb20-0591-4bae-80fc-7c34e9af2e7b')},
#   {'CAS number': 142825.0,
#    'name': 'Heptane',
#    'dummy': 'air',
#    'amount': 0.12692949709901863,
#    'categories': ('air',),
#    'input': ('biosphere3', '745503c2-768d-4f2c-b63c-bb75c1c5419c')},
#   {'CAS number': 110827.0,
#    'name': 'Cyclohexane',
#    'dummy': 'air',
#    'amount': 0.10154359767921492,
#    'categories': ('air',),
#    'input': ('biosphere3', 'f9727bf8-d8e3-432c-8feb-2dc43da4c37d')},
#   {'CAS number': 110827.0,
#    'name': 'Cyclohexane',
#    'dummy': 'air',
#    'amount': 0.10154359767921492,
#    'categories': ('air',),
#    'input': ('biosphere3', '5512f026-b3a9-419a-b787-c0be0b39be1c')},
#   {'CAS number': 110827.0,
#    'name': 'Cyclohexane',
#    'dummy': 'air',
#    'amount': 0.10154359767921492,
#    'categories': ('air',),
#    'input': ('biosphere3', '22ff429e-4506-428d-9bba-4f9595ed3b99')},
#   {'CAS number': 110827.0,
#    'name': 'Cyclohexane',
#    'dummy': 'air',
#    'amount': 0.10154359767921492,
#    'categories': ('air',),
#    'input': ('biosphere3', '9ada9c2e-9817-42fe-88ba-3c18aba85585')},
#   {'CAS number': 110827.0,
#    'name': 'Cyclohexane',
#    'dummy': 'air',
#    'amount': 0.10154359767921492,
#    'categories': ('air',),
#    'input': ('biosphere3', '165aaeac-93d1-4afd-adf2-e3d6c0eaf629')},
#   {'CAS number': 74851.0,
#    'name': 'Ethylene',
#    'dummy': 'air',
#    'amount': 0.3626557059971961,
#    'categories': ('air',),
#    'input': ('biosphere3', '90f722bf-cb9b-571a-88fc-34286632bdc4')},
#   {'CAS number': 109671.0,
#    'name': '1-Pentene',
#    'dummy': 'air',
#    'amount': 0.34452292069733625,
#    'categories': ('air',),
#    'input': ('biosphere3', '47a8dfb8-f1e5-4460-b7ca-eeea1ca44596')},
#   {'CAS number': 109671.0,
#    'name': '1-Pentene',
#    'dummy': 'air',
#    'amount': 0.34452292069733625,
#    'categories': ('air',),
#    'input': ('biosphere3', '87eed31b-5a6b-43ae-9a02-778a8c6e4ff8')},
#   {'CAS number': 109671.0,
#    'name': '1-Pentene',
#    'dummy': 'air',
#    'amount': 0.34452292069733625,
#    'categories': ('air',),
#    'input': ('biosphere3', '8cbaa905-41b0-4327-8403-bf1c8eb25429')},
#   {'CAS number': 109671.0,
#    'name': '1-Pentene',
#    'dummy': 'air',
#    'amount': 0.34452292069733625,
#    'categories': ('air',),
#    'input': ('biosphere3', 'ccfea48e-0aec-4573-8ed1-fb7c0f1b14ae')},
#   {'CAS number': 109671.0,
#    'name': '1-Pentene',
#    'dummy': 'air',
#    'amount': 0.34452292069733625,
#    'categories': ('air',),
#    'input': ('biosphere3', '651cbfbb-3027-4e20-a5b0-4a67e86e837a')},
#   {'CAS number': 78795.0,
#    'name': 'Isoprene',
#    'dummy': 'air',
#    'amount': 0.4134275048368035,
#    'categories': ('air',),
#    'input': ('biosphere3', '0c209634-80bb-4909-8442-3189b7cb01d7')},
#   {'CAS number': 78795.0,
#    'name': 'Isoprene',
#    'dummy': 'air',
#    'amount': 0.4134275048368035,
#    'categories': ('air',),
#    'input': ('biosphere3', 'bf633941-aa40-4c37-b361-b5cbfb1089f5')},
#   {'CAS number': 78795.0,
#    'name': 'Isoprene',
#    'dummy': 'air',
#    'amount': 0.4134275048368035,
#    'categories': ('air',),
#    'input': ('biosphere3', 'f0cc0453-32c0-48f5-b8d4-fc87d100b8d9')},
#   {'CAS number': 78795.0,
#    'name': 'Isoprene',
#    'dummy': 'air',
#    'amount': 0.4134275048368035,
#    'categories': ('air',),
#    'input': ('biosphere3', 'a31cd36e-e3ca-42ac-8d71-de1b6b12f523')},
#   {'CAS number': 78795.0,
#    'name': 'Isoprene',
#    'dummy': 'air',
#    'amount': 0.4134275048368035,
#    'categories': ('air',),
#    'input': ('biosphere3', 'e5e50f39-ab65-4ed0-84c3-93707e85f4d4')},
#   {'CAS number': 71432.0,
#    'name': 'Benzene',
#    'dummy': 'air',
#    'amount': 0.03626557059971961,
#    'categories': ('air',),
#    'input': ('biosphere3', '28999907-a8a7-45b3-857e-836495ca2aa0')},
#   {'CAS number': 71432.0,
#    'name': 'Benzene',
#    'dummy': 'air',
#    'amount': 0.03626557059971961,
#    'categories': ('air',),
#    'input': ('biosphere3', '5e883a00-04e6-4d96-8dce-12d7117c6635')},
#   {'CAS number': 71432.0,
#    'name': 'Benzene',
#    'dummy': 'air',
#    'amount': 0.03626557059971961,
#    'categories': ('air',),
#    'input': ('biosphere3', 'eb15dd66-43ee-4161-ac90-2cd6d19ca72d')},
#   {'CAS number': 71432.0,
#    'name': 'Benzene',
#    'dummy': 'air',
#    'amount': 0.03626557059971961,
#    'categories': ('air',),
#    'input': ('biosphere3', '8476d82a-4a17-4c08-8339-efd46c6518e7')},
#   {'CAS number': 71432.0,
#    'name': 'Benzene',
#    'dummy': 'air',
#    'amount': 0.03626557059971961,
#    'categories': ('air',),
#    'input': ('biosphere3', '1bb6a502-3ff9-4a79-835c-5588b855f1f5')},
#   {'CAS number': 108883.0,
#    'name': 'Toluene',
#    'dummy': 'air',
#    'amount': 0.15956851063876626,
#    'categories': ('air',),
#    'input': ('biosphere3', 'b98c02c6-89bb-4dd2-8d68-6af6758db3d9')},
#   {'CAS number': 108883.0,
#    'name': 'Toluene',
#    'dummy': 'air',
#    'amount': 0.15956851063876626,
#    'categories': ('air',),
#    'input': ('biosphere3', '77f17646-cede-4a49-99dd-55950098b077')},
#   {'CAS number': 108883.0,
#    'name': 'Toluene',
#    'dummy': 'air',
#    'amount': 0.15956851063876626,
#    'categories': ('air',),
#    'input': ('biosphere3', '0b0d8098-ecbf-4020-afd6-4bcf9db686ce')},
#   {'CAS number': 108883.0,
#    'name': 'Toluene',
#    'dummy': 'air',
#    'amount': 0.15956851063876626,
#    'categories': ('air',),
#    'input': ('biosphere3', '3b1ecf8e-1d2c-4330-81da-a79f9068976d')},
#   {'CAS number': 108883.0,
#    'name': 'Toluene',
#    'dummy': 'air',
#    'amount': 0.15956851063876626,
#    'categories': ('air',),
#    'input': ('biosphere3', '39946c56-cdf6-4a22-9ac9-1cd333b65533')},
#   {'CAS number': 95476.0,
#    'name': 'o-Xylene',
#    'dummy': 'air',
#    'amount': 0.28287145067781294,
#    'categories': ('air',),
#    'input': ('biosphere3', '4b841af5-7061-4e59-89d4-cace8bc364e1')},
#   {'CAS number': 95476.0,
#    'name': 'o-Xylene',
#    'dummy': 'air',
#    'amount': 0.28287145067781294,
#    'categories': ('air',),
#    'input': ('biosphere3', '527d6cb5-bbd7-403d-8dcc-b6678fb123f5')},
#   {'CAS number': 95476.0,
#    'name': 'o-Xylene',
#    'dummy': 'air',
#    'amount': 0.28287145067781294,
#    'categories': ('air',),
#    'input': ('biosphere3', '92259b90-6f92-42ec-b3f2-30775167aff7')},
#   {'CAS number': 95476.0,
#    'name': 'o-Xylene',
#    'dummy': 'air',
#    'amount': 0.28287145067781294,
#    'categories': ('air',),
#    'input': ('biosphere3', '8a4e7925-a486-467c-a255-f8a1ec5040de')},
#   {'CAS number': 95476.0,
#    'name': 'o-Xylene',
#    'dummy': 'air',
#    'amount': 0.28287145067781294,
#    'categories': ('air',),
#    'input': ('biosphere3', '5a6eb27d-9157-46d5-be32-92bbd543ada9')},
#   {'CAS number': 108383.0,
#    'name': 'm-Xylene',
#    'dummy': 'air',
#    'amount': 0.3118839071575886,
#    'categories': ('air',),
#    'input': ('biosphere3', 'cfdbc576-e8dc-44ef-bdf2-ddd7009ce57e')},
#   {'CAS number': 108383.0,
#    'name': 'm-Xylene',
#    'dummy': 'air',
#    'amount': 0.3118839071575886,
#    'categories': ('air',),
#    'input': ('biosphere3', '50e083ba-5784-4801-8011-164a14c61b5a')},
#   {'CAS number': 108383.0,
#    'name': 'm-Xylene',
#    'dummy': 'air',
#    'amount': 0.3118839071575886,
#    'categories': ('air',),
#    'input': ('biosphere3', '62bd2ced-16de-43c2-88e1-adfae242654e')},
#   {'CAS number': 108383.0,
#    'name': 'm-Xylene',
#    'dummy': 'air',
#    'amount': 0.3118839071575886,
#    'categories': ('air',),
#    'input': ('biosphere3', 'd24f41d7-279e-4f5a-9ac9-00f726dc3bcc')},
#   {'CAS number': 108383.0,
#    'name': 'm-Xylene',
#    'dummy': 'air',
#    'amount': 0.3118839071575886,
#    'categories': ('air',),
#    'input': ('biosphere3', '10571d92-ea97-4ac6-adb6-b25893a631cb')},
#   {'CAS number': 100425.0,
#    'name': 'Styrene',
#    'dummy': 'air',
#    'amount': 0.018132785299859806,
#    'categories': ('air',),
#    'input': ('biosphere3', '2b676e9e-1e3b-45d6-b209-6ed3af61fc42')},
#   {'CAS number': 100425.0,
#    'name': 'Styrene',
#    'dummy': 'air',
#    'amount': 0.018132785299859806,
#    'categories': ('air',),
#    'input': ('biosphere3', '2d456fb8-592b-46a7-97f0-81fc2a18e587')},
#   {'CAS number': 100425.0,
#    'name': 'Styrene',
#    'dummy': 'air',
#    'amount': 0.018132785299859806,
#    'categories': ('air',),
#    'input': ('biosphere3', 'd85a44cb-8407-4997-a146-581e4f35f39d')},
#   {'CAS number': 100425.0,
#    'name': 'Styrene',
#    'dummy': 'air',
#    'amount': 0.018132785299859806,
#    'categories': ('air',),
#    'input': ('biosphere3', 'f7bdeabf-a11d-4ddb-ad19-501485f39f07')},
#   {'CAS number': 100425.0,
#    'name': 'Styrene',
#    'dummy': 'air',
#    'amount': 0.018132785299859806,
#    'categories': ('air',),
#    'input': ('biosphere3', '9cec94a2-e7fe-43f4-82f4-293c477f86dc')},
#   {'CAS number': 50000.0,
#    'name': 'Formaldehyde',
#    'dummy': 'air',
#    'amount': 0.1668216247587102,
#    'categories': ('air',),
#    'input': ('biosphere3', '9167dca7-615e-435c-8ba6-dbbf50e50e34')},
#   {'CAS number': 50000.0,
#    'name': 'Formaldehyde',
#    'dummy': 'air',
#    'amount': 0.1668216247587102,
#    'categories': ('air',),
#    'input': ('biosphere3', '20664d0e-24e3-4daa-8c5c-2ade6e0c2723')},
#   {'CAS number': 50000.0,
#    'name': 'Formaldehyde',
#    'dummy': 'air',
#    'amount': 0.1668216247587102,
#    'categories': ('air',),
#    'input': ('biosphere3', 'a861cfae-a310-4e9d-b9eb-5d555c9a684c')},
#   {'CAS number': 50000.0,
#    'name': 'Formaldehyde',
#    'dummy': 'air',
#    'amount': 0.1668216247587102,
#    'categories': ('air',),
#    'input': ('biosphere3', '22b0b296-d066-4159-a44b-69fdb17dc802')},
#   {'CAS number': 50000.0,
#    'name': 'Formaldehyde',
#    'dummy': 'air',
#    'amount': 0.1668216247587102,
#    'categories': ('air',),
#    'input': ('biosphere3', '1258b87f-6a94-4c0f-a51a-cef98a3bf534')},
#   {'CAS number': 75070.0,
#    'name': 'Acetaldehyde',
#    'dummy': 'air',
#    'amount': 0.19946063829845787,
#    'categories': ('air',),
#    'input': ('biosphere3', 'e3e8f6a2-c45e-4685-9859-698b2eadaf5b')},
#   {'CAS number': 75070.0,
#    'name': 'Acetaldehyde',
#    'dummy': 'air',
#    'amount': 0.19946063829845787,
#    'categories': ('air',),
#    'input': ('biosphere3', '55b0bc94-7f43-4930-ad57-25af3f892757')},
#   {'CAS number': 75070.0,
#    'name': 'Acetaldehyde',
#    'dummy': 'air',
#    'amount': 0.19946063829845787,
#    'categories': ('air',),
#    'input': ('biosphere3', '43a7e8ef-634e-401b-92f1-32cb42f226ac')},
#   {'CAS number': 75070.0,
#    'name': 'Acetaldehyde',
#    'dummy': 'air',
#    'amount': 0.19946063829845787,
#    'categories': ('air',),
#    'input': ('biosphere3', 'fc9f9a81-c4b9-4dce-bc20-9f04e05ca2f1')},
#   {'CAS number': 75070.0,
#    'name': 'Acetaldehyde',
#    'dummy': 'air',
#    'amount': 0.19946063829845787,
#    'categories': ('air',),
#    'input': ('biosphere3', '5ad58fcc-e9ba-4155-a3c9-e4ffb3065a6f')},
#   {'CAS number': 100527.0,
#    'name': 'Benzaldehyde',
#    'dummy': 'air',
#    'amount': -0.06890458413946725,
#    'categories': ('air',),
#    'input': ('biosphere3', 'a61637db-d0a5-40c3-8969-e0b03509b667')},
#   {'CAS number': 100527.0,
#    'name': 'Benzaldehyde',
#    'dummy': 'air',
#    'amount': -0.06890458413946725,
#    'categories': ('air',),
#    'input': ('biosphere3', '4c08620f-1001-43b2-a42c-e02163ac41a3')},
#   {'CAS number': 100527.0,
#    'name': 'Benzaldehyde',
#    'dummy': 'air',
#    'amount': -0.06890458413946725,
#    'categories': ('air',),
#    'input': ('biosphere3', '2813518d-c4a8-4a8d-9542-f1882ec27c1c')},
#   {'CAS number': 100527.0,
#    'name': 'Benzaldehyde',
#    'dummy': 'air',
#    'amount': -0.06890458413946725,
#    'categories': ('air',),
#    'input': ('biosphere3', 'fe65f7e4-ee5b-4a6f-9d60-6c2f829dca3f')},
#   {'CAS number': 100527.0,
#    'name': 'Benzaldehyde',
#    'dummy': 'air',
#    'amount': -0.06890458413946725,
#    'categories': ('air',),
#    'input': ('biosphere3', '10d26189-a688-4859-8aa9-525e058a07f0')},
#   {'CAS number': 67561.0,
#    'name': 'Methanol',
#    'dummy': 'air',
#    'amount': 0.04714524177963549,
#    'categories': ('air',),
#    'input': ('biosphere3', 'd482b568-0604-4433-87b2-1340f7a17512')},
#   {'CAS number': 67561.0,
#    'name': 'Methanol',
#    'dummy': 'air',
#    'amount': 0.04714524177963549,
#    'categories': ('air',),
#    'input': ('biosphere3', '1d2439de-751b-469a-ba3e-fda8fe9802b2')},
#   {'CAS number': 67561.0,
#    'name': 'Methanol',
#    'dummy': 'air',
#    'amount': 0.04714524177963549,
#    'categories': ('air',),
#    'input': ('biosphere3', 'adf4ac5e-7edd-4ca3-9adb-0b50903a71c1')},
#   {'CAS number': 67561.0,
#    'name': 'Methanol',
#    'dummy': 'air',
#    'amount': 0.04714524177963549,
#    'categories': ('air',),
#    'input': ('biosphere3', 'f873299d-0675-4fdc-ad01-c5a4b951b583')},
#   {'CAS number': 67561.0,
#    'name': 'Methanol',
#    'dummy': 'air',
#    'amount': 0.04714524177963549,
#    'categories': ('air',),
#    'input': ('biosphere3', '0ebdb68a-f50d-4b0c-ad4b-3a1104d8b454')},
#   {'CAS number': 64175.0,
#    'name': 'Ethanol',
#    'dummy': 'air',
#    'amount': 0.12330294003904668,
#    'categories': ('air',),
#    'input': ('biosphere3', '0d3ccb17-b3fe-4c08-b7cb-458ed3ababf1')},
#   {'CAS number': 64175.0,
#    'name': 'Ethanol',
#    'dummy': 'air',
#    'amount': 0.12330294003904668,
#    'categories': ('air',),
#    'input': ('biosphere3', '379a827c-3290-4810-9689-b9e892945836')},
#   {'CAS number': 64175.0,
#    'name': 'Ethanol',
#    'dummy': 'air',
#    'amount': 0.12330294003904668,
#    'categories': ('air',),
#    'input': ('biosphere3', 'e47fcb9f-ef2f-4047-b902-37363ea5345c')},
#   {'CAS number': 64175.0,
#    'name': 'Ethanol',
#    'dummy': 'air',
#    'amount': 0.12330294003904668,
#    'categories': ('air',),
#    'input': ('biosphere3', 'dbafa5bd-48d1-455a-8042-7d631d913745')},
#   {'CAS number': 64175.0,
#    'name': 'Ethanol',
#    'dummy': 'air',
#    'amount': 0.12330294003904668,
#    'categories': ('air',),
#    'input': ('biosphere3', 'd3f5d0b9-0155-4800-9dbb-b0583948c8c6')},
#   {'CAS number': 71238.0,
#    'name': 'Propanol',
#    'dummy': 'air',
#    'amount': 0.1740747388786541,
#    'categories': ('air',),
#    'input': ('biosphere3', '29bfab29-0ad0-47da-b5b9-a76328ba5a64')},
#   {'CAS number': 71238.0,
#    'name': 'Propanol',
#    'dummy': 'air',
#    'amount': 0.1740747388786541,
#    'categories': ('air',),
#    'input': ('biosphere3', 'f6979c44-2a8a-4730-a4b4-376d5539dcd0')},
#   {'CAS number': 71238.0,
#    'name': 'Propanol',
#    'dummy': 'air',
#    'amount': 0.1740747388786541,
#    'categories': ('air',),
#    'input': ('biosphere3', 'ad3e6f24-22b0-4ca4-9f2c-f0f5f180f633')},
#   {'CAS number': 71238.0,
#    'name': 'Propanol',
#    'dummy': 'air',
#    'amount': 0.1740747388786541,
#    'categories': ('air',),
#    'input': ('biosphere3', '4a6af581-af93-4d79-9f45-a5c43f463bbb')},
#   {'CAS number': 71238.0,
#    'name': 'Propanol',
#    'dummy': 'air',
#    'amount': 0.1740747388786541,
#    'categories': ('air',),
#    'input': ('biosphere3', 'ff5d0fa9-6ca8-4e61-b99b-14981620c0d7')},
#   {'CAS number': 71363.0,
#    'name': 'Butanol',
#    'dummy': 'air',
#    'amount': 0.18858096711854197,
#    'categories': ('air',),
#    'input': ('biosphere3', 'b9a9b2ad-5db3-47aa-81de-3a48ae9ad4ec')},
#   {'CAS number': 71363.0,
#    'name': 'Butanol',
#    'dummy': 'air',
#    'amount': 0.18858096711854197,
#    'categories': ('air',),
#    'input': ('biosphere3', 'f202452b-5aff-45e6-9001-5fb0a2de7992')},
#   {'CAS number': 71363.0,
#    'name': 'Butanol',
#    'dummy': 'air',
#    'amount': 0.18858096711854197,
#    'categories': ('air',),
#    'input': ('biosphere3', 'efc4290c-1404-4e01-8b5e-e75c6d90615c')},
#   {'CAS number': 71363.0,
#    'name': 'Butanol',
#    'dummy': 'air',
#    'amount': 0.18858096711854197,
#    'categories': ('air',),
#    'input': ('biosphere3', 'b83f893c-f4b4-473f-bd13-a23fd300c5d1')},
#   {'CAS number': 71363.0,
#    'name': 'Butanol',
#    'dummy': 'air',
#    'amount': 0.18858096711854197,
#    'categories': ('air',),
#    'input': ('biosphere3', 'cb299863-b63a-45ae-a3fc-b5cc900aaeea')},
#   {'CAS number': 123513.0,
#    'name': '3-Methyl-1-butanol',
#    'dummy': 'air',
#    'amount': 0.15956851063876626,
#    'categories': ('air',),
#    'input': ('biosphere3', 'dc50265c-a1ea-49b3-97a9-fad6f1da0bd7')},
#   {'CAS number': 123513.0,
#    'name': '3-Methyl-1-butanol',
#    'dummy': 'air',
#    'amount': 0.15956851063876626,
#    'categories': ('air',),
#    'input': ('biosphere3', 'c6310f81-3859-4c5c-990a-4662ba179693')},
#   {'CAS number': 123513.0,
#    'name': '3-Methyl-1-butanol',
#    'dummy': 'air',
#    'amount': 0.15956851063876626,
#    'categories': ('air',),
#    'input': ('biosphere3', '1eefb686-03de-4dc8-933a-e3b7459438da')},
#   {'CAS number': 123513.0,
#    'name': '3-Methyl-1-butanol',
#    'dummy': 'air',
#    'amount': 0.15956851063876626,
#    'categories': ('air',),
#    'input': ('biosphere3', '8d50d9ce-3284-4a1e-ab89-2a7a931b110d')},
#   {'CAS number': 123513.0,
#    'name': '3-Methyl-1-butanol',
#    'dummy': 'air',
#    'amount': 0.15956851063876626,
#    'categories': ('air',),
#    'input': ('biosphere3', 'f792a1df-81cb-4c95-8c4a-e0626701e619')},
#   {'CAS number': 108952.0,
#    'name': 'Phenol',
#    'dummy': 'air',
#    'amount': -0.018132785299859806,
#    'categories': ('air',),
#    'input': ('biosphere3', 'ce8a4102-a9fe-4823-a6c0-7cc35b6ce07e')},
#   {'CAS number': 108952.0,
#    'name': 'Phenol',
#    'dummy': 'air',
#    'amount': -0.018132785299859806,
#    'categories': ('air',),
#    'input': ('biosphere3', '63974d2c-11f3-45eb-be9c-726261b04d85')},
#   {'CAS number': 108952.0,
#    'name': 'Phenol',
#    'dummy': 'air',
#    'amount': -0.018132785299859806,
#    'categories': ('air',),
#    'input': ('biosphere3', '5896c761-4e02-4573-8747-c4bbf73162c0')},
#   {'CAS number': 108952.0,
#    'name': 'Phenol',
#    'dummy': 'air',
#    'amount': -0.018132785299859806,
#    'categories': ('air',),
#    'input': ('biosphere3', 'd761d96f-d236-4131-89c8-ad3269d02a6b')},
#   {'CAS number': 108952.0,
#    'name': 'Phenol',
#    'dummy': 'air',
#    'amount': -0.018132785299859806,
#    'categories': ('air',),
#    'input': ('biosphere3', 'd8b6c259-4e1a-4482-8eed-237cde14f346')},
#   {'CAS number': 67641.0,
#    'name': 'Acetone',
#    'dummy': 'air',
#    'amount': 0.021759342359831763,
#    'categories': ('air',),
#    'input': ('biosphere3', 'a765d3a1-65c6-4544-8487-b3104b937568')},
#   {'CAS number': 67641.0,
#    'name': 'Acetone',
#    'dummy': 'air',
#    'amount': 0.021759342359831763,
#    'categories': ('air',),
#    'input': ('biosphere3', '1f130425-11f9-4ec2-8d2f-d282acaacf5c')},
#   {'CAS number': 67641.0,
#    'name': 'Acetone',
#    'dummy': 'air',
#    'amount': 0.021759342359831763,
#    'categories': ('air',),
#    'input': ('biosphere3', 'f3d5fd96-8805-4d3d-867a-5df27975b07f')},
#   {'CAS number': 67641.0,
#    'name': 'Acetone',
#    'dummy': 'air',
#    'amount': 0.021759342359831763,
#    'categories': ('air',),
#    'input': ('biosphere3', 'e91093c9-20df-49c5-8960-eabf05af6832')},
#   {'CAS number': 67641.0,
#    'name': 'Acetone',
#    'dummy': 'air',
#    'amount': 0.021759342359831763,
#    'categories': ('air',),
#    'input': ('biosphere3', '7a2d7097-20c4-4b5f-b2ee-bcfc2ba1378f')},
#   {'CAS number': 107313.0,
#    'name': 'Methyl formate',
#    'dummy': 'air',
#    'amount': 0.010879671179915881,
#    'categories': ('air',),
#    'input': ('biosphere3', '2563243b-9991-4fb4-bfe7-4239c25de7db')},
#   {'CAS number': 107313.0,
#    'name': 'Methyl formate',
#    'dummy': 'air',
#    'amount': 0.010879671179915881,
#    'categories': ('air',),
#    'input': ('biosphere3', 'a71b27f2-3bcb-4bcc-a0c6-b6a123f0b42e')},
#   {'CAS number': 107313.0,
#    'name': 'Methyl formate',
#    'dummy': 'air',
#    'amount': 0.010879671179915881,
#    'categories': ('air',),
#    'input': ('biosphere3', 'a6386bef-e154-4862-967c-f3767d7f9a2a')},
#   {'CAS number': 107313.0,
#    'name': 'Methyl formate',
#    'dummy': 'air',
#    'amount': 0.010879671179915881,
#    'categories': ('air',),
#    'input': ('biosphere3', '4877b7b5-0ac1-47f7-96bd-677179544c9f')},
#   {'CAS number': 107313.0,
#    'name': 'Methyl formate',
#    'dummy': 'air',
#    'amount': 0.010879671179915881,
#    'categories': ('air',),
#    'input': ('biosphere3', 'f4ce8a13-0159-48e3-a773-669d75e9fd78')},
#   {'CAS number': 79209.0,
#    'name': 'Methyl acetate',
#    'dummy': 'air',
#    'amount': 0.02538589941980373,
#    'categories': ('air',),
#    'input': ('biosphere3', 'ef06f2a4-4b8c-4740-9e06-0c2126d1839a')},
#   {'CAS number': 79209.0,
#    'name': 'Methyl acetate',
#    'dummy': 'air',
#    'amount': 0.02538589941980373,
#    'categories': ('air',),
#    'input': ('biosphere3', '0d4989fd-00e3-4522-905f-2ab6a1bd5677')},
#   {'CAS number': 79209.0,
#    'name': 'Methyl acetate',
#    'dummy': 'air',
#    'amount': 0.02538589941980373,
#    'categories': ('air',),
#    'input': ('biosphere3', 'ba38866f-4480-48a7-9e22-92a16fc3e9c5')},
#   {'CAS number': 79209.0,
#    'name': 'Methyl acetate',
#    'dummy': 'air',
#    'amount': 0.02538589941980373,
#    'categories': ('air',),
#    'input': ('biosphere3', '435b0dec-6a6a-4f44-8fa4-0988332459f5')},
#   {'CAS number': 79209.0,
#    'name': 'Methyl acetate',
#    'dummy': 'air',
#    'amount': 0.02538589941980373,
#    'categories': ('air',),
#    'input': ('biosphere3', 'bd70c699-1ea1-4bb1-b23d-bc771d7d6311')},
#   {'CAS number': 141786.0,
#    'name': 'Ethyl acetate',
#    'dummy': 'air',
#    'amount': 0.06890458413946725,
#    'categories': ('air',),
#    'input': ('biosphere3', '8077467e-8d30-46cc-ab55-5759286eebd3')},
#   {'CAS number': 141786.0,
#    'name': 'Ethyl acetate',
#    'dummy': 'air',
#    'amount': 0.06890458413946725,
#    'categories': ('air',),
#    'input': ('biosphere3', '5933e933-9eaf-4f97-ae63-5eb1eea95e53')},
#   {'CAS number': 141786.0,
#    'name': 'Ethyl acetate',
#    'dummy': 'air',
#    'amount': 0.06890458413946725,
#    'categories': ('air',),
#    'input': ('biosphere3', '227f85d8-5156-461f-9d03-03960287debf')},
#   {'CAS number': 141786.0,
#    'name': 'Ethyl acetate',
#    'dummy': 'air',
#    'amount': 0.06890458413946725,
#    'categories': ('air',),
#    'input': ('biosphere3', 'bb656df7-0d8a-427c-b58c-02962e50df57')},
#   {'CAS number': 141786.0,
#    'name': 'Ethyl acetate',
#    'dummy': 'air',
#    'amount': 0.06890458413946725,
#    'categories': ('air',),
#    'input': ('biosphere3', '41cce80a-82c1-4caa-b6ef-718ec4b83fd6')},
#   {'CAS number': 123864.0,
#    'name': 'Butyl acetate',
#    'dummy': 'air',
#    'amount': 0.09429048355927099,
#    'categories': ('air',),
#    'input': ('biosphere3', '5c91a905-8d1d-4b84-b207-9b6332b4425e')},
#   {'CAS number': 123864.0,
#    'name': 'Butyl acetate',
#    'dummy': 'air',
#    'amount': 0.09429048355927099,
#    'categories': ('air',),
#    'input': ('biosphere3', '108e9780-646b-448d-903b-609b3f65950b')},
#   {'CAS number': 123864.0,
#    'name': 'Butyl acetate',
#    'dummy': 'air',
#    'amount': 0.09429048355927099,
#    'categories': ('air',),
#    'input': ('biosphere3', '9f7e577d-509b-4bbd-805f-3293a44fdc89')},
#   {'CAS number': 123864.0,
#    'name': 'Butyl acetate',
#    'dummy': 'air',
#    'amount': 0.09429048355927099,
#    'categories': ('air',),
#    'input': ('biosphere3', 'da3d541f-0063-4ddf-9b0d-7ba7b8cb6ec7')},
#   {'CAS number': 123864.0,
#    'name': 'Butyl acetate',
#    'dummy': 'air',
#    'amount': 0.09429048355927099,
#    'categories': ('air',),
#    'input': ('biosphere3', '1fee3bdb-480b-4194-b3d7-0e4bd2814c33')},
#   {'CAS number': 64186.0,
#    'name': 'Formic acid',
#    'dummy': 'air',
#    'amount': 0.010879671179915881,
#    'categories': ('air',),
#    'input': ('biosphere3', 'c8da1004-26dc-493a-a568-72f4c3820fc8')},
#   {'CAS number': 64186.0,
#    'name': 'Formic acid',
#    'dummy': 'air',
#    'amount': 0.010879671179915881,
#    'categories': ('air',),
#    'input': ('biosphere3', 'da3057af-dca7-4b7d-b36e-8b241586cc0c')},
#   {'CAS number': 64186.0,
#    'name': 'Formic acid',
#    'dummy': 'air',
#    'amount': 0.010879671179915881,
#    'categories': ('air',),
#    'input': ('biosphere3', '2cbe35d9-052c-4fe8-8eb2-08769f10b2c7')},
#   {'CAS number': 64186.0,
#    'name': 'Formic acid',
#    'dummy': 'air',
#    'amount': 0.010879671179915881,
#    'categories': ('air',),
#    'input': ('biosphere3', '27804c78-5eee-47f9-9a91-1f6126ccfe45')},
#   {'CAS number': 64186.0,
#    'name': 'Formic acid',
#    'dummy': 'air',
#    'amount': 0.010879671179915881,
#    'categories': ('air',),
#    'input': ('biosphere3', 'e7f7fd97-a1c8-4be9-8a21-68ef06437d20')},
#   {'CAS number': 64197.0,
#    'name': 'Acetic acid',
#    'dummy': 'air',
#    'amount': 0.03263901353974765,
#    'categories': ('air',),
#    'input': ('biosphere3', 'd157416d-db9b-4f88-a7f3-a9a5f1ea88f2')},
#   {'CAS number': 64197.0,
#    'name': 'Acetic acid',
#    'dummy': 'air',
#    'amount': 0.03263901353974765,
#    'categories': ('air',),
#    'input': ('biosphere3', 'f53378fe-3e04-4f74-9a08-bea2a6332b67')},
#   {'CAS number': 64197.0,
#    'name': 'Acetic acid',
#    'dummy': 'air',
#    'amount': 0.03263901353974765,
#    'categories': ('air',),
#    'input': ('biosphere3', 'b9b68c0c-053e-41de-ab72-8dfe1c3f5755')},
#   {'CAS number': 64197.0,
#    'name': 'Acetic acid',
#    'dummy': 'air',
#    'amount': 0.03263901353974765,
#    'categories': ('air',),
#    'input': ('biosphere3', 'c5cc0625-6e01-4639-b053-5d1d9d22a53c')},
#   {'CAS number': 64197.0,
#    'name': 'Acetic acid',
#    'dummy': 'air',
#    'amount': 0.03263901353974765,
#    'categories': ('air',),
#    'input': ('biosphere3', 'e9acbffd-7211-42e2-9f3a-cd9556e21132')},
#   {'CAS number': 107028.0,
#    'name': 'Acrolein',
#    'dummy': 'air',
#    'amount': 0.1958340812384859,
#    'categories': ('air',),
#    'input': ('biosphere3', '12840cef-c3b8-4ef2-b7d4-3a73dbd6a280')},
#   {'CAS number': 107028.0,
#    'name': 'Acrolein',
#    'dummy': 'air',
#    'amount': 0.1958340812384859,
#    'categories': ('air',),
#    'input': ('biosphere3', 'd896ced7-a107-4017-b284-d95a8ef3e735')},
#   {'CAS number': 107028.0,
#    'name': 'Acrolein',
#    'dummy': 'air',
#    'amount': 0.1958340812384859,
#    'categories': ('air',),
#    'input': ('biosphere3', '7ed6dc0d-9c2e-4046-a44b-e8a708c2081e')},
#   {'CAS number': 107028.0,
#    'name': 'Acrolein',
#    'dummy': 'air',
#    'amount': 0.1958340812384859,
#    'categories': ('air',),
#    'input': ('biosphere3', '1ccc25c5-f5c0-4deb-b34a-965ccbaa4caa')},
#   {'CAS number': 107028.0,
#    'name': 'Acrolein',
#    'dummy': 'air',
#    'amount': 0.1958340812384859,
#    'categories': ('air',),
#    'input': ('biosphere3', '086f6b04-002c-49a0-9be8-2bad29a9c17a')},
#   {'CAS number': 79016.0,
#    'name': 'Trichloroethylene',
#    'dummy': 'air',
#    'amount': 0.10517015473918685,
#    'categories': ('air',),
#    'input': ('biosphere3', 'a0950325-06dc-5ca0-84b6-983c9e6ccf74')},
#   {'CAS number': 67663.0,
#    'name': 'Chloroform',
#    'dummy': 'air',
#    'amount': 0.0,
#    'categories': ('air',),
#    'input': ('biosphere3', 'fbf6ab3a-74e3-4cbe-b61d-959728bdce46')},
#   {'CAS number': 67663.0,
#    'name': 'Chloroform',
#    'dummy': 'air',
#    'amount': 0.0,
#    'categories': ('air',),
#    'input': ('biosphere3', '78259cf2-1bb2-41ec-941c-9d70909df094')},
#   {'CAS number': 67663.0,
#    'name': 'Chloroform',
#    'dummy': 'air',
#    'amount': 0.0,
#    'categories': ('air',),
#    'input': ('biosphere3', '98af3079-fb76-488d-8afe-713814e14d36')},
#   {'CAS number': 67663.0,
#    'name': 'Chloroform',
#    'dummy': 'air',
#    'amount': 0.0,
#    'categories': ('air',),
#    'input': ('biosphere3', 'fa9b9736-6de8-4bd6-ba22-1bd78c798373')},
#   {'CAS number': 67663.0,
#    'name': 'Chloroform',
#    'dummy': 'air',
#    'amount': 0.0,
#    'categories': ('air',),
#    'input': ('biosphere3', '4cadbc9f-0472-4bb9-a942-df5b90e37878')},
#   {'CAS number': '',
#    'name': 'Aldehydes, unspecified',
#    'dummy': 'air',
#    'amount': 0.174,
#    'categories': ('air',),
#    'input': ('biosphere3', 'ac07bb4a-a492-45b3-9a07-4ab9b8959374')},
#   {'CAS number': '',
#    'name': 'Aldehydes, unspecified',
#    'dummy': 'air',
#    'amount': 0.174,
#    'categories': ('air',),
#    'input': ('biosphere3', 'ba1a3dcb-d53a-42fd-80f0-d09f3a12ffe2')},
#   {'CAS number': '',
#    'name': 'Aldehydes, unspecified',
#    'dummy': 'air',
#    'amount': 0.174,
#    'categories': ('air',),
#    'input': ('biosphere3', '5f1878da-0442-40c8-8c89-7173d67697cf')},
#   {'CAS number': '',
#    'name': 'Aldehydes, unspecified',
#    'dummy': 'air',
#    'amount': 0.174,
#    'categories': ('air',),
#    'input': ('biosphere3', '06f0a67c-ec68-435d-8c32-0decd79a4a1a')},
#   {'CAS number': '',
#    'name': 'Aldehydes, unspecified',
#    'dummy': 'air',
#    'amount': 0.174,
#    'categories': ('air',),
#    'input': ('biosphere3', 'd961f86b-e36b-4ac6-8cd4-b253e496de79')},
#   {'CAS number': '',
#    'name': 'Hydrocarbons, chlorinated',
#    'dummy': 'air',
#    'amount': 0.0266,
#    'categories': ('air',),
#    'input': ('biosphere3', 'd6626dfb-3ac8-4169-9e75-54c41ef2a582')},
#   {'CAS number': '',
#    'name': 'Hydrocarbons, chlorinated',
#    'dummy': 'air',
#    'amount': 0.0266,
#    'categories': ('air',),
#    'input': ('biosphere3', '626dd1d8-5355-40cb-8569-9c87c2c6ab18')},
#   {'CAS number': '',
#    'name': 'Hydrocarbons, chlorinated',
#    'dummy': 'air',
#    'amount': 0.0266,
#    'categories': ('air',),
#    'input': ('biosphere3', '15a335be-9a71-431f-a0b0-56585fbafe5e')},
#   {'CAS number': '',
#    'name': 'Hydrocarbons, chlorinated',
#    'dummy': 'air',
#    'amount': 0.0266,
#    'categories': ('air',),
#    'input': ('biosphere3', '21f7d520-f329-4592-8880-949a08773371')},
#   {'CAS number': '',
#    'name': 'Hydrocarbons, chlorinated',
#    'dummy': 'air',
#    'amount': 0.0266,
#    'categories': ('air',),
#    'input': ('biosphere3', 'd14eb0da-95fd-46c3-90db-55ca33d78701')},
#   {'CAS number': '',
#    'name': 'Hydrocarbons, aliphatic, alkanes, cyclic',
#    'dummy': 'air',
#    'amount': 0.0984,
#    'categories': ('air',),
#    'input': ('biosphere3', 'fea16062-6c4b-4d59-be9e-e9b0b56ca9f0')},
#   {'CAS number': '',
#    'name': 'Hydrocarbons, aliphatic, alkanes, cyclic',
#    'dummy': 'air',
#    'amount': 0.0984,
#    'categories': ('air',),
#    'input': ('biosphere3', 'a97ba30e-898d-4e73-bd62-ec8f636659c2')},
#   {'CAS number': '',
#    'name': 'Hydrocarbons, aliphatic, alkanes, cyclic',
#    'dummy': 'air',
#    'amount': 0.0984,
#    'categories': ('air',),
#    'input': ('biosphere3', '5f4baaf6-055e-491e-9852-258897ab5194')},
#   {'CAS number': '',
#    'name': 'Hydrocarbons, aliphatic, alkanes, cyclic',
#    'dummy': 'air',
#    'amount': 0.0984,
#    'categories': ('air',),
#    'input': ('biosphere3', '18282ab8-5b46-4c56-9038-588ed28a4a95')},
#   {'CAS number': '',
#    'name': 'Hydrocarbons, aliphatic, alkanes, cyclic',
#    'dummy': 'air',
#    'amount': 0.0984,
#    'categories': ('air',),
#    'input': ('biosphere3', '5c9ec415-12f1-4390-bcff-3ff0fcd7ba73')},
#   {'CAS number': '',
#    'name': 'Hydrocarbons, aromatic',
#    'dummy': 'air',
#    'amount': 0.163,
#    'categories': ('air',),
#    'input': ('biosphere3', '596712ce-d415-4636-a3cf-acc767b36857')},
#   {'CAS number': '',
#    'name': 'Hydrocarbons, aromatic',
#    'dummy': 'air',
#    'amount': 0.163,
#    'categories': ('air',),
#    'input': ('biosphere3', '8b5d5c1d-c786-4367-94f0-fae42cd3ac0a')},
#   {'CAS number': '',
#    'name': 'Hydrocarbons, aromatic',
#    'dummy': 'air',
#    'amount': 0.163,
#    'categories': ('air',),
#    'input': ('biosphere3', 'c67be924-e68d-4bc1-9dd9-25f33a6cad34')},
#   {'CAS number': '',
#    'name': 'Hydrocarbons, aromatic',
#    'dummy': 'air',
#    'amount': 0.163,
#    'categories': ('air',),
#    'input': ('biosphere3', '34cbdeb9-6462-4938-a048-881a9f7e6978')},
#   {'CAS number': '',
#    'name': 'Hydrocarbons, aromatic',
#    'dummy': 'air',
#    'amount': 0.163,
#    'categories': ('air',),
#    'input': ('biosphere3', '3cca7f02-58b0-4b49-9938-e0f8bea03064')}]}

# %%
gw.write_excel("ozone-formation-humans")
# Out:
# Wrote matching file to:
# /Users/cmutel/Library/Application Support/Brightway3/default.c21f969b/output/lcia-matching-ozone-formation-humans.xlsx

# %%
gw.statistics()
# Out:
# 1 methods
# 337 cfs
# 104 unlinked cfs
# (1, 337, 104)

# %%
for x in gw.unlinked:
    if c.match(x['name'], search=False):
        print(x['name'])

# %%
for x in gw.unlinked:
    print(x['name'])
# Out:
# i-Pentane
# Neopentane
# 2,2-Dimethylbutane
# 2,3-Dimethylbutane
# 2-Methylhexane
# 3-Methylhexane
# Octane
# 2-Methylheptane
# 3-Methylheptane
# Nonane
# 2-Methyloctane
# 3-Methyloctane
# 4-Methyloctane
# 3,4-Dimethylheptane
# Decane
# 2-Methylnonane
# 3-Methylnonane
# 4-Methylnonane
# 2,5-Dimethyloctane
# 2,6-Dimethyloctane
# 2-Methyl-3-ethylheptane
# 2,2-Dimethyl-3,3-dimethylhexane
# Undecane
# 2-Methyldecane
# 3-Methyldecane
# 4-Methyldecane
# 5-Methyldecane
# Dodecane
# Tridecane
# Tetradecane
# Methylcyclopentane
# Methylcyclohexane
# Ethylcyclohexane
# Propylcyclohexane
# 1,2,3-Trimethylcyclohexane
# i-Propylcyclohexane
# Butylcyclohexane
# i-Butylcyclohexane
# 1-Methyl-3-propylcyclohexane
# 1-Methyl-4-propylcyclohexane
# Pentylcyclohexane
# Hexylcyclohexane
# But-1-ene
# Cis-but-2-ene
# Trans-but-2-ene
# Butylene
# Cis-pent-2-ene
# Trans-pent-2-ene
# 2-Methylbut-1-ene
# 3-Methylbut-1-ene
# Hex-1-ene
# Cis-hex-2-ene
# Trans-hex-2-ene
# Alpha-pinene
# Beta-pinene
# Limonene
# 2-Methyl-3-butenol
# p-Xylene
# Propylbenzene
# 1,2,3-Trimethylbenzene
# 1,2,4-Trimethylbenzene
# 1,3,5-Trimethylbenzene
# o-Ethyltoluene
# m-Ethyltoluene
# p-Ethyltoluene
# 3,5-Dimethylethylbenzene
# 3,5-Diethyltoluene
# 1,2,3,5-Tetramethylbenzene
# 1,2,4,5-Tetramethylbenzene
# 1-Methyl-4-i-propylbenzene
# 1-Methyl-3-i-propylbenzene
# i-Propionaldehyde
# Butyraldehyde
# Pentanal
# 3-Methylbutanal
# 2-Methylbenzaldehyde
# 3-Methylbenzaldehyde
# 4-Methylbenzaldehyde
# sec-butanol
# t-Butanol
# o-Cresol
# 2,5-Xylenol
# 2,4-Xylenol
# 2,3-Xylenol
# Cyclohexanol
# Diacetone alcohol
# Cyclohexanone
# Methylpropylketone
# i-Propyl acetate
# n-Propyl acetate
# Di-i-propylether
# Ethylene glycol
# Propylene glycol
# 2-Butoxyethanol
# 1-Methoxy-2-propanol
# 2-Methoxyethanol
# Methacrolein
# Glyoxal
# Methylglyoxal
# Propyne
# Ethylidene dichloride
# Cis-dichloroethylene
# Trans-dichloroethylene
# Carboxylic acids

# %%
biosphere_names = sorted({o['name']: o for o in biosphere})

# %%
biosphere_names
# Out:
# ['1,3-Dioxolan-2-one',
#  '1,4-Butanediol',
#  '1-Pentanol',
#  '1-Pentene',
#  '2,2,4-Trimethyl pentane',
#  '2,4-D',
#  '2,4-D amines',
#  '2,4-D ester',
#  '2,4-DB',
#  '2,4-di-tert-butylphenol',
#  '2-Amino-3-chloro-1,4-naphthoquinone',
#  '2-Aminopropanol',
#  '2-Methyl pentane',
#  '2-Methyl-1-propanol',
#  '2-Methyl-2-butene',
#  '2-Nitrobenzoic acid',
#  '2-Phenylphenol',
#  '2-Propanol',
#  '2-chlorobenzaldehyde',
#  '3-Methyl-1-butanol',
#  '4-Methyl-2-pentanol',
#  '4-Methyl-2-pentanone',
#  '8-Quinolinol',
#  'AOX, Adsorbable Organic Halogen as Cl',
#  'Abamectin',
#  'Acenaphthene',
#  'Acenaphthylene',
#  'Acephate',
#  'Acetaldehyde',
#  'Acetamide',
#  'Acetamiprid',
#  'Acetic acid',
#  'Acetic acid, trifluoro-',
#  'Acetochlor',
#  'Acetone',
#  'Acetonitrile',
#  'Acetyl chloride',
#  'Acibenzolar-S-methyl',
#  'Acidity, unspecified',
#  'Acifluorfen',
#  'Aclonifen',
#  'Acrinathrin',
#  'Acrolein',
#  'Acrylate, ion',
#  'Acrylic acid',
#  'Acrylonitrile',
#  'Actinides, radioactive, unspecified',
#  'Actinium, in ground',
#  'Aerosols, radioactive, unspecified',
#  'Alachlor',
#  'Alanycarb',
#  'Aldehydes, unspecified',
#  'Aldicarb',
#  'Aldrin',
#  'Allethrin',
#  'Allyl chloride',
#  'Alpha-cypermethrin',
#  'Aluminium',
#  'Aluminium hydroxide',
#  'Aluminium, 24% in bauxite, 11% in crude ore, in ground',
#  'Aluminium, in ground',
#  'Americium-241',
#  'Ametryn',
#  'Amidosulfuron',
#  'Amine oxide',
#  'Amitraz',
#  'Ammonia',
#  'Ammonium carbonate',
#  'Ammonium sulfate',
#  'Ammonium, ion',
#  'Anhydrite, in ground',
#  'Anilazine',
#  'Aniline',
#  'Anthracene',
#  'Anthranilic acid',
#  'Anthraquinone',
#  'Antimony',
#  'Antimony, in ground',
#  'Antimony-122',
#  'Antimony-124',
#  'Antimony-125',
#  'Argon-40',
#  'Argon-41',
#  'Arsenic',
#  'Arsenic, in ground',
#  'Arsenic, ion',
#  'Arsine',
#  'Astatine, in ground',
#  'Asulam',
#  'Atrazine',
#  'Azaconazol',
#  'Azadirachtin',
#  'Azinphos-methyl',
#  'Aziprotryne',
#  'Azoxystrobin',
#  'BOD5, Biological Oxygen Demand',
#  'Barite',
#  'Barite, 15% in crude ore, in ground',
#  'Barium',
#  'Barium sulfide',
#  'Barium, in ground',
#  'Barium-140',
#  'Basalt, in ground',
#  'Benalaxyl',
#  'Benazolin',
#  'Benfluralin',
#  'Benomyl',
#  'Benoxacor',
#  'Bensulfuron methyl ester',
#  'Bensultap',
#  'Bentazone',
#  'Benthiavalicarb',
#  'Benthiavalicarb-isopropyl',
#  'Benz(a)anthracene',
#  'Benzal chloride',
#  'Benzaldehyde',
#  'Benzene',
#  'Benzene, chloro-',
#  'Benzene, dichloro',
#  'Benzene, ethyl-',
#  'Benzene, hexachloro-',
#  'Benzene, pentachloro-',
#  'Benzo(a)pyrene',
#  'Benzo(b)fluoranthene',
#  'Benzo(ghi)perylene',
#  'Benzo(k)fluoranthene',
#  'Benzoic acid',
#  'Benzoximate',
#  'Benzthiazuron',
#  'Benzyl alcohol',
#  'Beryllium',
#  'Beryllium, in ground',
#  'Beta-cypermethrin',
#  'Bicarbonate, ion',
#  'Bifenox',
#  'Bifenthrin',
#  'Bismuth, in ground',
#  'Bisphenol A',
#  'Bitertanol',
#  'Borate',
#  'Borax, in ground',
#  'Boric acid',
#  'Boron',
#  'Boron carbide',
#  'Boron trifluoride',
#  'Boron, in ground',
#  'Boscalid',
#  'Bromacil',
#  'Bromate',
#  'Bromide',
#  'Bromine',
#  'Bromine, 0.23% in water',
#  'Bromine, in water',
#  'Bromofenoxim',
#  'Bromopropane',
#  'Bromopropylate',
#  'Bromoxynil',
#  'Bromoxynil octanoate',
#  'Bromuconazole',
#  'Bupirimate',
#  'Buprofezin',
#  'Butadiene',
#  'Butafenacil',
#  'Butane',
#  'Butanol',
#  'Butene',
#  'Butoxycarboxim',
#  'Butralin',
#  'Butyl acetate',
#  'Butylcarbamate, iodopropynyl',
#  'Butyrolactone',
#  'COD, Chemical Oxygen Demand',
#  'Cadmium',
#  'Cadmium, 0.30% in sulfide, Cd 0.18%, Pb, Zn, Ag, In, in ground',
#  'Cadmium, in ground',
#  'Cadmium, ion',
#  'Cadmium-109',
#  'Caesium, in ground',
#  'Calcite, in ground',
#  'Calcium',
#  'Calcium cyanamide',
#  'Calcium hydroxide',
#  'Calcium, in ground',
#  'Calcium, ion',
#  'Captan',
#  'Carbaryl',
#  'Carbendazim',
#  'Carbetamide',
#  'Carbofuran',
#  'Carbon',
#  'Carbon dioxide, fossil',
#  'Carbon dioxide, from soil or biomass stock',
#  'Carbon dioxide, in air',
#  'Carbon dioxide, non-fossil',
#  'Carbon dioxide, non-fossil, from calcination',
#  'Carbon dioxide, to soil or biomass stock',
#  'Carbon disulfide',
#  'Carbon monoxide, fossil',
#  'Carbon monoxide, from soil or biomass stock',
#  'Carbon monoxide, non-fossil',
#  'Carbon, organic, in soil or biomass stock',
#  'Carbon-14',
#  'Carbonate',
#  'Carbonyl sulfide',
#  'Carbosulfan',
#  'Carboxin',
#  'Carboxylic acids, unspecified',
#  'Carfentrazone ethyl ester',
#  'Carfentrazone-ethyl',
#  'Carnallite',
#  'Cerium, 24% in bastnasite, 2.4% in crude ore, in ground',
#  'Cerium, in ground',
#  'Cerium-141',
#  'Cerium-144',
#  'Cesium',
#  'Cesium-134',
#  'Cesium-136',
#  'Cesium-137',
#  'Chloramine',
#  'Chlorate',
#  'Chlorbromuron',
#  'Chlorbufam',
#  'Chlorfenvinphos',
#  'Chloridazon',
#  'Chloride',
#  'Chloride, ion',
#  'Chlorides, unspecified',
#  'Chlorimuron-ethyl',
#  'Chlorinated solvents, unspecified',
#  'Chlorine',
#  'Chlormequat',
#  'Chlormequat chloride',
#  'Chloroacetic acid',
#  'Chloroacetyl chloride',
#  'Chloroform',
#  'Chloropicrin',
#  'Chlorosilane, trimethyl-',
#  'Chlorosulfonic acid',
#  'Chlorothalonil',
#  'Chlorotoluron',
#  'Chlorpyrifos',
#  'Chlorpyrifos methyl',
#  'Chlorsulfuron',
#  'Chlorthal',
#  'Chlozolinate',
#  'Choline chloride',
#  'Chromium',
#  'Chromium IV',
#  'Chromium VI',
#  'Chromium, 25.5% in chromite, 11.6% in crude ore, in ground',
#  'Chromium, in ground',
#  'Chromium, ion',
#  'Chromium-51',
#  'Chrysene',
#  'Chrysotile, in ground',
#  'Cinidon-ethyl',
#  'Cinnabar, in ground',
#  'Clay, bentonite, in ground',
#  'Clay, unspecified, in ground',
#  'Clethodim',
#  'Clodinafop-propargyl',
#  'Clofentezine',
#  'Clomazone',
#  'Clopyralid',
#  'Cloquintocet-mexyl',
#  'Cloransulam-methyl',
#  'Clothianidin',
#  'Coal, brown, in ground',
#  'Coal, hard, unspecified, in ground',
#  'Cobalt',
#  'Cobalt, Co 5.0E-2%, in mixed ore, in ground',
#  'Cobalt, in ground',
#  'Cobalt-57',
#  'Cobalt-58',
#  'Cobalt-60',
#  'Colemanite, in ground',
#  'Copper',
#  'Copper, 0.52% in sulfide, Cu 0.27% and Mo 8.2E-3% in crude ore, in ground',
#  'Copper, 0.59% in sulfide, Cu 0.22% and Mo 8.2E-3% in crude ore, in ground',
#  'Copper, 0.97% in sulfide, Cu 0.36% and Mo 4.1E-2% in crude ore, in ground',
#  'Copper, 0.99% in sulfide, Cu 0.36% and Mo 8.2E-3% in crude ore, in ground',
#  'Copper, 1.13% in sulfide, Cu 0.76% and Ni 0.76% in crude ore, in ground',
#  'Copper, 1.18% in sulfide, Cu 0.39% and Mo 8.2E-3% in crude ore, in ground',
#  'Copper, 1.25% in sulfide, Cu 0.24% and Zn 0,1% in crude ore, in ground',
#  'Copper, 1.42% in sulfide, Cu 0.81% and Mo 8.2E-3% in crude ore, in ground',
#  'Copper, 2.19% in sulfide, Cu 1.83% and Mo 8.2E-3% in crude ore, in ground',
#  'Copper, Cu 0.2%, in mixed ore, in ground',
#  'Copper, Cu 0.38%, in mixed ore, in ground',
#  'Copper, Cu 6.8E-1%, in mixed ore, in ground',
#  'Copper, in ground',
#  'Copper, ion',
#  'Cu, Cu 3.2E+0%, Pt 2.5E-4%, Pd 7.3E-4%, Rh 2.0E-5%, Ni 2.3E+0% in ore, in ground',
#  'Cu, Cu 5.2E-2%, Pt 4.8E-4%, Pd 2.0E-4%, Rh 2.4E-5%, Ni 3.7E-2% in ore, in ground',
#  'Cu-HDO',
#  'Cumene',
#  'Curium alpha',
#  'Curium-242',
#  'Curium-244',
#  'Cyanamide',
#  'Cyanazine',
#  'Cyanide',
#  'Cyanoacetic acid',
#  'Cyazofamid',
#  'Cyclanilide',
#  'Cyclohexane',
#  'Cyclohexane (for all cycloalkanes)',
#  'Cyclopentane',
#  'Cycloxydim',
#  'Cycluron',
#  'Cyfluthrin',
#  'Cyhalothrin',
#  'Cyhalothrin, gamma-',
#  'Cyhexatin',
#  'Cymoxanil',
#  'Cypermethrin',
#  'Cyproconazole',
#  'Cyprodinil',
#  'Cyromazine',
#  'DNOC',
#  'DOC, Dissolved Organic Carbon',
#  'DSMA',
#  'Daminozide',
#  'Dazomet',
#  'Decanoic acid',
#  'Deltamethrin',
#  'Demeton-S-methylsulfon',
#  'Desmedipham',
#  'Diafenthiuron',
#  'Dialifor',
#  'Diatomite, in ground',
#  'Diazinon',
#  'Dibenz(a,h)anthracene',
#  'Diborane',
#  'Dibutyltin',
#  'Dicamba',
#  'Dichlobenil',
#  'Dichlofluanid',
#  'Dichlorodimethylsilane',
#  'Dichlorprop',
#  'Dichlorprop-P',
#  'Dichlorvos',
#  'Dichromate',
#  'Diclofop',
#  'Diclofop-methyl',
#  'Dicofol',
#  'Dicrotophos',
#  'Dienochlor',
#  'Diethanolamine',
#  'Diethofencarb',
#  'Diethyl ether',
#  'Diethylamine',
#  'Diethylene glycol',
#  'Difenoconazole',
#  'Diflubenzuron',
#  'Diflufenican',
#  'Diflufenzopyr-sodium',
#  'Diisobutyl ketone',
#  'Dimefuron',
#  'Dimethachlor',
#  'Dimethenamid',
#  'Dimethenamid-P',
#  'Dimethipin',
#  'Dimethoate',
#  'Dimethomorph',
#  'Dimethyl carbonate',
#  'Dimethyl ether',
#  'Dimethyl hexanediol',
#  'Dimethyl hexynediol',
#  'Dimethyl malonate',
#  'Dimethylamine',
#  'Dimethyldichlorosilane',
#  'Dinitrogen monoxide',
#  'Dinitrogen tetroxide',
#  'Dinocap',
#  'Dinoseb',
#  'Diofenolan',
#  'Dioxins, measured as 2,3,7,8-tetrachlorodibenzo-p-dioxin',
#  'Diphenylether-compound',
#  'Diphenyltin',
#  'Dipropylamine',
#  'Diquat',
#  'Diquat dibromide',
#  'Discarded fish, demersal, to ocean',
#  'Discarded fish, pelagic, to ocean',
#  'Disinfectants, unspecified',
#  'Dissolved solids',
#  'Disulfoton',
#  'Dithianon',
#  'Diuron',
#  'Dodecanol',
#  'Dodemorph',
#  'Dodine',
#  'Dolomite, in ground',
#  'Dysprosium, in ground',
#  'EPTC',
#  'Elemental carbon',
#  'Endosulfan',
#  'Endothall',
#  'Energy, geothermal, converted',
#  'Energy, gross calorific value, in biomass',
#  'Energy, gross calorific value, in biomass, primary forest',
#  'Energy, kinetic (in wind), converted',
#  'Energy, potential (in hydropower reservoir), converted',
#  'Energy, solar, converted',
#  'Epichlorohydrin',
#  'Epoxiconazole',
#  'Erbium, in ground',
#  'Esfenvalerate',
#  'Ethalfluralin',
#  'Ethane',
#  'Ethane thiol',
#  'Ethane, 1,1,1,2-tetrafluoro-, HFC-134a',
#  'Ethane, 1,1,1-trichloro-, HCFC-140',
#  'Ethane, 1,1,1-trifluoro-, HFC-143a',
#  'Ethane, 1,1,2-trichloro-',
#  'Ethane, 1,1,2-trichloro-1,2,2-trifluoro-, CFC-113',
#  'Ethane, 1,1-dichloro-1-fluoro-, HCFC-141b',
#  'Ethane, 1,1-difluoro-, HFC-152a',
#  'Ethane, 1,2-dichloro-',
#  'Ethane, 1,2-dichloro-1,1,2,2-tetrafluoro-, CFC-114',
#  'Ethane, 1-chloro-1,1-difluoro-, HCFC-142b',
#  'Ethane, 2,2-dichloro-1,1,1-trifluoro-, HCFC-123',
#  'Ethane, 2-chloro-1,1,1,2-tetrafluoro-, HCFC-124',
#  'Ethane, chloropentafluoro-, CFC-115',
#  'Ethane, hexachloro-',
#  'Ethane, hexafluoro-, HFC-116',
#  'Ethane, pentafluoro-, HFC-125',
#  'Ethanol',
#  'Ethene',
#  'Ethene, chloro-',
#  'Ethene, tetrachloro-',
#  'Ethene, trichloro-',
#  'Ethephon',
#  'Ethiofencarb',
#  'Ethofumesate',
#  'Ethoprop',
#  'Ethyl acetate',
#  'Ethyl cellulose',
#  'Ethylamine',
#  'Ethylene',
#  'Ethylene diamine',
#  'Ethylene glycol monoethyl ether',
#  'Ethylene oxide',
#  'Ethyne',
#  'Etoxazole',
#  'Etridiazole',
#  'Europium, 0.06% in bastnasite, 0.006% in crude ore, in ground',
#  'Europium, in ground',
#  'Expenditures on primary production factors',
#  'Famoxadone',
#  'Feldspar, in ground',
#  'Fenamidone',
#  'Fenamiphos',
#  'Fenazaquin',
#  'Fenbuconazole',
#  'Fenbutatin oxide',
#  'Fenfuram',
#  'Fenhexamid',
#  'Fenitrothion',
#  'Fenoxaprop',
#  'Fenoxaprop ethyl ester',
#  'Fenoxaprop-P ethyl ester',
#  'Fenoxycarb',
#  'Fenpiclonil',
#  'Fenpropathrin',
#  'Fenpropidin',
#  'Fenpropimorph',
#  'Fenpyroximate',
#  'Fentin acetate',
#  'Fentin hydroxide',
#  'Fipronil',
#  'Fish, demersal, in ocean',
#  'Fish, pelagic, in ocean',
#  'Flazasulfuron',
#  'Florasulam',
#  'Fluazifop',
#  'Fluazifop-P-butyl',
#  'Fluazifop-p-butyl',
#  'Fluazinam',
#  'Flucarbazone sodium salt',
#  'Fludioxonil',
#  'Flufenacet',
#  'Flumetsulam',
#  'Flumiclorac-pentyl',
#  'Flumioxazin',
#  'Fluoboric acid',
#  'Fluometuron',
#  'Fluoranthene',
#  'Fluorene',
#  'Fluoride',
#  'Fluorine',
#  'Fluorine, 4.5% in apatite, 1% in crude ore, in ground',
#  'Fluorine, 4.5% in apatite, 3% in crude ore, in ground',
#  'Fluorine, in ground',
#  'Fluorochloridone',
#  'Fluoroglycofen',
#  'Fluoroglycofen-ethyl',
#  'Fluorspar, 92%, in ground',
#  'Fluorspar, in ground',
#  'Fluosilicic acid',
#  'Flupyrsulfuron-methyl',
#  'Fluquinconazole',
#  'Flurenol',
#  'Flurochloridone',
#  'Fluroxypyr',
#  'Flurtamone',
#  'Flusilazole',
#  'Flutolanil',
#  'Folpet',
#  'Fomesafen',
#  'Fonofos',
#  'Foramsulfuron',
#  'Formaldehyde',
#  'Formamide',
#  'Formate',
#  'Formic acid',
#  'Fosetyl',
#  'Fosetyl-aluminium',
#  'Fresh water (obsolete)',
#  'Fuberidazole',
#  'Fungicides, unspecified',
#  'Furalaxyl',
#  'Furan',
#  'Furathiocarb',
#  'Furfural',
#  'Gadolinium, 0.15% in bastnasite, 0.015% in crude ore, in ground',
#  'Gadolinium, in ground',
#  'Gallium, 0.014% in bauxite, in ground',
#  'Gallium, in ground',
#  'Gangue, bauxite, in ground',
#  'Gangue, in ground',
#  'Gas, mine, off-gas, process, coal mining',
#  'Gas, natural, in ground',
#  'Germanium, in ground',
#  'Glucose',
#  'Glufosinate',
#  'Glufosinate ammonium',
#  'Glutaraldehyde',
#  'Glyphosate',
#  'Gold',
#  'Gold, Au 1.0E-7%, in mixed ore, in ground',
#  'Gold, Au 1.1E-4%, Ag 4.2E-3%, in ore, in ground',
#  'Gold, Au 1.3E-4%, Ag 4.6E-5%, in ore, in ground',
#  'Gold, Au 1.4E-4%, in ore, in ground',
#  'Gold, Au 1.8E-4%, in mixed ore, in ground',
#  'Gold, Au 2.1E-4%, Ag 2.1E-4%, in ore, in ground',
#  'Gold, Au 4.3E-4%, in ore, in ground',
#  'Gold, Au 4.9E-5%, in ore, in ground',
#  'Gold, Au 5.4E-4%, Ag 1.5E-5%, in ore, in ground',
#  'Gold, Au 6.7E-4%, in ore, in ground',
#  'Gold, Au 6.8E-4%, Ag 1.5E-4%, in ore, in ground',
#  'Gold, Au 7.1E-4%, in ore, in ground',
#  'Gold, Au 9.7E-4%, in mixed ore, in ground',
#  'Gold, Au 9.7E-5%, Ag 7.6E-5%, in ore, in ground',
#  'Gold, in ground',
#  'Granite, in ground',
#  'Gravel, in ground',
#  'Guazatine',
#  'Gypsum, in ground',
#  'Hafnium, in ground',
#  'Halosulfuron-methyl',
#  'Haloxyfop- (R) Methylester',
#  'Haloxyfop-P-methyl',
#  'Heat, waste',
#  'Helium',
#  'Helium, 0.08% in natural gas, in ground',
#  'Helium, in natural gas, in ground',
#  'Heptane',
#  'Heptenophos',
#  'Herbicides, unspecified',
#  'Hexaconazole',
#  'Hexaflumuron',
#  'Hexamethyldisilizane',
#  'Hexane',
#  'Hexazinone',
#  'Hexythiazox',
#  'Holmium, in ground',
#  'Hydramethylnon',
#  'Hydrazine',
#  'Hydrocarbons, aliphatic, alkanes, cyclic',
#  'Hydrocarbons, aliphatic, alkanes, unspecified',
#  'Hydrocarbons, aliphatic, unsaturated',
#  'Hydrocarbons, aromatic',
#  'Hydrocarbons, chlorinated',
#  'Hydrocarbons, unspecified',
#  'Hydrochloric acid',
#  'Hydrogen',
#  'Hydrogen carbonate',
#  'Hydrogen chloride',
#  'Hydrogen fluoride',
#  'Hydrogen peroxide',
#  'Hydrogen sulfide',
#  'Hydrogen-3, Tritium',
#  'Hydroxide',
#  'Hymexazol',
#  'Hypochlorite',
#  'Imazalil',
#  'Imazamox',
#  'Imazapyr',
#  'Imazaquin',
#  'Imazethapyr',
#  'Imidacloprid',
#  'Indeno(1,2,3-cd)pyrene',
#  'Indium, 0.005% in sulfide, In 0.003%, Pb, Zn, Ag, Cd, in ground',
#  'Indium, in ground',
#  'Indoxacarb',
#  'Insecticides, unspecified',
#  'Iodide',
#  'Iodine',
#  'Iodine, 0.03% in water',
#  'Iodine, in water',
#  'Iodine-129',
#  'Iodine-131',
#  'Iodine-133',
#  'Iodine-135',
#  'Iodosulfuron',
#  'Iodosulfuron-methyl-sodium',
#  'Ioxynil',
#  'Ioxynil methyl ester',
#  'Iprodion',
#  'Iprovalicarb',
#  'Iridium, in ground',
#  'Iron',
#  'Iron, 46% in ore, 25% in crude ore, in ground',
#  'Iron, 72% in magnetite, 14% in crude ore, in ground',
#  'Iron, in ground',
#  'Iron, ion',
#  'Iron-59',
#  'Isobutane',
#  'Isocyanic acid',
#  'Isoprene',
#  'Isopropylamine',
#  'Isoproturon',
#  'Isoxadifen-ethyl',
#  'Isoxaflutole',
#  'Kaolin',
#  'Kaolinite, 24% in crude ore, in ground',
#  'Kaolinite, in ground',
#  'Kieserite, 25% in crude ore, in ground',
#  'Kieserite, in ground',
#  'Kresoxim-methyl',
#  'Krypton, in air',
#  'Krypton-85',
#  'Krypton-85m',
#  'Krypton-87',
#  'Krypton-88',
#  'Krypton-89',
#  'Labour cost',
#  'Lactic acid',
#  'Lactofen',
#  'Lambda-cyhalothrin',
#  'Lanthanum',
#  'Lanthanum, 7.2% in bastnasite, 0.72% in crude ore, in ground',
#  'Lanthanum, in ground',
#  'Lanthanum-140',
#  'Laterite, in ground',
#  'Lauric acid',
#  'Lead',
#  'Lead, 5.0% in sulfide, Pb 3.0%, Zn, Ag, Cd, In, in ground',
#  'Lead, Pb 0.014%, in mixed ore, in ground',
#  'Lead, Pb 3.6E-1%, in mixed ore, in ground',
#  'Lead, in ground',
#  'Lead-210',
#  'Lenacil',
#  'Lindane',
#  'Linuron',
#  'Lithium',
#  'Lithium carbonate',
#  'Lithium, 0.15% in brine, in ground',
#  'Lithium, in ground',
#  'Lithium, ion',
#  'Lufenuron',
#  'Lutetium, in ground',
#  'MCPA',
#  'MCPB',
#  'MSMA',
#  'Magnesite, 60% in crude ore, in ground',
#  'Magnesite, in ground',
#  'Magnesium',
#  'Magnesium phosphide',
#  'Magnesium, 0.13% in water',
#  'Magnesium, in ground',
#  'Magnesium, in water',
#  'Malathion',
#  'Maleic anhydride',
#  'Maleic hydrazide',
#  'Mancozeb',
#  'Mandipropamid',
#  'Maneb',
#  'Manganese',
#  'Manganese, 35.7% in sedimentary deposit, 14.2% in crude ore, in ground',
#  'Manganese, in ground',
#  'Manganese-54',
#  'Manganese-55',
#  'Mecoprop',
#  'Mecoprop-P',
#  'Mefenpyr',
#  'Mefenpyr-diethyl',
#  'Mepanipyrim',
#  'Mepiquat chloride',
#  'Mepronil',
#  'Mercury',
#  'Mercury, in ground',
#  'Mesosulfuron',
#  'Mesosulfuron-methyl (prop)',
#  'Mesotrione',
#  'Metalaxil',
#  'Metalaxyl-M',
#  'Metaldehyde',
#  'Metam-sodium',
#  'Metamitron',
#  'Metamorphous rock, graphite containing, in ground',
#  'Metazachlor',
#  'Metconazole',
#  'Methabenzthiazuron',
#  'Methamidophos',
#  'Methane',
#  'Methane, bromo-, Halon 1001',
#  'Methane, bromochlorodifluoro-, Halon 1211',
#  'Methane, bromotrifluoro-, Halon 1301',
#  'Methane, chloro-fluoro-, HCFC-31',
#  'Methane, chlorodifluoro-, HCFC-22',
#  'Methane, chlorotrifluoro-, CFC-13',
#  'Methane, dichloro-, HCC-30',
#  'Methane, dichlorodifluoro-, CFC-12',
#  'Methane, dichlorofluoro-, HCFC-21',
#  'Methane, difluoro-, HFC-32',
#  'Methane, fossil',
#  'Methane, from soil or biomass stock',
#  'Methane, monochloro-, R-40',
#  'Methane, non-fossil',
#  'Methane, tetrachloro-, R-10',
#  'Methane, tetrafluoro-, R-14',
#  'Methane, trichlorofluoro-, CFC-11',
#  'Methane, trifluoro-, HFC-23',
#  'Methanesulfonic acid',
#  'Methanol',
#  'Methidathion',
#  'Methiocarb',
#  'Methomyl',
#  'Methoprene',
#  'Methoxyfenozide',
#  'Methyl acetate',
#  'Methyl acrylate',
#  'Methyl amine',
#  'Methyl borate',
#  'Methyl ethyl ketone',
#  'Methyl formate',
#  'Methyl lactate',
#  'Methyl parathion',
#  'Methyl pentane',
#  'Methylamine',
#  'Metiram',
#  'Metobromuron',
#  'Metolachlor',
#  'Metosulam',
#  'Metribuzin',
#  'Metsulfuron-methyl',
#  'Mevinfos',
#  'Mineral oil',
#  'Molinate',
#  'Molybdenum',
#  'Molybdenum, 0.010% in sulfide, Mo 8.2E-3% and Cu 1.83% in crude ore, in ground',
#  'Molybdenum, 0.014% in sulfide, Mo 8.2E-3% and Cu 0.81% in crude ore, in ground',
#  'Molybdenum, 0.016% in sulfide, Mo 8.2E-3% and Cu 0.27% in crude ore, in ground',
#  'Molybdenum, 0.022% in sulfide, Mo 8.2E-3% and Cu 0.22% in crude ore, in ground',
#  'Molybdenum, 0.022% in sulfide, Mo 8.2E-3% and Cu 0.36% in crude ore, in ground',
#  'Molybdenum, 0.025% in sulfide, Mo 8.2E-3% and Cu 0.39% in crude ore, in ground',
#  'Molybdenum, 0.11% in sulfide, Mo 4.1E-2% and Cu 0.36% in crude ore, in ground',
#  'Molybdenum, in ground',
#  'Molybdenum-99',
#  'Monobutyltin',
#  'Monochloroethane',
#  'Monocrotophos',
#  'Monoethanolamine',
#  'Monolinuron',
#  'Monophenyltin',
#  'Myclobutanil',
#  'N-Bromoacetamide',
#  'NMVOC, non-methane volatile organic compounds, unspecified origin',
#  'Naled',
#  'Naphtalene',
#  'Naphthalene',
#  'Napropamide',
#  'Neburon',
#  'Neodymium, 4% in bastnasite, 0.4% in crude ore, in ground',
#  'Neodymium, in ground',
#  'Neptunium-237',
#  'Net operating surplus',
#  'Net tax',
#  'Ni, Ni 2.3E+0%, Pt 2.5E-4%, Pd 7.3E-4%, Rh 2.0E-5%, Cu 3.2E+0% in ore, in ground',
#  'Ni, Ni 3.7E-2%, Pt 4.8E-4%, Pd 2.0E-4%, Rh 2.4E-5%, Cu 5.2E-2% in ore, in ground',
#  'Nickel',
#  'Nickel, 1.13% in sulfide, Ni 0.76% and Cu 0.76% in crude ore, in ground',
#  'Nickel, 1.98% in silicates, 1.04% in crude ore, in ground',
#  'Nickel, Ni 2.5E+0%, in mixed ore, in ground',
#  'Nickel, in ground',
#  'Nickel, ion',
#  'Nicosulfuron',
#  'Niobium, in ground',
#  'Niobium-95',
#  'Nitrate',
#  'Nitric acid',
#  'Nitric oxide',
#  'Nitrite',
#  'Nitrobenzene',
#  'Nitrogen',
#  'Nitrogen dioxide',
#  'Nitrogen fluoride',
#  'Nitrogen oxides',
#  'Nitrogen, organic bound',
#  'Nitrothal-isopropyl',
#  'Noble gases, radioactive, unspecified',
#  'Norflurazon',
#  'Novaluron',
#  'Occupation, annual crop',
#  'Occupation, annual crop, flooded crop',
#  'Occupation, annual crop, greenhouse',
#  'Occupation, annual crop, irrigated',
#  'Occupation, annual crop, irrigated, extensive',
#  'Occupation, annual crop, irrigated, intensive',
#  'Occupation, annual crop, non-irrigated',
#  'Occupation, annual crop, non-irrigated, extensive',
#  'Occupation, annual crop, non-irrigated, intensive',
#  'Occupation, arable land, unspecified use',
#  'Occupation, arable, conservation tillage (obsolete)',
#  'Occupation, arable, conventional tillage (obsolete)',
#  'Occupation, arable, reduced tillage (obsolete)',
#  'Occupation, bare area (non-use)',
#  'Occupation, construction site',
#  'Occupation, cropland fallow (non-use)',
#  'Occupation, dump site',
#  'Occupation, field margin/hedgerow',
#  'Occupation, forest, extensive',
#  'Occupation, forest, intensive',
#  'Occupation, forest, primary (non-use)',
#  'Occupation, forest, secondary (non-use)',
#  'Occupation, forest, unspecified',
#  'Occupation, grassland, natural (non-use)',
#  'Occupation, grassland, natural, for livestock grazing',
#  'Occupation, heterogeneous, agricultural',
#  'Occupation, industrial area',
#  'Occupation, inland waterbody, unspecified',
#  'Occupation, lake, artificial',
#  'Occupation, lake, natural (non-use)',
#  'Occupation, mineral extraction site',
#  'Occupation, pasture, man made',
#  'Occupation, pasture, man made, extensive',
#  'Occupation, pasture, man made, intensive',
#  'Occupation, permanent crop',
#  'Occupation, permanent crop, irrigated',
#  'Occupation, permanent crop, irrigated, extensive',
#  'Occupation, permanent crop, irrigated, intensive',
#  'Occupation, permanent crop, non-irrigated',
#  'Occupation, permanent crop, non-irrigated, extensive',
#  'Occupation, permanent crop, non-irrigated, intensive',
#  'Occupation, river, artificial',
#  'Occupation, river, natural (non-use)',
#  'Occupation, seabed, drilling and mining',
#  'Occupation, seabed, infrastructure',
#  'Occupation, seabed, natural (non-use)',
#  'Occupation, seabed, unspecified',
#  'Occupation, shrub land, sclerophyllous',
#  'Occupation, snow and ice (non-use)',
#  'Occupation, traffic area, rail network',
#  'Occupation, traffic area, rail/road embankment',
#  'Occupation, traffic area, road network',
#  'Occupation, unspecified',
#  'Occupation, unspecified, natural (non-use)',
#  'Occupation, urban, continuously built',
#  'Occupation, urban, discontinuously built',
#  'Occupation, urban, green area',
#  'Occupation, urban/industrial fallow (non-use)',
#  'Occupation, wetland, coastal (non-use)',
#  'Occupation, wetland, inland (non-use)',
#  'Octaethylene glycol monododecyl ether',
#  'Octanoic acid',
#  'Oil, crude, in ground',
#  'Oils, non-fossil',
#  'Oils, unspecified',
#  'Olivine, in ground',
#  'Orbencarb',
#  'Organic carbon',
#  'Oryzalin',
#  'Osmium, in ground',
#  'Oxadixyl',
#  'Oxamyl',
#  'Oxasulfuron',
#  'Oxydemeton-methyl',
#  'Oxyfluorfen',
#  'Oxygen',
#  'Ozone',
#  'P-tert-amylphenol',
#  'PAH, polycyclic aromatic hydrocarbons',
#  'Palladium',
#  'Palladium, Pd 1.6E-6%, in mixed ore, in ground',
#  'Palladium, in ground',
#  'Paraffins',
#  'Paraquat',
#  'Parathion',
#  'Particulates, < 2.5 um',
#  'Particulates, > 10 um',
#  'Particulates, > 2.5 um, and < 10um',
#  'Pd, Pd 2.0E-4%, Pt 4.8E-4%, Rh 2.4E-5%, Ni 3.7E-2%, Cu 5.2E-2% in ore, in ground',
#  'Pd, Pd 7.3E-4%, Pt 2.5E-4%, Rh 2.0E-5%, Ni 2.3E+0%, Cu 3.2E+0% in ore, in ground',
#  'Peat, in ground',
#  'Penconazole',
#  'Pencycuron',
#  'Pendimethalin',
#  'Pentane',
#  'Perchlorate, ion',
#  'Perfluoropentane',
#  'Perlite, in ground',
#  'Permethrin',
#  'Pesticides, unspecified',
#  'Pethoxamid',
#  'Phenanthrene',
#  'Phenmedipham',
#  'Phenol',
#  'Phenol, 2,4-dichloro',
#  'Phenol, pentachloro-',
#  'Phorate',
#  'Phosalone',
#  'Phosgene',
#  'Phosmet',
#  'Phosphate',
#  'Phosphine',
#  'Phosphoric acid',
#  'Phosphorus',
#  'Phosphorus oxychloride',
#  'Phosphorus pentachloride',
#  'Phosphorus trichloride',
#  'Phosphorus, 18% in apatite, 12% in crude ore, in ground',
#  'Phosphorus, 18% in apatite, 4% in crude ore, in ground',
#  'Phosphorus, in ground',
#  'Phthalate, butyl-benzyl-',
#  'Phthalate, dibutyl-',
#  'Phthalate, dimethyl-',
#  'Phthalate, dioctyl-',
#  'Picloram',
#  'Picoxystrobin',
#  'Pinoxaden',
#  'Piperonyl butoxide',
#  'Pirimicarb',
#  'Pirimiphos methyl',
#  'Platinum',
#  'Platinum, Pt 4.7E-7%, in mixed ore, in ground',
#  'Platinum, in ground',
#  'Plutonium-238',
#  'Plutonium-241',
#  'Plutonium-alpha',
#  'Polonium, in ground',
#  'Polonium-210',
#  'Polychlorinated biphenyls',
#  'Potassium',
#  'Potassium chloride',
#  'Potassium hydroxide',
#  'Potassium soap',
#  'Potassium, in ground',
#  'Potassium, ion',
#  'Potassium-40',
#  'Praseodymium, 0.42% in bastnasite, 0.042% in crude ore, in ground',
#  'Praseodymium, in ground',
#  'Primisulfuron',
#  'Prochloraz',
#  'Procymidone',
#  'Profenofos',
#  'Prohexadione-calcium',
#  'Promethium-147',
#  'Prometryn',
#  'Pronamide',
#  'Propachlor',
#  'Propamocarb',
#  'Propamocarb HCl',
#  'Propanal',
#  'Propane',
#  'Propanil',
#  'Propanol',
#  'Propaquizafop',
#  'Propargite',
#  'Propene',
#  'Propham',
#  'Propiconazole',
#  'Propineb',
#  'Propionic acid',
#  'Propoxycarbazone-sodium (prop)',
#  'Propylamine',
#  'Propylene oxide',
#  'Proquinazid',
#  'Prosulfocarb',
#  'Prosulfuron',
#  'Protactinium, in ground',
#  'Protactinium-234',
#  'Prothioconazol',
#  'Pt, Pt 2.5E-4%, Pd 7.3E-4%, Rh 2.0E-5%, Ni 2.3E+0%, Cu 3.2E+0% in ore, in ground',
#  'Pt, Pt 4.8E-4%, Pd 2.0E-4%, Rh 2.4E-5%, Ni 3.7E-2%, Cu 5.2E-2% in ore, in ground',
#  'Pumice, in ground',
#  'Pymetrozine',
#  'Pyraclostrobin',
#  'Pyraclostrobin (prop)',
#  ...]

# %%
comp = gw.compare_to_previous()

# %%
[(key, len(comp[key])) for key in comp]
# Out:
# [('found', 61), ('missing', 107), ('reference', 73)]

# %% [markdown]
# Present in previous ReCiPe, missing here

# %%
c.master_mapping['isobutanol']
# Out:
# '2-methyl-1-propanol'

# %%
[(x['name'], x['CAS number']) for x in biosphere if (x['name'].lower() in ("i-butanol", '2-methyl-1-propanol')) or (x.get('CAS number') == '000078-83-1')]
# Out:
# [('2-Methyl-1-propanol', '000078-83-1'),
#  ('2-Methyl-1-propanol', '000078-83-1'),
#  ('2-Methyl-1-propanol', '000078-83-1'),
#  ('2-Methyl-1-propanol', '000078-83-1'),
#  ('2-Methyl-1-propanol', '000078-83-1'),
#  ('2-Methyl-1-propanol', '000078-83-1'),
#  ('2-Methyl-1-propanol', '000078-83-1'),
#  ('2-Methyl-1-propanol', '000078-83-1'),
#  ('2-Methyl-1-propanol', '000078-83-1'),
#  ('2-Methyl-1-propanol', '000078-83-1')]

# %%
comp['reference']
# Out:
# {'1-pentene',
#  '2-methyl pentane',
#  '2-methyl-1-propanol',
#  '2-methyl-2-butene',
#  '2-propanol',
#  '3-methyl-1-butanol',
#  '4-methyl-2-pentanone',
#  'acetaldehyde',
#  'acetic acid',
#  'acetone',
#  'aldehydes, unspecified',
#  'benzaldehyde',
#  'benzene',
#  'benzene, ethyl-',
#  'butadiene',
#  'butane',
#  'butanol',
#  'butyl acetate',
#  'carbon monoxide, fossil',
#  'carbon monoxide, from soil or biomass stock',
#  'carbon monoxide, non-fossil',
#  'chloroform',
#  'cumene',
#  'cyclohexane',
#  'cyclohexane (for all cycloalkanes)',
#  'diethyl ether',
#  'dimethyl carbonate',
#  'dimethyl ether',
#  'ethane',
#  'ethane, 1,1,1-trichloro-, hcfc-140',
#  'ethanol',
#  'ethene',
#  'ethene, tetrachloro-',
#  'ethene, trichloro-',
#  'ethyl acetate',
#  'ethylene',
#  'ethylene glycol monoethyl ether',
#  'ethyne',
#  'formaldehyde',
#  'formic acid',
#  'heptane',
#  'hexane',
#  'hydrocarbons, aliphatic, alkanes, cyclic',
#  'hydrocarbons, aromatic',
#  'hydrocarbons, chlorinated',
#  'isobutane',
#  'isoprene',
#  'm-xylene',
#  'methane',
#  'methane, dichloro-, hcc-30',
#  'methane, fossil',
#  'methane, from soil or biomass stock',
#  'methane, monochloro-, r-40',
#  'methane, non-fossil',
#  'methanol',
#  'methyl acetate',
#  'methyl ethyl ketone',
#  'methyl formate',
#  'nitrogen oxides',
#  'nmvoc, non-methane volatile organic compounds, unspecified origin',
#  'o-xylene',
#  'pentane',
#  'propanal',
#  'propane',
#  'propanol',
#  'propene',
#  'propionic acid',
#  'styrene',
#  'sulfur dioxide',
#  'sulfur oxides',
#  't-butyl methyl ether',
#  'toluene',
#  'trichloroethylene'}

# %%
comp['found']
# Out:
# {'1,3-butadiene',
#  '1-pentene',
#  '2-ethoxyethanol',
#  '2-methyl pentane',
#  '2-methylbut-2-ene',
#  '3-methyl-1-butanol',
#  '3-methylpentane',
#  'acetaldehyde',
#  'acetic acid',
#  'acetone',
#  'acetylene',
#  'acrolein',
#  'aldehydes, unspecified',
#  'benzaldehyde',
#  'benzene',
#  'butane',
#  'butanol',
#  'butyl acetate',
#  'chloroform',
#  'cyclohexane',
#  'diethylether',
#  'dimethylether',
#  'ethane',
#  'ethanol',
#  'ethyl acetate',
#  'ethyl chloride',
#  'ethylbenzene',
#  'ethylene',
#  'formaldehyde',
#  'formic acid',
#  'heptane',
#  'hexane',
#  'hydrocarbons, aliphatic, alkanes, cyclic',
#  'hydrocarbons, aromatic',
#  'hydrocarbons, chlorinated',
#  'i-butane',
#  'i-butanol',
#  'i-propanol',
#  'i-propylbenzene',
#  'isoprene',
#  'm-xylene',
#  'methanol',
#  'methyl acetate',
#  'methyl chloride',
#  'methyl chloroform',
#  'methyl formate',
#  'methyl-i-butylketone',
#  'methylene dichloride',
#  'methylethylketone',
#  'nitrogen oxides',
#  'o-xylene',
#  'pentane',
#  'phenol',
#  'propane',
#  'propanoic acid',
#  'propanol',
#  'propionaldehyde',
#  'propylene',
#  'styrene',
#  'tetrachloroethylene',
#  'toluene',
#  'trichloroethylene'}

# %%
sorted(comp['reference'].difference(comp['found']))
# Out:
# ['carbon monoxide, fossil',
#  'carbon monoxide, from soil or biomass stock',
#  'carbon monoxide, non-fossil',
#  'cyclohexane (for all cycloalkanes)',
#  'dimethyl carbonate',
#  'ethene',
#  'ethene, trichloro-',
#  'methane',
#  'methane, fossil',
#  'methane, from soil or biomass stock',
#  'methane, non-fossil',
#  'nmvoc, non-methane volatile organic compounds, unspecified origin',
#  'sulfur dioxide',
#  'sulfur oxides',
#  't-butyl methyl ether']

# %%
c['found']

# %%
c['missing']

# %%
gw.drop_unlinked()
# Out:
# Applying strategy: drop_unlinked_cfs
# Applied 1 strategies in 0.00 seconds

# %%
gw.write_methods(overwrite=True)
# Out:
# Wrote 1 LCIA methods with 233 characterization factors

# %%
gw.data[0]['name']
# Out:
# ('ReCiPe 2016', 'v1.1 (20180117)', 'HOFP')

# %% [markdown]
# # Compare to previous ReCiPe method

# %%
# %matplotlib inline

# %%
import bw2data, bw2calc
import pyprind
import seaborn as sb
import numpy as np

# %%
keys = sorted([x.key for x in bw2data.Database("ecoinvent 3.6 cutoff")])

# %%
results_reference, results_2016 = [], []

# %%
lca = bw2calc.LCA({keys[0]: 1}, gw.previous_reference)
lca.lci()
lca.lcia()

# %%
reference_cm = lca.characterization_matrix.copy()

# %%
lca.switch_method(('ReCiPe 2016', 'v1.1 (20180117)', 'HOFP'))

# %%
lca.characterization_matrix.sum(), reference_cm.sum()
# Out:
# (22.627503518015146, 78.32105052284896)

# %%
new_cm = lca.characterization_matrix.copy()

# %%
for key in pyprind.prog_bar(keys):
    lca.redo_lci({key: 1})
    results_reference.append((reference_cm * lca.inventory).sum())
    results_2016.append((new_cm * lca.inventory).sum())
# Out:
# 0% [##############################] 100% | ETA: 00:00:00
# Total time elapsed: 00:05:23

# %%
sb.scatterplot(np.log10(np.array(results_reference)), np.log10(np.array(results_2016)))
# Out:
# /Users/cmutel/miniconda3/envs/bw2dev/lib/python3.7/site-packages/ipykernel_launcher.py:1: RuntimeWarning: divide by zero encountered in log10
#   """Entry point for launching an IPython kernel.

# %%
def masked_ratio(a, b):
    a, b = np.array(a), np.array(b)
    mask = (a != 0) * (b != 0)
    return a / b

# %%
sb.distplot(masked_ratio(results_2016, results_reference))
# Out:
# /Users/cmutel/miniconda3/envs/bw2dev/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: divide by zero encountered in true_divide
#   after removing the cwd from sys.path.
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# <ipython-input-23-2a222fdd991d> in <module>
# ----> 1 sb.distplot(masked_ratio(results_2016, results_reference))
#
# ~/miniconda3/envs/bw2dev/lib/python3.7/site-packages/seaborn/distributions.py in distplot(a, bins, hist, kde, rug, fit, hist_kws, kde_kws, rug_kws, fit_kws, color, vertical, norm_hist, axlabel, label, ax)
#     213     if hist:
#     214         if bins is None:
# --> 215             bins = min(_freedman_diaconis_bins(a), 50)
#     216         hist_kws.setdefault("alpha", 0.4)
#     217         hist_kws.setdefault("density", norm_hist)
#
# ~/miniconda3/envs/bw2dev/lib/python3.7/site-packages/seaborn/distributions.py in _freedman_diaconis_bins(a)
#      33         return int(np.sqrt(a.size))
#      34     else:
# ---> 35         return int(np.ceil((a.max() - a.min()) / h))
#      36
#      37
#
# OverflowError: cannot convert float infinity to integer

# %%
def abnormal_ratio(a, b):
    if not a or not b:
        return
    ratio = abs(a / b)
    if 0.8 < ratio < 1.25:
        return
    return ratio

# %%
exceptions = sorted([
    (abnormal_ratio(results_2016[i], results_reference[i]), bw2data.get_activity(key)) 
    for i, key in enumerate(keys) 
    if abnormal_ratio(results_2016[i], results_reference[i])
], reverse=True)

# %%
len(exceptions)

# %%
exceptions[:10]

# %%
lca.redo_lci({exceptions[0][1]: 1})
lca.characterized_inventory = new_cm * lca.inventory
