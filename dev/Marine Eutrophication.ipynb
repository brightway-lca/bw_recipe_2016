# %%
from bw_recipe_2016 import (
    MarineEutrophication,
    get_biosphere_database, 
    extract_recipe,
)

# %%
data = extract_recipe()[10]

# %%
biosphere = get_biosphere_database()

# %%
for x in sorted({(x['name'].lower(), x['categories'][0]) for x in biosphere}):
    print(x)
# Out:
# ('1,3-dioxolan-2-one', 'water')
# ('1,4-butanediol', 'air')
# ('1,4-butanediol', 'water')
# ('1-pentanol', 'air')
# ('1-pentanol', 'water')
# ('1-pentene', 'air')
# ('1-pentene', 'water')
# ('2,2,4-trimethyl pentane', 'air')
# ('2,4-d', 'air')
# ('2,4-d', 'soil')
# ('2,4-d amines', 'air')
# ('2,4-d amines', 'soil')
# ('2,4-d amines', 'water')
# ('2,4-d ester', 'air')
# ('2,4-d ester', 'soil')
# ('2,4-d ester', 'water')
# ('2,4-db', 'air')
# ('2,4-db', 'soil')
# ('2,4-db', 'water')
# ('2,4-di-tert-butylphenol', 'water')
# ('2-amino-3-chloro-1,4-naphthoquinone', 'soil')
# ('2-aminopropanol', 'air')
# ('2-aminopropanol', 'water')
# ('2-chlorobenzaldehyde', 'water')
# ('2-methyl pentane', 'air')
# ('2-methyl-1-propanol', 'air')
# ('2-methyl-1-propanol', 'water')
# ('2-methyl-2-butene', 'air')
# ('2-methyl-2-butene', 'water')
# ('2-nitrobenzoic acid', 'air')
# ('2-phenylphenol', 'soil')
# ('2-propanol', 'air')
# ('2-propanol', 'water')
# ('3-methyl-1-butanol', 'air')
# ('3-methyl-1-butanol', 'water')
# ('4-methyl-2-pentanol', 'water')
# ('4-methyl-2-pentanone', 'air')
# ('4-methyl-2-pentanone', 'water')
# ('8-quinolinol', 'soil')
# ('abamectin', 'soil')
# ('acenaphthene', 'air')
# ('acenaphthene', 'water')
# ('acenaphthylene', 'air')
# ('acenaphthylene', 'water')
# ('acephate', 'air')
# ('acephate', 'soil')
# ('acetaldehyde', 'air')
# ('acetaldehyde', 'water')
# ('acetamide', 'air')
# ('acetamide', 'soil')
# ('acetamiprid', 'soil')
# ('acetic acid', 'air')
# ('acetic acid', 'water')
# ('acetic acid, trifluoro-', 'air')
# ('acetochlor', 'soil')
# ('acetone', 'air')
# ('acetone', 'water')
# ('acetonitrile', 'air')
# ('acetonitrile', 'water')
# ('acetyl chloride', 'water')
# ('acibenzolar-s-methyl', 'soil')
# ('acidity, unspecified', 'water')
# ('acifluorfen', 'air')
# ('acifluorfen', 'soil')
# ('aclonifen', 'soil')
# ('acrinathrin', 'soil')
# ('acrolein', 'air')
# ('acrolein', 'water')
# ('acrylate, ion', 'water')
# ('acrylic acid', 'air')
# ('acrylonitrile', 'air')
# ('acrylonitrile', 'water')
# ('actinides, radioactive, unspecified', 'air')
# ('actinides, radioactive, unspecified', 'water')
# ('actinium, in ground', 'natural resource')
# ('aerosols, radioactive, unspecified', 'air')
# ('alachlor', 'air')
# ('alachlor', 'soil')
# ('alanycarb', 'soil')
# ('aldehydes, unspecified', 'air')
# ('aldicarb', 'soil')
# ('aldrin', 'soil')
# ('allethrin', 'soil')
# ('allyl chloride', 'water')
# ('alpha-cypermethrin', 'soil')
# ('aluminium', 'air')
# ('aluminium', 'soil')
# ('aluminium', 'water')
# ('aluminium hydroxide', 'water')
# ('aluminium, 24% in bauxite, 11% in crude ore, in ground', 'natural resource')
# ('aluminium, in ground', 'natural resource')
# ('americium-241', 'air')
# ('americium-241', 'water')
# ('ametryn', 'soil')
# ('amidosulfuron', 'soil')
# ('amine oxide', 'air')
# ('amitraz', 'soil')
# ('ammonia', 'air')
# ('ammonia', 'soil')
# ('ammonium carbonate', 'air')
# ('ammonium sulfate', 'water')
# ('ammonium, ion', 'water')
# ('anhydrite, in ground', 'natural resource')
# ('anilazine', 'soil')
# ('aniline', 'air')
# ('aniline', 'water')
# ('anthracene', 'air')
# ('anthracene', 'water')
# ('anthranilic acid', 'air')
# ('anthraquinone', 'soil')
# ('antimony', 'air')
# ('antimony', 'soil')
# ('antimony', 'water')
# ('antimony, in ground', 'natural resource')
# ('antimony-122', 'water')
# ('antimony-124', 'air')
# ('antimony-124', 'water')
# ('antimony-125', 'air')
# ('antimony-125', 'water')
# ('aox, adsorbable organic halogen as cl', 'water')
# ('argon-40', 'air')
# ('argon-40', 'natural resource')
# ('argon-41', 'air')
# ('arsenic', 'air')
# ('arsenic', 'soil')
# ('arsenic, in ground', 'natural resource')
# ('arsenic, ion', 'water')
# ('arsine', 'air')
# ('astatine, in ground', 'natural resource')
# ('asulam', 'soil')
# ('atrazine', 'air')
# ('atrazine', 'soil')
# ('atrazine', 'water')
# ('azaconazol', 'soil')
# ('azadirachtin', 'soil')
# ('azinphos-methyl', 'soil')
# ('aziprotryne', 'soil')
# ('azoxystrobin', 'air')
# ('azoxystrobin', 'soil')
# ('barite', 'water')
# ('barite, 15% in crude ore, in ground', 'natural resource')
# ('barium', 'air')
# ('barium', 'soil')
# ('barium', 'water')
# ('barium sulfide', 'water')
# ('barium, in ground', 'natural resource')
# ('barium-140', 'air')
# ('barium-140', 'water')
# ('basalt, in ground', 'natural resource')
# ('benalaxyl', 'soil')
# ('benazolin', 'soil')
# ('benfluralin', 'soil')
# ('benomyl', 'soil')
# ('benoxacor', 'soil')
# ('bensulfuron methyl ester', 'soil')
# ('bensultap', 'soil')
# ('bentazone', 'air')
# ('bentazone', 'soil')
# ('bentazone', 'water')
# ('benthiavalicarb', 'soil')
# ('benthiavalicarb-isopropyl', 'soil')
# ('benz(a)anthracene', 'air')
# ('benz(a)anthracene', 'water')
# ('benzal chloride', 'air')
# ('benzal chloride', 'water')
# ('benzaldehyde', 'air')
# ('benzaldehyde', 'water')
# ('benzene', 'air')
# ('benzene', 'water')
# ('benzene, chloro-', 'water')
# ('benzene, dichloro', 'air')
# ('benzene, ethyl-', 'air')
# ('benzene, ethyl-', 'water')
# ('benzene, hexachloro-', 'air')
# ('benzene, hexachloro-', 'water')
# ('benzene, pentachloro-', 'air')
# ('benzene, pentachloro-', 'water')
# ('benzo(a)pyrene', 'air')
# ('benzo(a)pyrene', 'water')
# ('benzo(b)fluoranthene', 'air')
# ('benzo(b)fluoranthene', 'water')
# ('benzo(ghi)perylene', 'air')
# ('benzo(ghi)perylene', 'water')
# ('benzo(k)fluoranthene', 'air')
# ('benzo(k)fluoranthene', 'water')
# ('benzoic acid', 'soil')
# ('benzoximate', 'soil')
# ('benzthiazuron', 'soil')
# ('benzyl alcohol', 'water')
# ('beryllium', 'air')
# ('beryllium', 'soil')
# ('beryllium', 'water')
# ('beryllium, in ground', 'natural resource')
# ('beta-cypermethrin', 'soil')
# ('bicarbonate, ion', 'water')
# ('bifenox', 'soil')
# ('bifenthrin', 'soil')
# ('bismuth, in ground', 'natural resource')
# ('bisphenol a', 'water')
# ('bitertanol', 'soil')
# ('bod5, biological oxygen demand', 'water')
# ('borate', 'water')
# ('borax, in ground', 'natural resource')
# ('boric acid', 'air')
# ('boron', 'air')
# ('boron', 'soil')
# ('boron', 'water')
# ('boron carbide', 'air')
# ('boron carbide', 'water')
# ('boron trifluoride', 'air')
# ('boron, in ground', 'natural resource')
# ('boscalid', 'soil')
# ('bromacil', 'soil')
# ('bromate', 'water')
# ('bromide', 'water')
# ('bromine', 'air')
# ('bromine', 'soil')
# ('bromine', 'water')
# ('bromine, 0.23% in water', 'natural resource')
# ('bromine, in water', 'natural resource')
# ('bromofenoxim', 'soil')
# ('bromopropane', 'air')
# ('bromopropane', 'water')
# ('bromopropylate', 'soil')
# ('bromoxynil', 'air')
# ('bromoxynil', 'soil')
# ('bromoxynil', 'water')
# ('bromoxynil octanoate', 'soil')
# ('bromuconazole', 'soil')
# ('bupirimate', 'soil')
# ('buprofezin', 'soil')
# ('butadiene', 'air')
# ('butafenacil', 'soil')
# ('butane', 'air')
# ('butanol', 'air')
# ('butanol', 'water')
# ('butene', 'air')
# ('butene', 'water')
# ('butoxycarboxim', 'soil')
# ('butralin', 'soil')
# ('butyl acetate', 'air')
# ('butyl acetate', 'water')
# ('butylcarbamate, iodopropynyl', 'air')
# ('butylcarbamate, iodopropynyl', 'water')
# ('butyrolactone', 'air')
# ('butyrolactone', 'water')
# ('cadmium', 'air')
# ('cadmium', 'soil')
# ('cadmium, 0.30% in sulfide, cd 0.18%, pb, zn, ag, in, in ground', 'natural resource')
# ('cadmium, in ground', 'natural resource')
# ('cadmium, ion', 'water')
# ('cadmium-109', 'water')
# ('caesium, in ground', 'natural resource')
# ('calcite, in ground', 'natural resource')
# ('calcium', 'air')
# ('calcium', 'soil')
# ('calcium cyanamide', 'soil')
# ('calcium hydroxide', 'air')
# ('calcium, in ground', 'natural resource')
# ('calcium, ion', 'water')
# ('captan', 'soil')
# ('carbaryl', 'air')
# ('carbaryl', 'soil')
# ('carbaryl', 'water')
# ('carbendazim', 'soil')
# ('carbetamide', 'soil')
# ('carbofuran', 'soil')
# ('carbon', 'soil')
# ('carbon dioxide, fossil', 'air')
# ('carbon dioxide, from soil or biomass stock', 'air')
# ('carbon dioxide, in air', 'natural resource')
# ('carbon dioxide, non-fossil', 'air')
# ('carbon dioxide, non-fossil, from calcination', 'air')
# ('carbon dioxide, to soil or biomass stock', 'soil')
# ('carbon disulfide', 'air')
# ('carbon disulfide', 'water')
# ('carbon monoxide, fossil', 'air')
# ('carbon monoxide, from soil or biomass stock', 'air')
# ('carbon monoxide, non-fossil', 'air')
# ('carbon, organic, in soil or biomass stock', 'natural resource')
# ('carbon-14', 'air')
# ('carbon-14', 'water')
# ('carbonate', 'water')
# ('carbonyl sulfide', 'air')
# ('carbosulfan', 'soil')
# ('carboxin', 'soil')
# ('carboxylic acids, unspecified', 'water')
# ('carfentrazone ethyl ester', 'soil')
# ('carfentrazone-ethyl', 'air')
# ('carfentrazone-ethyl', 'soil')
# ('carnallite', 'natural resource')
# ('cerium, 24% in bastnasite, 2.4% in crude ore, in ground', 'natural resource')
# ('cerium, in ground', 'natural resource')
# ('cerium-141', 'air')
# ('cerium-141', 'water')
# ('cerium-144', 'air')
# ('cerium-144', 'water')
# ('cesium', 'water')
# ('cesium-134', 'air')
# ('cesium-134', 'water')
# ('cesium-136', 'water')
# ('cesium-137', 'air')
# ('cesium-137', 'water')
# ('chloramine', 'air')
# ('chloramine', 'water')
# ('chlorate', 'water')
# ('chlorbromuron', 'soil')
# ('chlorbufam', 'soil')
# ('chlorfenvinphos', 'soil')
# ('chloridazon', 'soil')
# ('chloride', 'soil')
# ('chloride', 'water')
# ('chloride, ion', 'water')
# ('chlorides, unspecified', 'water')
# ('chlorimuron-ethyl', 'air')
# ('chlorimuron-ethyl', 'soil')
# ('chlorinated solvents, unspecified', 'air')
# ('chlorinated solvents, unspecified', 'water')
# ('chlorine', 'air')
# ('chlorine', 'soil')
# ('chlorine', 'water')
# ('chlormequat', 'soil')
# ('chlormequat chloride', 'soil')
# ('chloroacetic acid', 'air')
# ('chloroacetic acid', 'water')
# ('chloroacetyl chloride', 'water')
# ('chloroform', 'air')
# ('chloroform', 'water')
# ('chloropicrin', 'soil')
# ('chlorosilane, trimethyl-', 'air')
# ('chlorosilane, trimethyl-', 'water')
# ('chlorosulfonic acid', 'air')
# ('chlorosulfonic acid', 'water')
# ('chlorothalonil', 'soil')
# ('chlorotoluron', 'soil')
# ('chlorpyrifos', 'air')
# ('chlorpyrifos', 'soil')
# ('chlorpyrifos methyl', 'soil')
# ('chlorsulfuron', 'soil')
# ('chlorthal', 'soil')
# ('chlozolinate', 'soil')
# ('choline chloride', 'soil')
# ('chromium', 'air')
# ('chromium', 'soil')
# ('chromium iv', 'air')
# ('chromium vi', 'air')
# ('chromium vi', 'soil')
# ('chromium vi', 'water')
# ('chromium, 25.5% in chromite, 11.6% in crude ore, in ground', 'natural resource')
# ('chromium, in ground', 'natural resource')
# ('chromium, ion', 'water')
# ('chromium-51', 'air')
# ('chromium-51', 'water')
# ('chrysene', 'air')
# ('chrysene', 'water')
# ('chrysotile, in ground', 'natural resource')
# ('cinidon-ethyl', 'soil')
# ('cinnabar, in ground', 'natural resource')
# ('clay, bentonite, in ground', 'natural resource')
# ('clay, unspecified, in ground', 'natural resource')
# ('clethodim', 'air')
# ('clethodim', 'soil')
# ('clodinafop-propargyl', 'soil')
# ('clofentezine', 'soil')
# ('clomazone', 'soil')
# ('clopyralid', 'soil')
# ('cloquintocet-mexyl', 'soil')
# ('cloransulam-methyl', 'air')
# ('cloransulam-methyl', 'soil')
# ('clothianidin', 'soil')
# ('coal, brown, in ground', 'natural resource')
# ('coal, hard, unspecified, in ground', 'natural resource')
# ('cobalt', 'air')
# ('cobalt', 'soil')
# ('cobalt', 'water')
# ('cobalt, co 5.0e-2%, in mixed ore, in ground', 'natural resource')
# ('cobalt, in ground', 'natural resource')
# ('cobalt-57', 'air')
# ('cobalt-57', 'water')
# ('cobalt-58', 'air')
# ('cobalt-58', 'water')
# ('cobalt-60', 'air')
# ('cobalt-60', 'water')
# ('cod, chemical oxygen demand', 'water')
# ('colemanite, in ground', 'natural resource')
# ('copper', 'air')
# ('copper', 'soil')
# ('copper, 0.52% in sulfide, cu 0.27% and mo 8.2e-3% in crude ore, in ground', 'natural resource')
# ('copper, 0.59% in sulfide, cu 0.22% and mo 8.2e-3% in crude ore, in ground', 'natural resource')
# ('copper, 0.97% in sulfide, cu 0.36% and mo 4.1e-2% in crude ore, in ground', 'natural resource')
# ('copper, 0.99% in sulfide, cu 0.36% and mo 8.2e-3% in crude ore, in ground', 'natural resource')
# ('copper, 1.13% in sulfide, cu 0.76% and ni 0.76% in crude ore, in ground', 'natural resource')
# ('copper, 1.18% in sulfide, cu 0.39% and mo 8.2e-3% in crude ore, in ground', 'natural resource')
# ('copper, 1.25% in sulfide, cu 0.24% and zn 0,1% in crude ore, in ground', 'natural resource')
# ('copper, 1.42% in sulfide, cu 0.81% and mo 8.2e-3% in crude ore, in ground', 'natural resource')
# ('copper, 2.19% in sulfide, cu 1.83% and mo 8.2e-3% in crude ore, in ground', 'natural resource')
# ('copper, cu 0.2%, in mixed ore, in ground', 'natural resource')
# ('copper, cu 0.38%, in mixed ore, in ground', 'natural resource')
# ('copper, cu 6.8e-1%, in mixed ore, in ground', 'natural resource')
# ('copper, in ground', 'natural resource')
# ('copper, ion', 'water')
# ('cu, cu 3.2e+0%, pt 2.5e-4%, pd 7.3e-4%, rh 2.0e-5%, ni 2.3e+0% in ore, in ground', 'natural resource')
# ('cu, cu 5.2e-2%, pt 4.8e-4%, pd 2.0e-4%, rh 2.4e-5%, ni 3.7e-2% in ore, in ground', 'natural resource')
# ('cu-hdo', 'water')
# ('cumene', 'air')
# ('cumene', 'water')
# ('curium alpha', 'air')
# ('curium alpha', 'water')
# ('curium-242', 'air')
# ('curium-244', 'air')
# ('cyanamide', 'soil')
# ('cyanazine', 'soil')
# ('cyanide', 'air')
# ('cyanide', 'water')
# ('cyanoacetic acid', 'air')
# ('cyazofamid', 'soil')
# ('cyclanilide', 'soil')
# ('cyclohexane', 'air')
# ('cyclohexane', 'water')
# ('cyclohexane (for all cycloalkanes)', 'air')
# ('cyclopentane', 'air')
# ('cycloxydim', 'soil')
# ('cycluron', 'soil')
# ('cyfluthrin', 'air')
# ('cyfluthrin', 'soil')
# ('cyhalothrin', 'soil')
# ('cyhalothrin, gamma-', 'air')
# ('cyhalothrin, gamma-', 'soil')
# ('cyhexatin', 'soil')
# ('cymoxanil', 'soil')
# ('cypermethrin', 'air')
# ('cypermethrin', 'soil')
# ('cyproconazole', 'soil')
# ('cyprodinil', 'soil')
# ('cyromazine', 'soil')
# ('daminozide', 'soil')
# ('dazomet', 'soil')
# ('decanoic acid', 'water')
# ('deltamethrin', 'soil')
# ('demeton-s-methylsulfon', 'soil')
# ('desmedipham', 'soil')
# ('diafenthiuron', 'soil')
# ('dialifor', 'soil')
# ('diatomite, in ground', 'natural resource')
# ('diazinon', 'soil')
# ('dibenz(a,h)anthracene', 'air')
# ('dibenz(a,h)anthracene', 'water')
# ('diborane', 'air')
# ('diborane', 'water')
# ('dibutyltin', 'water')
# ('dicamba', 'air')
# ('dicamba', 'soil')
# ('dicamba', 'water')
# ('dichlobenil', 'soil')
# ('dichlofluanid', 'soil')
# ('dichlorodimethylsilane', 'air')
# ('dichlorprop', 'air')
# ('dichlorprop', 'soil')
# ('dichlorprop', 'water')
# ('dichlorprop-p', 'soil')
# ('dichlorvos', 'soil')
# ('dichromate', 'water')
# ('diclofop', 'soil')
# ('diclofop-methyl', 'soil')
# ('dicofol', 'soil')
# ('dicrotophos', 'soil')
# ('dienochlor', 'soil')
# ('diethanolamine', 'water')
# ('diethofencarb', 'soil')
# ('diethyl ether', 'air')
# ('diethylamine', 'air')
# ('diethylamine', 'water')
# ('diethylene glycol', 'air')
# ('diethylene glycol', 'water')
# ('difenoconazole', 'soil')
# ('diflubenzuron', 'air')
# ('diflubenzuron', 'soil')
# ('diflufenican', 'soil')
# ('diflufenzopyr-sodium', 'soil')
# ('diisobutyl ketone', 'water')
# ('dimefuron', 'soil')
# ('dimethachlor', 'soil')
# ('dimethenamid', 'air')
# ('dimethenamid', 'soil')
# ('dimethenamid', 'water')
# ('dimethenamid-p', 'soil')
# ('dimethipin', 'soil')
# ('dimethoate', 'soil')
# ('dimethomorph', 'soil')
# ('dimethyl carbonate', 'air')
# ('dimethyl ether', 'air')
# ('dimethyl ether', 'water')
# ('dimethyl hexanediol', 'water')
# ('dimethyl hexynediol', 'water')
# ('dimethyl malonate', 'air')
# ('dimethylamine', 'air')
# ('dimethylamine', 'water')
# ('dimethyldichlorosilane', 'air')
# ('dimethyldichlorosilane', 'water')
# ('dinitrogen monoxide', 'air')
# ('dinitrogen tetroxide', 'air')
# ('dinocap', 'soil')
# ('dinoseb', 'soil')
# ('diofenolan', 'soil')
# ('dioxins, measured as 2,3,7,8-tetrachlorodibenzo-p-dioxin', 'air')
# ('dioxins, measured as 2,3,7,8-tetrachlorodibenzo-p-dioxin', 'soil')
# ('dioxins, measured as 2,3,7,8-tetrachlorodibenzo-p-dioxin', 'water')
# ('diphenylether-compound', 'water')
# ('diphenyltin', 'water')
# ('dipropylamine', 'air')
# ('dipropylamine', 'water')
# ('diquat', 'soil')
# ('diquat dibromide', 'soil')
# ('discarded fish, demersal, to ocean', 'water')
# ('discarded fish, pelagic, to ocean', 'water')
# ('disinfectants, unspecified', 'water')
# ('dissolved solids', 'water')
# ('disulfoton', 'soil')
# ('dithianon', 'soil')
# ('diuron', 'soil')
# ('dnoc', 'soil')
# ('doc, dissolved organic carbon', 'water')
# ('dodecanol', 'water')
# ('dodemorph', 'soil')
# ('dodine', 'soil')
# ('dolomite, in ground', 'natural resource')
# ('dsma', 'soil')
# ('dysprosium, in ground', 'natural resource')
# ('elemental carbon', 'air')
# ('elemental carbon', 'soil')
# ('elemental carbon', 'water')
# ('endosulfan', 'soil')
# ('endothall', 'soil')
# ('energy, geothermal, converted', 'natural resource')
# ('energy, gross calorific value, in biomass', 'natural resource')
# ('energy, gross calorific value, in biomass, primary forest', 'natural resource')
# ('energy, kinetic (in wind), converted', 'natural resource')
# ('energy, potential (in hydropower reservoir), converted', 'natural resource')
# ('energy, solar, converted', 'natural resource')
# ('epichlorohydrin', 'air')
# ('epichlorohydrin', 'water')
# ('epoxiconazole', 'soil')
# ('eptc', 'soil')
# ('erbium, in ground', 'natural resource')
# ('esfenvalerate', 'air')
# ('esfenvalerate', 'soil')
# ('ethalfluralin', 'soil')
# ('ethane', 'air')
# ('ethane thiol', 'air')
# ('ethane, 1,1,1,2-tetrafluoro-, hfc-134a', 'air')
# ('ethane, 1,1,1-trichloro-, hcfc-140', 'air')
# ('ethane, 1,1,1-trichloro-, hcfc-140', 'water')
# ('ethane, 1,1,1-trifluoro-, hfc-143a', 'air')
# ('ethane, 1,1,2-trichloro-', 'air')
# ('ethane, 1,1,2-trichloro-1,2,2-trifluoro-, cfc-113', 'air')
# ('ethane, 1,1-dichloro-1-fluoro-, hcfc-141b', 'air')
# ('ethane, 1,1-difluoro-, hfc-152a', 'air')
# ('ethane, 1,2-dichloro-', 'air')
# ('ethane, 1,2-dichloro-', 'water')
# ('ethane, 1,2-dichloro-1,1,2,2-tetrafluoro-, cfc-114', 'air')
# ('ethane, 1-chloro-1,1-difluoro-, hcfc-142b', 'air')
# ('ethane, 2,2-dichloro-1,1,1-trifluoro-, hcfc-123', 'air')
# ('ethane, 2-chloro-1,1,1,2-tetrafluoro-, hcfc-124', 'air')
# ('ethane, chloropentafluoro-, cfc-115', 'air')
# ('ethane, hexachloro-', 'water')
# ('ethane, hexafluoro-, hfc-116', 'air')
# ('ethane, pentafluoro-, hfc-125', 'air')
# ('ethanol', 'air')
# ('ethanol', 'water')
# ('ethene', 'air')
# ('ethene', 'water')
# ('ethene, chloro-', 'air')
# ('ethene, chloro-', 'water')
# ('ethene, tetrachloro-', 'air')
# ('ethene, tetrachloro-', 'water')
# ('ethene, trichloro-', 'air')
# ('ethene, trichloro-', 'water')
# ('ethephon', 'air')
# ('ethephon', 'soil')
# ('ethephon', 'water')
# ('ethiofencarb', 'soil')
# ('ethofumesate', 'soil')
# ('ethoprop', 'soil')
# ('ethyl acetate', 'air')
# ('ethyl acetate', 'water')
# ('ethyl cellulose', 'air')
# ('ethylamine', 'air')
# ('ethylamine', 'water')
# ('ethylene', 'air')
# ('ethylene diamine', 'air')
# ('ethylene diamine', 'water')
# ('ethylene glycol monoethyl ether', 'air')
# ('ethylene glycol monoethyl ether', 'water')
# ('ethylene oxide', 'air')
# ('ethylene oxide', 'water')
# ('ethyne', 'air')
# ('etoxazole', 'soil')
# ('etridiazole', 'soil')
# ('europium, 0.06% in bastnasite, 0.006% in crude ore, in ground', 'natural resource')
# ('europium, in ground', 'natural resource')
# ('expenditures on primary production factors', 'economic')
# ('famoxadone', 'soil')
# ('feldspar, in ground', 'natural resource')
# ('fenamidone', 'soil')
# ('fenamiphos', 'soil')
# ('fenazaquin', 'soil')
# ('fenbuconazole', 'soil')
# ('fenbutatin oxide', 'soil')
# ('fenfuram', 'soil')
# ('fenhexamid', 'soil')
# ('fenitrothion', 'soil')
# ('fenoxaprop', 'air')
# ('fenoxaprop', 'soil')
# ('fenoxaprop ethyl ester', 'soil')
# ('fenoxaprop-p ethyl ester', 'soil')
# ('fenoxycarb', 'soil')
# ('fenpiclonil', 'soil')
# ('fenpropathrin', 'soil')
# ('fenpropidin', 'soil')
# ('fenpropimorph', 'soil')
# ('fenpyroximate', 'soil')
# ('fentin acetate', 'soil')
# ('fentin hydroxide', 'soil')
# ('fipronil', 'soil')
# ('fish, demersal, in ocean', 'natural resource')
# ('fish, pelagic, in ocean', 'natural resource')
# ('flazasulfuron', 'soil')
# ('florasulam', 'soil')
# ('fluazifop', 'soil')
# ('fluazifop-p-butyl', 'air')
# ('fluazifop-p-butyl', 'soil')
# ('fluazinam', 'soil')
# ('flucarbazone sodium salt', 'soil')
# ('fludioxonil', 'soil')
# ('flufenacet', 'air')
# ('flufenacet', 'soil')
# ('flumetsulam', 'air')
# ('flumetsulam', 'soil')
# ('flumiclorac-pentyl', 'air')
# ('flumiclorac-pentyl', 'soil')
# ('flumioxazin', 'air')
# ('flumioxazin', 'soil')
# ('fluoboric acid', 'water')
# ('fluometuron', 'soil')
# ('fluoranthene', 'air')
# ('fluoranthene', 'water')
# ('fluorene', 'air')
# ('fluorene', 'water')
# ('fluoride', 'soil')
# ('fluoride', 'water')
# ('fluorine', 'air')
# ('fluorine, 4.5% in apatite, 1% in crude ore, in ground', 'natural resource')
# ('fluorine, 4.5% in apatite, 3% in crude ore, in ground', 'natural resource')
# ('fluorine, in ground', 'natural resource')
# ('fluorochloridone', 'soil')
# ('fluoroglycofen', 'soil')
# ('fluoroglycofen-ethyl', 'soil')
# ('fluorspar, 92%, in ground', 'natural resource')
# ('fluorspar, in ground', 'natural resource')
# ('fluosilicic acid', 'air')
# ('fluosilicic acid', 'water')
# ('flupyrsulfuron-methyl', 'soil')
# ('fluquinconazole', 'soil')
# ('flurenol', 'soil')
# ('flurochloridone', 'soil')
# ('fluroxypyr', 'soil')
# ('flurtamone', 'soil')
# ('flusilazole', 'soil')
# ('flutolanil', 'soil')
# ('folpet', 'soil')
# ('fomesafen', 'air')
# ('fomesafen', 'soil')
# ('fonofos', 'soil')
# ('foramsulfuron', 'soil')
# ('formaldehyde', 'air')
# ('formaldehyde', 'water')
# ('formamide', 'air')
# ('formamide', 'water')
# ('formate', 'water')
# ('formic acid', 'air')
# ('formic acid', 'water')
# ('fosetyl', 'soil')
# ('fosetyl-aluminium', 'soil')
# ('fresh water (obsolete)', 'water')
# ('fuberidazole', 'soil')
# ('fungicides, unspecified', 'soil')
# ('fungicides, unspecified', 'water')
# ('furalaxyl', 'soil')
# ('furan', 'air')
# ('furathiocarb', 'soil')
# ('furfural', 'air')
# ('gadolinium, 0.15% in bastnasite, 0.015% in crude ore, in ground', 'natural resource')
# ('gadolinium, in ground', 'natural resource')
# ('gallium, 0.014% in bauxite, in ground', 'natural resource')
# ('gallium, in ground', 'natural resource')
# ('gangue, bauxite, in ground', 'natural resource')
# ('gangue, in ground', 'natural resource')
# ('gas, mine, off-gas, process, coal mining', 'natural resource')
# ('gas, natural, in ground', 'natural resource')
# ('germanium, in ground', 'natural resource')
# ('glucose', 'water')
# ('glufosinate', 'soil')
# ('glufosinate ammonium', 'soil')
# ('glutaraldehyde', 'water')
# ('glyphosate', 'air')
# ('glyphosate', 'soil')
# ('glyphosate', 'water')
# ('gold', 'water')
# ('gold, au 1.0e-7%, in mixed ore, in ground', 'natural resource')
# ('gold, au 1.1e-4%, ag 4.2e-3%, in ore, in ground', 'natural resource')
# ('gold, au 1.3e-4%, ag 4.6e-5%, in ore, in ground', 'natural resource')
# ('gold, au 1.4e-4%, in ore, in ground', 'natural resource')
# ('gold, au 1.8e-4%, in mixed ore, in ground', 'natural resource')
# ('gold, au 2.1e-4%, ag 2.1e-4%, in ore, in ground', 'natural resource')
# ('gold, au 4.3e-4%, in ore, in ground', 'natural resource')
# ('gold, au 4.9e-5%, in ore, in ground', 'natural resource')
# ('gold, au 5.4e-4%, ag 1.5e-5%, in ore, in ground', 'natural resource')
# ('gold, au 6.7e-4%, in ore, in ground', 'natural resource')
# ('gold, au 6.8e-4%, ag 1.5e-4%, in ore, in ground', 'natural resource')
# ('gold, au 7.1e-4%, in ore, in ground', 'natural resource')
# ('gold, au 9.7e-4%, in mixed ore, in ground', 'natural resource')
# ('gold, au 9.7e-5%, ag 7.6e-5%, in ore, in ground', 'natural resource')
# ('gold, in ground', 'natural resource')
# ('granite, in ground', 'natural resource')
# ('gravel, in ground', 'natural resource')
# ('guazatine', 'soil')
# ('gypsum, in ground', 'natural resource')
# ('hafnium, in ground', 'natural resource')
# ('halosulfuron-methyl', 'soil')
# ('haloxyfop- (r) methylester', 'soil')
# ('haloxyfop-p-methyl', 'soil')
# ('heat, waste', 'air')
# ('heat, waste', 'soil')
# ('heat, waste', 'water')
# ('helium', 'air')
# ('helium, 0.08% in natural gas, in ground', 'natural resource')
# ('helium, in natural gas, in ground', 'natural resource')
# ('heptane', 'air')
# ('heptenophos', 'soil')
# ('herbicides, unspecified', 'soil')
# ('herbicides, unspecified', 'water')
# ('hexaconazole', 'soil')
# ('hexaflumuron', 'soil')
# ('hexamethyldisilizane', 'air')
# ('hexane', 'air')
# ('hexane', 'water')
# ('hexazinone', 'soil')
# ('hexythiazox', 'soil')
# ('holmium, in ground', 'natural resource')
# ('hydramethylnon', 'soil')
# ('hydrazine', 'water')
# ('hydrocarbons, aliphatic, alkanes, cyclic', 'air')
# ('hydrocarbons, aliphatic, alkanes, unspecified', 'air')
# ('hydrocarbons, aliphatic, alkanes, unspecified', 'water')
# ('hydrocarbons, aliphatic, unsaturated', 'air')
# ('hydrocarbons, aliphatic, unsaturated', 'water')
# ('hydrocarbons, aromatic', 'air')
# ('hydrocarbons, aromatic', 'water')
# ('hydrocarbons, chlorinated', 'air')
# ('hydrocarbons, unspecified', 'air')
# ('hydrocarbons, unspecified', 'soil')
# ('hydrocarbons, unspecified', 'water')
# ('hydrochloric acid', 'air')
# ('hydrochloric acid', 'water')
# ('hydrogen', 'air')
# ('hydrogen carbonate', 'water')
# ('hydrogen chloride', 'air')
# ('hydrogen fluoride', 'air')
# ('hydrogen peroxide', 'air')
# ('hydrogen peroxide', 'water')
# ('hydrogen sulfide', 'air')
# ('hydrogen sulfide', 'water')
# ('hydrogen-3, tritium', 'air')
# ('hydrogen-3, tritium', 'water')
# ('hydroxide', 'water')
# ('hymexazol', 'soil')
# ('hypochlorite', 'water')
# ('imazalil', 'soil')
# ('imazamox', 'air')
# ('imazamox', 'soil')
# ('imazapyr', 'soil')
# ('imazaquin', 'air')
# ('imazaquin', 'soil')
# ('imazethapyr', 'air')
# ('imazethapyr', 'soil')
# ('imidacloprid', 'soil')
# ('indeno(1,2,3-cd)pyrene', 'air')
# ('indeno(1,2,3-cd)pyrene', 'water')
# ('indium, 0.005% in sulfide, in 0.003%, pb, zn, ag, cd, in ground', 'natural resource')
# ('indium, in ground', 'natural resource')
# ('indoxacarb', 'soil')
# ('insecticides, unspecified', 'soil')
# ('insecticides, unspecified', 'water')
# ('iodide', 'soil')
# ('iodide', 'water')
# ('iodine', 'air')
# ('iodine, 0.03% in water', 'natural resource')
# ('iodine, in water', 'natural resource')
# ('iodine-129', 'air')
# ('iodine-129', 'water')
# ('iodine-131', 'air')
# ('iodine-131', 'water')
# ('iodine-133', 'air')
# ('iodine-133', 'water')
# ('iodine-135', 'air')
# ('iodosulfuron', 'soil')
# ('iodosulfuron-methyl-sodium', 'soil')
# ('ioxynil', 'soil')
# ('ioxynil methyl ester', 'soil')
# ('iprodion', 'soil')
# ('iprovalicarb', 'soil')
# ('iridium, in ground', 'natural resource')
# ('iron', 'air')
# ('iron', 'soil')
# ('iron', 'water')
# ('iron, 46% in ore, 25% in crude ore, in ground', 'natural resource')
# ('iron, 72% in magnetite, 14% in crude ore, in ground', 'natural resource')
# ('iron, in ground', 'natural resource')
# ('iron, ion', 'water')
# ('iron-59', 'air')
# ('iron-59', 'water')
# ('isobutane', 'air')
# ('isocyanic acid', 'air')
# ('isoprene', 'air')
# ('isopropylamine', 'air')
# ('isopropylamine', 'water')
# ('isoproturon', 'soil')
# ('isoxadifen-ethyl', 'soil')
# ('isoxaflutole', 'soil')
# ('kaolin', 'soil')
# ('kaolinite, 24% in crude ore, in ground', 'natural resource')
# ('kaolinite, in ground', 'natural resource')
# ('kieserite, 25% in crude ore, in ground', 'natural resource')
# ('kieserite, in ground', 'natural resource')
# ('kresoxim-methyl', 'soil')
# ('krypton, in air', 'natural resource')
# ('krypton-85', 'air')
# ('krypton-85', 'water')
# ('krypton-85m', 'air')
# ('krypton-87', 'air')
# ('krypton-88', 'air')
# ('krypton-89', 'air')
# ('labour cost', 'economic')
# ('lactic acid', 'air')
# ('lactic acid', 'water')
# ('lactofen', 'air')
# ('lactofen', 'soil')
# ('lambda-cyhalothrin', 'air')
# ('lambda-cyhalothrin', 'soil')
# ('lambda-cyhalothrin', 'water')
# ('lanthanum', 'air')
# ('lanthanum, 7.2% in bastnasite, 0.72% in crude ore, in ground', 'natural resource')
# ('lanthanum, in ground', 'natural resource')
# ('lanthanum-140', 'air')
# ('lanthanum-140', 'water')
# ('laterite, in ground', 'natural resource')
# ('lauric acid', 'air')
# ('lauric acid', 'water')
# ('lead', 'air')
# ('lead', 'soil')
# ('lead', 'water')
# ('lead, 5.0% in sulfide, pb 3.0%, zn, ag, cd, in, in ground', 'natural resource')
# ('lead, in ground', 'natural resource')
# ('lead, pb 0.014%, in mixed ore, in ground', 'natural resource')
# ('lead, pb 3.6e-1%, in mixed ore, in ground', 'natural resource')
# ('lead-210', 'air')
# ('lead-210', 'water')
# ('lenacil', 'soil')
# ('lindane', 'soil')
# ('linuron', 'soil')
# ('lithium', 'air')
# ('lithium', 'soil')
# ('lithium', 'water')
# ('lithium carbonate', 'air')
# ('lithium, 0.15% in brine, in ground', 'natural resource')
# ('lithium, in ground', 'natural resource')
# ('lithium, ion', 'water')
# ('lufenuron', 'soil')
# ('lutetium, in ground', 'natural resource')
# ('m-xylene', 'air')
# ('m-xylene', 'water')
# ('magnesite, 60% in crude ore, in ground', 'natural resource')
# ('magnesite, in ground', 'natural resource')
# ('magnesium', 'air')
# ('magnesium', 'soil')
# ('magnesium', 'water')
# ('magnesium phosphide', 'soil')
# ('magnesium, 0.13% in water', 'natural resource')
# ('magnesium, in ground', 'natural resource')
# ('magnesium, in water', 'natural resource')
# ('malathion', 'soil')
# ('maleic anhydride', 'water')
# ('maleic hydrazide', 'soil')
# ('mancozeb', 'soil')
# ('mandipropamid', 'soil')
# ('maneb', 'soil')
# ('manganese', 'air')
# ('manganese', 'soil')
# ('manganese', 'water')
# ('manganese, 35.7% in sedimentary deposit, 14.2% in crude ore, in ground', 'natural resource')
# ('manganese, in ground', 'natural resource')
# ('manganese-54', 'air')
# ('manganese-54', 'water')
# ('manganese-55', 'water')
# ('mcpa', 'air')
# ('mcpa', 'soil')
# ('mcpa', 'water')
# ('mcpb', 'air')
# ('mcpb', 'soil')
# ('mcpb', 'water')
# ('mecoprop', 'soil')
# ('mecoprop-p', 'soil')
# ('mefenpyr', 'soil')
# ('mefenpyr-diethyl', 'soil')
# ('mepanipyrim', 'soil')
# ('mepiquat chloride', 'soil')
# ('mepronil', 'soil')
# ('mercury', 'air')
# ('mercury', 'soil')
# ('mercury', 'water')
# ('mercury, in ground', 'natural resource')
# ('mesosulfuron', 'soil')
# ('mesosulfuron-methyl (prop)', 'soil')
# ('mesotrione', 'soil')
# ('metalaxil', 'soil')
# ('metalaxyl-m', 'soil')
# ('metaldehyde', 'soil')
# ('metam-sodium', 'soil')
# ('metamitron', 'soil')
# ('metamorphous rock, graphite containing, in ground', 'natural resource')
# ('metazachlor', 'soil')
# ('metconazole', 'soil')
# ('methabenzthiazuron', 'soil')
# ('methamidophos', 'soil')
# ('methane', 'air')
# ('methane, bromo-, halon 1001', 'air')
# ('methane, bromochlorodifluoro-, halon 1211', 'air')
# ('methane, bromotrifluoro-, halon 1301', 'air')
# ('methane, chloro-fluoro-, hcfc-31', 'air')
# ('methane, chlorodifluoro-, hcfc-22', 'air')
# ('methane, chlorotrifluoro-, cfc-13', 'air')
# ('methane, dichloro-, hcc-30', 'air')
# ('methane, dichloro-, hcc-30', 'water')
# ('methane, dichlorodifluoro-, cfc-12', 'air')
# ('methane, dichlorofluoro-, hcfc-21', 'air')
# ('methane, dichlorofluoro-, hcfc-21', 'water')
# ('methane, difluoro-, hfc-32', 'air')
# ('methane, fossil', 'air')
# ('methane, from soil or biomass stock', 'air')
# ('methane, monochloro-, r-40', 'air')
# ('methane, non-fossil', 'air')
# ('methane, tetrachloro-, r-10', 'air')
# ('methane, tetrachloro-, r-10', 'water')
# ('methane, tetrafluoro-, r-14', 'air')
# ('methane, trichlorofluoro-, cfc-11', 'air')
# ('methane, trifluoro-, hfc-23', 'air')
# ('methanesulfonic acid', 'air')
# ('methanol', 'air')
# ('methanol', 'water')
# ('methidathion', 'soil')
# ('methiocarb', 'soil')
# ('methomyl', 'air')
# ('methomyl', 'soil')
# ('methomyl', 'water')
# ('methoprene', 'soil')
# ('methoxyfenozide', 'soil')
# ('methyl acetate', 'air')
# ('methyl acetate', 'water')
# ('methyl acrylate', 'air')
# ('methyl acrylate', 'water')
# ('methyl amine', 'air')
# ('methyl amine', 'water')
# ('methyl borate', 'air')
# ('methyl borate', 'water')
# ('methyl ethyl ketone', 'air')
# ('methyl ethyl ketone', 'water')
# ('methyl formate', 'air')
# ('methyl formate', 'water')
# ('methyl lactate', 'air')
# ('methyl parathion', 'air')
# ('methyl parathion', 'soil')
# ('methyl pentane', 'water')
# ('methylamine', 'air')
# ('metiram', 'soil')
# ('metobromuron', 'soil')
# ('metolachlor', 'air')
# ('metolachlor', 'soil')
# ('metolachlor', 'water')
# ('metosulam', 'soil')
# ('metribuzin', 'air')
# ('metribuzin', 'soil')
# ('metsulfuron-methyl', 'soil')
# ('mevinfos', 'soil')
# ('mineral oil', 'soil')
# ('molinate', 'soil')
# ('molybdenum', 'air')
# ('molybdenum', 'soil')
# ('molybdenum', 'water')
# ('molybdenum, 0.010% in sulfide, mo 8.2e-3% and cu 1.83% in crude ore, in ground', 'natural resource')
# ('molybdenum, 0.014% in sulfide, mo 8.2e-3% and cu 0.81% in crude ore, in ground', 'natural resource')
# ('molybdenum, 0.016% in sulfide, mo 8.2e-3% and cu 0.27% in crude ore, in ground', 'natural resource')
# ('molybdenum, 0.022% in sulfide, mo 8.2e-3% and cu 0.22% in crude ore, in ground', 'natural resource')
# ('molybdenum, 0.022% in sulfide, mo 8.2e-3% and cu 0.36% in crude ore, in ground', 'natural resource')
# ('molybdenum, 0.025% in sulfide, mo 8.2e-3% and cu 0.39% in crude ore, in ground', 'natural resource')
# ('molybdenum, 0.11% in sulfide, mo 4.1e-2% and cu 0.36% in crude ore, in ground', 'natural resource')
# ('molybdenum, in ground', 'natural resource')
# ('molybdenum-99', 'water')
# ('monobutyltin', 'water')
# ('monochloroethane', 'air')
# ('monochloroethane', 'water')
# ('monocrotophos', 'soil')
# ('monoethanolamine', 'air')
# ('monoethanolamine', 'water')
# ('monolinuron', 'soil')
# ('monophenyltin', 'water')
# ('msma', 'soil')
# ('myclobutanil', 'soil')
# ('n-bromoacetamide', 'air')
# ('naled', 'soil')
# ('naphtalene', 'air')
# ('naphtalene', 'water')
# ('naphthalene', 'air')
# ('napropamide', 'soil')
# ('neburon', 'soil')
# ('neodymium, 4% in bastnasite, 0.4% in crude ore, in ground', 'natural resource')
# ('neodymium, in ground', 'natural resource')
# ('neptunium-237', 'air')
# ('neptunium-237', 'water')
# ('net operating surplus', 'economic')
# ('net tax', 'economic')
# ('ni, ni 2.3e+0%, pt 2.5e-4%, pd 7.3e-4%, rh 2.0e-5%, cu 3.2e+0% in ore, in ground', 'natural resource')
# ('ni, ni 3.7e-2%, pt 4.8e-4%, pd 2.0e-4%, rh 2.4e-5%, cu 5.2e-2% in ore, in ground', 'natural resource')
# ('nickel', 'air')
# ('nickel', 'soil')
# ('nickel', 'water')
# ('nickel, 1.13% in sulfide, ni 0.76% and cu 0.76% in crude ore, in ground', 'natural resource')
# ('nickel, 1.98% in silicates, 1.04% in crude ore, in ground', 'natural resource')
# ('nickel, in ground', 'natural resource')
# ('nickel, ion', 'water')
# ('nickel, ni 2.5e+0%, in mixed ore, in ground', 'natural resource')
# ('nicosulfuron', 'soil')
# ('niobium, in ground', 'natural resource')
# ('niobium-95', 'air')
# ('niobium-95', 'water')
# ('nitrate', 'air')
# ('nitrate', 'soil')
# ('nitrate', 'water')
# ('nitric acid', 'soil')
# ('nitric oxide', 'air')
# ('nitrite', 'water')
# ('nitrobenzene', 'air')
# ('nitrobenzene', 'water')
# ('nitrogen', 'air')
# ('nitrogen', 'natural resource')
# ('nitrogen', 'soil')
# ('nitrogen', 'water')
# ('nitrogen dioxide', 'water')
# ('nitrogen fluoride', 'air')
# ('nitrogen oxides', 'air')
# ('nitrogen, organic bound', 'water')
# ('nitrothal-isopropyl', 'soil')
# ('nmvoc, non-methane volatile organic compounds, unspecified origin', 'air')
# ('noble gases, radioactive, unspecified', 'air')
# ('norflurazon', 'soil')
# ('novaluron', 'soil')
# ('o-dichlorobenzene', 'water')
# ('o-nitrotoluene', 'air')
# ('o-xylene', 'air')
# ('o-xylene', 'water')
# ('occupation, annual crop', 'natural resource')
# ('occupation, annual crop, flooded crop', 'natural resource')
# ('occupation, annual crop, greenhouse', 'natural resource')
# ('occupation, annual crop, irrigated', 'natural resource')
# ('occupation, annual crop, irrigated, extensive', 'natural resource')
# ('occupation, annual crop, irrigated, intensive', 'natural resource')
# ('occupation, annual crop, non-irrigated', 'natural resource')
# ('occupation, annual crop, non-irrigated, extensive', 'natural resource')
# ('occupation, annual crop, non-irrigated, intensive', 'natural resource')
# ('occupation, arable land, unspecified use', 'natural resource')
# ('occupation, arable, conservation tillage (obsolete)', 'natural resource')
# ('occupation, arable, conventional tillage (obsolete)', 'natural resource')
# ('occupation, arable, reduced tillage (obsolete)', 'natural resource')
# ('occupation, bare area (non-use)', 'natural resource')
# ('occupation, construction site', 'natural resource')
# ('occupation, cropland fallow (non-use)', 'natural resource')
# ('occupation, dump site', 'natural resource')
# ('occupation, field margin/hedgerow', 'natural resource')
# ('occupation, forest, extensive', 'natural resource')
# ('occupation, forest, intensive', 'natural resource')
# ('occupation, forest, primary (non-use)', 'natural resource')
# ('occupation, forest, secondary (non-use)', 'natural resource')
# ('occupation, forest, unspecified', 'natural resource')
# ('occupation, grassland, natural (non-use)', 'natural resource')
# ('occupation, grassland, natural, for livestock grazing', 'natural resource')
# ('occupation, heterogeneous, agricultural', 'natural resource')
# ('occupation, industrial area', 'natural resource')
# ('occupation, inland waterbody, unspecified', 'natural resource')
# ('occupation, lake, artificial', 'natural resource')
# ('occupation, lake, natural (non-use)', 'natural resource')
# ('occupation, mineral extraction site', 'natural resource')
# ('occupation, pasture, man made', 'natural resource')
# ('occupation, pasture, man made, extensive', 'natural resource')
# ('occupation, pasture, man made, intensive', 'natural resource')
# ('occupation, permanent crop', 'natural resource')
# ('occupation, permanent crop, irrigated', 'natural resource')
# ('occupation, permanent crop, irrigated, extensive', 'natural resource')
# ('occupation, permanent crop, irrigated, intensive', 'natural resource')
# ('occupation, permanent crop, non-irrigated', 'natural resource')
# ('occupation, permanent crop, non-irrigated, extensive', 'natural resource')
# ('occupation, permanent crop, non-irrigated, intensive', 'natural resource')
# ('occupation, river, artificial', 'natural resource')
# ('occupation, river, natural (non-use)', 'natural resource')
# ('occupation, seabed, drilling and mining', 'natural resource')
# ('occupation, seabed, infrastructure', 'natural resource')
# ('occupation, seabed, natural (non-use)', 'natural resource')
# ('occupation, seabed, unspecified', 'natural resource')
# ('occupation, shrub land, sclerophyllous', 'natural resource')
# ('occupation, snow and ice (non-use)', 'natural resource')
# ('occupation, traffic area, rail network', 'natural resource')
# ('occupation, traffic area, rail/road embankment', 'natural resource')
# ('occupation, traffic area, road network', 'natural resource')
# ('occupation, unspecified', 'natural resource')
# ('occupation, unspecified, natural (non-use)', 'natural resource')
# ('occupation, urban, continuously built', 'natural resource')
# ('occupation, urban, discontinuously built', 'natural resource')
# ('occupation, urban, green area', 'natural resource')
# ('occupation, urban/industrial fallow (non-use)', 'natural resource')
# ('occupation, wetland, coastal (non-use)', 'natural resource')
# ('occupation, wetland, inland (non-use)', 'natural resource')
# ('octaethylene glycol monododecyl ether', 'air')
# ('octanoic acid', 'soil')
# ('oil, crude, in ground', 'natural resource')
# ('oils, non-fossil', 'soil')
# ('oils, non-fossil', 'water')
# ('oils, unspecified', 'soil')
# ('oils, unspecified', 'water')
# ('olivine, in ground', 'natural resource')
# ('orbencarb', 'soil')
# ('organic carbon', 'air')
# ('organic carbon', 'soil')
# ('organic carbon', 'water')
# ('oryzalin', 'soil')
# ('osmium, in ground', 'natural resource')
# ('oxadixyl', 'soil')
# ('oxamyl', 'soil')
# ('oxasulfuron', 'soil')
# ('oxydemeton-methyl', 'soil')
# ('oxyfluorfen', 'soil')
# ('oxygen', 'natural resource')
# ('oxygen', 'water')
# ('ozone', 'air')
# ('p-tert-amylphenol', 'soil')
# ('pah, polycyclic aromatic hydrocarbons', 'air')
# ('pah, polycyclic aromatic hydrocarbons', 'soil')
# ('pah, polycyclic aromatic hydrocarbons', 'water')
# ('palladium', 'air')
# ('palladium', 'water')
# ('palladium, in ground', 'natural resource')
# ('palladium, pd 1.6e-6%, in mixed ore, in ground', 'natural resource')
# ('paraffins', 'air')
# ('paraffins', 'water')
# ('paraquat', 'air')
# ('paraquat', 'soil')
# ('parathion', 'soil')
# ('particulates, < 2.5 um', 'air')
# ('particulates, > 10 um', 'air')
# ('particulates, > 2.5 um, and < 10um', 'air')
# ('pd, pd 2.0e-4%, pt 4.8e-4%, rh 2.4e-5%, ni 3.7e-2%, cu 5.2e-2% in ore, in ground', 'natural resource')
# ('pd, pd 7.3e-4%, pt 2.5e-4%, rh 2.0e-5%, ni 2.3e+0%, cu 3.2e+0% in ore, in ground', 'natural resource')
# ('peat, in ground', 'natural resource')
# ('penconazole', 'soil')
# ('pencycuron', 'soil')
# ('pendimethalin', 'air')
# ('pendimethalin', 'soil')
# ('pendimethalin', 'water')
# ('pentane', 'air')
# ('pentane', 'water')
# ('perchlorate, ion', 'water')
# ('perfluoropentane', 'air')
# ('perlite, in ground', 'natural resource')
# ('permethrin', 'air')
# ('permethrin', 'soil')
# ('permethrin', 'water')
# ('pesticides, unspecified', 'soil')
# ('pethoxamid', 'soil')
# ('phenanthrene', 'air')
# ('phenanthrene', 'water')
# ('phenmedipham', 'soil')
# ('phenol', 'air')
# ('phenol', 'water')
# ('phenol, 2,4-dichloro', 'air')
# ('phenol, pentachloro-', 'air')
# ('phenol, pentachloro-', 'soil')
# ('phorate', 'soil')
# ('phosalone', 'soil')
# ('phosgene', 'air')
# ('phosmet', 'soil')
# ('phosphate', 'water')
# ('phosphine', 'air')
# ('phosphoric acid', 'air')
# ('phosphoric acid', 'water')
# ('phosphorus', 'air')
# ('phosphorus', 'soil')
# ('phosphorus', 'water')
# ('phosphorus oxychloride', 'water')
# ('phosphorus pentachloride', 'water')
# ('phosphorus trichloride', 'air')
# ('phosphorus trichloride', 'water')
# ('phosphorus, 18% in apatite, 12% in crude ore, in ground', 'natural resource')
# ('phosphorus, 18% in apatite, 4% in crude ore, in ground', 'natural resource')
# ('phosphorus, in ground', 'natural resource')
# ('phthalate, butyl-benzyl-', 'water')
# ('phthalate, dibutyl-', 'water')
# ('phthalate, dimethyl-', 'water')
# ('phthalate, dioctyl-', 'water')
# ('picloram', 'soil')
# ('picoxystrobin', 'soil')
# ('pinoxaden', 'soil')
# ('piperonyl butoxide', 'soil')
# ('pirimicarb', 'soil')
# ('pirimiphos methyl', 'soil')
# ('platinum', 'air')
# ('platinum, in ground', 'natural resource')
# ('platinum, pt 4.7e-7%, in mixed ore, in ground', 'natural resource')
# ('plutonium-238', 'air')
# ('plutonium-241', 'air')
# ('plutonium-241', 'water')
# ('plutonium-alpha', 'air')
# ('plutonium-alpha', 'water')
# ('polonium, in ground', 'natural resource')
# ('polonium-210', 'air')
# ('polonium-210', 'water')
# ('polychlorinated biphenyls', 'air')
# ('polychlorinated biphenyls', 'water')
# ('potassium', 'air')
# ('potassium', 'soil')
# ('potassium', 'water')
# ('potassium chloride', 'air')
# ('potassium hydroxide', 'air')
# ('potassium soap', 'soil')
# ('potassium, in ground', 'natural resource')
# ('potassium, ion', 'water')
# ('potassium-40', 'air')
# ('potassium-40', 'water')
# ('praseodymium, 0.42% in bastnasite, 0.042% in crude ore, in ground', 'natural resource')
# ('praseodymium, in ground', 'natural resource')
# ('primisulfuron', 'soil')
# ('prochloraz', 'soil')
# ('procymidone', 'soil')
# ('profenofos', 'soil')
# ('prohexadione-calcium', 'soil')
# ('promethium-147', 'air')
# ('prometryn', 'soil')
# ('pronamide', 'soil')
# ('propachlor', 'soil')
# ('propamocarb', 'soil')
# ('propamocarb hcl', 'soil')
# ('propanal', 'air')
# ('propanal', 'water')
# ('propane', 'air')
# ('propanil', 'soil')
# ('propanol', 'air')
# ('propanol', 'water')
# ('propaquizafop', 'soil')
# ('propargite', 'soil')
# ('propene', 'air')
# ('propene', 'water')
# ('propham', 'soil')
# ('propiconazole', 'air')
# ('propiconazole', 'soil')
# ('propiconazole', 'water')
# ('propineb', 'soil')
# ('propionic acid', 'air')
# ('propionic acid', 'water')
# ('propoxycarbazone-sodium (prop)', 'soil')
# ('propylamine', 'air')
# ('propylamine', 'water')
# ('propylene oxide', 'air')
# ('propylene oxide', 'water')
# ('proquinazid', 'soil')
# ('prosulfocarb', 'soil')
# ('prosulfuron', 'soil')
# ('protactinium, in ground', 'natural resource')
# ('protactinium-234', 'air')
# ('protactinium-234', 'water')
# ('prothioconazol', 'air')
# ('prothioconazol', 'soil')
# ('prothioconazol', 'water')
# ('pt, pt 2.5e-4%, pd 7.3e-4%, rh 2.0e-5%, ni 2.3e+0%, cu 3.2e+0% in ore, in ground', 'natural resource')
# ('pt, pt 4.8e-4%, pd 2.0e-4%, rh 2.4e-5%, ni 3.7e-2%, cu 5.2e-2% in ore, in ground', 'natural resource')
# ('pumice, in ground', 'natural resource')
# ('pymetrozine', 'soil')
# ('pyraclostrobin', 'air')
# ('pyraclostrobin', 'water')
# ('pyraclostrobin (prop)', 'soil')
# ('pyraflufen-ethyl', 'soil')
# ('pyrazophos', 'soil')
# ('pyrene', 'air')
# ('pyrene', 'water')
# ('pyrethrin', 'soil')
# ('pyrethrine', 'soil')
# ('pyrethrum', 'soil')
# ('pyridate', 'soil')
# ('pyrifenox', 'soil')
# ('pyrimethanil', 'soil')
# ('pyriproxyfen', 'soil')
# ('pyrite, in ground', 'natural resource')
# ('pyrithiobac sodium salt', 'soil')
# ('pyrolusite, in ground', 'natural resource')
# ('quinclorac', 'soil')
# ('quinmerac', 'soil')
# ('quinoxyfen', 'soil')
# ('quintozene', 'soil')
# ('quizalofop ethyl ester', 'soil')
# ('quizalofop-ethyl', 'air')
# ('quizalofop-p', 'soil')
# ('quizalofop-p-ethyl', 'soil')
# ('rabon', 'soil')
# ('radiation, electromagnetic', 'air')
# ('radioactive species, alpha emitters', 'water')
# ('radioactive species, from fission and activation', 'water')
# ('radioactive species, nuclides, unspecified', 'water')
# ('radioactive species, other beta emitters', 'air')
# ('radium, in ground', 'natural resource')
# ('radium-224', 'water')
# ('radium-226', 'air')
# ('radium-226', 'water')
# ('radium-228', 'air')
# ('radium-228', 'water')
# ('radon-220', 'air')
# ('radon-222', 'air')
# ('rent', 'economic')
# ('residual hardwood, wet', 'social')
# ('residual softwood, wet', 'social')
# ('residual wood, dry', 'social')
# ('rh, rh 2.0e-5%, pt 2.5e-4%, pd 7.3e-4%, ni 2.3e+0%, cu 3.2e+0% in ore, in ground', 'natural resource')
# ('rh, rh 2.4e-5%, pt 4.8e-4%, pd 2.0e-4%, ni 3.7e-2%, cu 5.2e-2% in ore, in ground', 'natural resource')
# ('rhenium, in crude ore, in ground', 'natural resource')
# ('rhenium, in ground', 'natural resource')
# ('rhodium', 'air')
# ('rhodium, in ground', 'natural resource')
# ('rhodium, rh 1.6e-7%, in mixed ore, in ground', 'natural resource')
# ('rimsulfuron', 'soil')
# ('rotenone', 'soil')
# ('rubidium', 'water')
# ('rubidium, in ground', 'natural resource')
# ('ruthenium, in ground', 'natural resource')
# ('ruthenium-103', 'air')
# ('ruthenium-103', 'water')
# ('ruthenium-106', 'air')
# ('ruthenium-106', 'water')
# ('s-metolachlor', 'soil')
# ('salt water (obsolete)', 'water')
# ('samarium, 0.3% in bastnasite, 0.03% in crude ore, in ground', 'natural resource')
# ('samarium, in ground', 'natural resource')
# ('sand, unspecified, in ground', 'natural resource')
# ('scandium', 'air')
# ('scandium', 'soil')
# ('scandium', 'water')
# ('scandium, in ground', 'natural resource')
# ('selenium', 'air')
# ('selenium', 'soil')
# ('selenium', 'water')
# ('selenium, in ground', 'natural resource')
# ('sethoxydim', 'air')
# ('sethoxydim', 'soil')
# ('shale, in ground', 'natural resource')
# ('siduron', 'soil')
# ('silicon', 'air')
# ('silicon', 'soil')
# ('silicon', 'water')
# ('silicon dioxide', 'water')
# ('silicon tetrachloride', 'air')
# ('silicon tetrafluoride', 'air')
# ('silicon, in ground', 'natural resource')
# ('silthiofam', 'soil')
# ('silver', 'air')
# ('silver', 'soil')
# ('silver, 0.007% in sulfide, ag 0.004%, pb, zn, cd, in, in ground', 'natural resource')
# ('silver, 0.01% in crude ore, in ground', 'natural resource')
# ('silver, 3.2ppm in sulfide, ag 1.2ppm, cu and te, in crude ore, in ground', 'natural resource')
# ('silver, ag 1.5e-4%, au 6.8e-4%, in ore, in ground', 'natural resource')
# ('silver, ag 1.5e-5%, au 5.4e-4%, in ore, in ground', 'natural resource')
# ('silver, ag 1.8e-6%, in mixed ore, in ground', 'natural resource')
# ('silver, ag 2.1e-4%, au 2.1e-4%, in ore, in ground', 'natural resource')
# ('silver, ag 4.2e-3%, au 1.1e-4%, in ore, in ground', 'natural resource')
# ('silver, ag 4.6e-5%, au 1.3e-4%, in ore, in ground', 'natural resource')
# ('silver, ag 5.4e-3%, in mixed ore, in ground', 'natural resource')
# ('silver, ag 7.6e-5%, au 9.7e-5%, in ore, in ground', 'natural resource')
# ('silver, ag 9.7e-4%, in mixed ore, in ground', 'natural resource')
# ('silver, in ground', 'natural resource')
# ('silver, ion', 'water')
# ('silver-110', 'air')
# ('silver-110', 'water')
# ('simazine', 'soil')
# ('sodium', 'air')
# ('sodium', 'soil')
# ('sodium', 'water')
# ('sodium chlorate', 'air')
# ('sodium chlorate', 'water')
# ('sodium chloride, in ground', 'natural resource')
# ('sodium dichromate', 'air')
# ('sodium fluorosilicate', 'soil')
# ('sodium formate', 'air')
# ('sodium formate', 'water')
# ('sodium hydroxide', 'air')
# ('sodium hypochlorite', 'air')
# ('sodium nitrate, in ground', 'natural resource')
# ('sodium perchlorate', 'air')
# ('sodium sulphate, various forms, in ground', 'natural resource')
# ('sodium tetrahydridoborate', 'air')
# ('sodium, in ground', 'natural resource')
# ('sodium, ion', 'water')
# ('sodium-24', 'water')
# ('solids, inorganic', 'water')
# ('spinosad', 'soil')
# ('spirodiclofen', 'soil')
# ('spiroxamine', 'soil')
# ('spodumene, in ground', 'natural resource')
# ('starane', 'soil')
# ('steatite, in ground', 'natural resource')
# ('stibnite, in ground', 'natural resource')
# ('strontium', 'air')
# ('strontium', 'soil')
# ('strontium', 'water')
# ('strontium, in ground', 'natural resource')
# ('strontium-89', 'air')
# ('strontium-89', 'water')
# ('strontium-90', 'air')
# ('strontium-90', 'water')
# ('styrene', 'air')
# ('styrene', 'water')
# ('sulcotrione', 'soil')
# ('sulfate', 'air')
# ('sulfate', 'soil')
# ('sulfate', 'water')
# ('sulfate, ion', 'water')
# ('sulfentrazone', 'air')
# ('sulfentrazone', 'soil')
# ('sulfide', 'water')
# ('sulfite', 'water')
# ('sulfosate', 'soil')
# ('sulfosulfuron', 'soil')
# ('sulfotep', 'soil')
# ('sulfur', 'soil')
# ('sulfur', 'water')
# ('sulfur dioxide', 'air')
# ('sulfur hexafluoride', 'air')
# ('sulfur oxides', 'air')
# ('sulfur trioxide', 'air')
# ('sulfur, in ground', 'natural resource')
# ('sulfuric acid', 'air')
# ('sulfuric acid', 'soil')
# ('sulfuric acid', 'water')
# ('suspended solids, unspecified', 'water')
# ('sylvite, 25 % in sylvinite, in ground', 'natural resource')
# ('sylvite, in ground', 'natural resource')
# ('t-butyl methyl ether', 'air')
# ('t-butyl methyl ether', 'water')
# ('t-butylamine', 'air')
# ('t-butylamine', 'water')
# ('talc, in ground', 'natural resource')
# ('tantalum, 81.9% in tantalite, 1.6e-4% in crude ore, in ground', 'natural resource')
# ('tantalum, in ground', 'natural resource')
# ('tau-fluvalinate', 'soil')
# ('tcmtb', 'soil')
# ('tebuconazole', 'air')
# ('tebuconazole', 'soil')
# ('tebuconazole', 'water')
# ('tebufenozide', 'soil')
# ('tebufenpyrad', 'soil')
# ('tebupirimphos', 'soil')
# ('tebutam', 'soil')
# ('technetium-99', 'air')
# ('technetium-99', 'water')
# ('technetium-99m', 'water')
# ('teflubenzuron', 'soil')
# ('tefluthrin', 'air')
# ('tefluthrin', 'soil')
# ('tefluthrin', 'water')
# ('tellurium', 'air')
# ('tellurium, 0.5ppm in sulfide, te 0.2ppm, cu and ag, in crude ore, in ground', 'natural resource')
# ('tellurium, in ground', 'natural resource')
# ('tellurium-123m', 'air')
# ('tellurium-123m', 'water')
# ('tellurium-132', 'water')
# ('tepraloxydim', 'soil')
# ('terbacil', 'soil')
# ('terbium, in ground', 'natural resource')
# ('terbufos', 'soil')
# ('terbuthylazin', 'soil')
# ('terbutryn', 'soil')
# ('terpenes', 'air')
# ('tetramethyl ammonium hydroxide', 'air')
# ('thallium', 'air')
# ('thallium', 'soil')
# ('thallium', 'water')
# ('thallium, in ground', 'natural resource')
# ('thiabendazole', 'soil')
# ('thiacloprid', 'soil')
# ('thiamethoxam', 'soil')
# ('thidiazuron', 'soil')
# ('thifensulfuron', 'air')
# ('thifensulfuron-methyl', 'soil')
# ('thiobencarb', 'soil')
# ('thiocyanate, ion', 'water')
# ('thiocyclam', 'soil')
# ('thiodicarb', 'air')
# ('thiodicarb', 'soil')
# ('thiophanat-methyl', 'soil')
# ('thiram', 'soil')
# ('thorium', 'air')
# ('thorium, in ground', 'natural resource')
# ('thorium-228', 'air')
# ('thorium-228', 'water')
# ('thorium-230', 'air')
# ('thorium-230', 'water')
# ('thorium-232', 'air')
# ('thorium-232', 'water')
# ('thorium-234', 'air')
# ('thorium-234', 'water')
# ('thulium, in ground', 'natural resource')
# ('tin', 'air')
# ('tin', 'soil')
# ('tin, 79% in cassiterite, 0.1% in crude ore, in ground', 'natural resource')
# ('tin, in ground', 'natural resource')
# ('tin, ion', 'water')
# ('tio2, 54% in ilmenite, 18% in crude ore, in ground', 'natural resource')
# ('tio2, 54% in ilmenite, 2.6% in crude ore, in ground', 'natural resource')
# ('tio2, 95% in rutile, 0.40% in crude ore, in ground', 'natural resource')
# ('titanium', 'air')
# ('titanium', 'soil')
# ('titanium, in ground', 'natural resource')
# ('titanium, ion', 'water')
# ('toc, total organic carbon', 'water')
# ('toluene', 'air')
# ('toluene', 'water')
# ('toluene, 2-chloro', 'air')
# ('toluene, 2-chloro', 'water')
# ('tolylfluanid', 'soil')
# ('tralkoxydim', 'soil')
# ('tralomethrin', 'soil')
# ('transformation, from annual crop', 'natural resource')
# ('transformation, from annual crop, flooded crop', 'natural resource')
# ('transformation, from annual crop, greenhouse', 'natural resource')
# ('transformation, from annual crop, irrigated', 'natural resource')
# ('transformation, from annual crop, irrigated, extensive', 'natural resource')
# ('transformation, from annual crop, irrigated, intensive', 'natural resource')
# ('transformation, from annual crop, non-irrigated', 'natural resource')
# ('transformation, from annual crop, non-irrigated, extensive', 'natural resource')
# ('transformation, from annual crop, non-irrigated, intensive', 'natural resource')
# ('transformation, from arable land, unspecified use', 'natural resource')
# ('transformation, from bare area (non-use)', 'natural resource')
# ('transformation, from cropland fallow (non-use)', 'natural resource')
# ('transformation, from dump site', 'natural resource')
# ('transformation, from dump site, inert material landfill', 'natural resource')
# ('transformation, from dump site, residual material landfill', 'natural resource')
# ('transformation, from dump site, sanitary landfill', 'natural resource')
# ('transformation, from dump site, slag compartment', 'natural resource')
# ('transformation, from field margin/hedgerow', 'natural resource')
# ('transformation, from forest, extensive', 'natural resource')
# ('transformation, from forest, intensive', 'natural resource')
# ('transformation, from forest, primary (non-use)', 'natural resource')
# ('transformation, from forest, secondary (non-use)', 'natural resource')
# ('transformation, from forest, unspecified', 'natural resource')
# ('transformation, from grassland, natural (non-use)', 'natural resource')
# ('transformation, from grassland, natural, for livestock grazing', 'natural resource')
# ('transformation, from heterogeneous, agricultural', 'natural resource')
# ('transformation, from industrial area', 'natural resource')
# ('transformation, from inland waterbody, unspecified', 'natural resource')
# ('transformation, from lake, artificial', 'natural resource')
# ('transformation, from lake, natural (non-use)', 'natural resource')
# ('transformation, from mineral extraction site', 'natural resource')
# ('transformation, from pasture, man made', 'natural resource')
# ('transformation, from pasture, man made, extensive', 'natural resource')
# ('transformation, from pasture, man made, intensive', 'natural resource')
# ('transformation, from permanent crop', 'natural resource')
# ('transformation, from permanent crop, irrigated', 'natural resource')
# ('transformation, from permanent crop, irrigated, extensive', 'natural resource')
# ('transformation, from permanent crop, irrigated, intensive', 'natural resource')
# ('transformation, from permanent crop, non-irrigated', 'natural resource')
# ('transformation, from permanent crop, non-irrigated, extensive', 'natural resource')
# ('transformation, from permanent crop, non-irrigated, intensive', 'natural resource')
# ('transformation, from river, artificial', 'natural resource')
# ('transformation, from river, natural (non-use)', 'natural resource')
# ('transformation, from seabed, drilling and mining', 'natural resource')
# ('transformation, from seabed, infrastructure', 'natural resource')
# ('transformation, from seabed, natural (non-use)', 'natural resource')
# ('transformation, from seabed, unspecified', 'natural resource')
# ('transformation, from shrub land, sclerophyllous', 'natural resource')
# ('transformation, from snow and ice (non-use)', 'natural resource')
# ('transformation, from traffic area, rail network', 'natural resource')
# ('transformation, from traffic area, rail/road embankment', 'natural resource')
# ('transformation, from traffic area, road network', 'natural resource')
# ('transformation, from unknown', 'natural resource')
# ('transformation, from unspecified', 'natural resource')
# ('transformation, from unspecified, natural (non-use)', 'natural resource')
# ('transformation, from urban, continuously built', 'natural resource')
# ('transformation, from urban, discontinuously built', 'natural resource')
# ('transformation, from urban, green area', 'natural resource')
# ('transformation, from urban/industrial fallow (non-use)', 'natural resource')
# ('transformation, from wetland, coastal (non-use)', 'natural resource')
# ('transformation, from wetland, inland (non-use)', 'natural resource')
# ('transformation, to annual crop', 'natural resource')
# ('transformation, to annual crop, flooded crop', 'natural resource')
# ('transformation, to annual crop, greenhouse', 'natural resource')
# ('transformation, to annual crop, irrigated', 'natural resource')
# ('transformation, to annual crop, irrigated, extensive', 'natural resource')
# ('transformation, to annual crop, irrigated, intensive', 'natural resource')
# ('transformation, to annual crop, non-irrigated', 'natural resource')
# ('transformation, to annual crop, non-irrigated, extensive', 'natural resource')
# ('transformation, to annual crop, non-irrigated, intensive', 'natural resource')
# ('transformation, to arable land, unspecified use', 'natural resource')
# ('transformation, to bare area (non-use)', 'natural resource')
# ('transformation, to cropland fallow (non-use)', 'natural resource')
# ('transformation, to dump site', 'natural resource')
# ('transformation, to dump site, inert material landfill', 'natural resource')
# ('transformation, to dump site, residual material landfill', 'natural resource')
# ('transformation, to dump site, sanitary landfill', 'natural resource')
# ('transformation, to dump site, slag compartment', 'natural resource')
# ('transformation, to field margin/hedgerow', 'natural resource')
# ('transformation, to forest, extensive', 'natural resource')
# ('transformation, to forest, intensive', 'natural resource')
# ('transformation, to forest, primary (non-use)', 'natural resource')
# ('transformation, to forest, secondary (non-use)', 'natural resource')
# ('transformation, to forest, unspecified', 'natural resource')
# ('transformation, to grassland, natural (non-use)', 'natural resource')
# ('transformation, to grassland, natural, for livestock grazing', 'natural resource')
# ('transformation, to heterogeneous, agricultural', 'natural resource')
# ('transformation, to industrial area', 'natural resource')
# ('transformation, to inland waterbody, unspecified', 'natural resource')
# ('transformation, to lake, artificial', 'natural resource')
# ('transformation, to lake, natural (non-use)', 'natural resource')
# ('transformation, to mineral extraction site', 'natural resource')
# ('transformation, to pasture, man made', 'natural resource')
# ('transformation, to pasture, man made, extensive', 'natural resource')
# ('transformation, to pasture, man made, intensive', 'natural resource')
# ('transformation, to permanent crop', 'natural resource')
# ('transformation, to permanent crop, irrigated', 'natural resource')
# ('transformation, to permanent crop, irrigated, extensive', 'natural resource')
# ('transformation, to permanent crop, irrigated, intensive', 'natural resource')
# ('transformation, to permanent crop, non-irrigated', 'natural resource')
# ('transformation, to permanent crop, non-irrigated, extensive', 'natural resource')
# ('transformation, to permanent crop, non-irrigated, intensive', 'natural resource')
# ('transformation, to river, artificial', 'natural resource')
# ('transformation, to river, natural (non-use)', 'natural resource')
# ('transformation, to seabed, drilling and mining', 'natural resource')
# ('transformation, to seabed, infrastructure', 'natural resource')
# ('transformation, to seabed, natural (non-use)', 'natural resource')
# ('transformation, to seabed, unspecified', 'natural resource')
# ('transformation, to shrub land, sclerophyllous', 'natural resource')
# ('transformation, to snow and ice (non-use)', 'natural resource')
# ('transformation, to traffic area, rail network', 'natural resource')
# ('transformation, to traffic area, rail/road embankment', 'natural resource')
# ('transformation, to traffic area, road network', 'natural resource')
# ('transformation, to unknown', 'natural resource')
# ('transformation, to unspecified', 'natural resource')
# ('transformation, to unspecified, natural (non-use)', 'natural resource')
# ('transformation, to urban, continuously built', 'natural resource')
# ('transformation, to urban, discontinuously built', 'natural resource')
# ('transformation, to urban, green area', 'natural resource')
# ('transformation, to urban/industrial fallow (non-use)', 'natural resource')
# ('transformation, to wetland, coastal (non-use)', 'natural resource')
# ('transformation, to wetland, inland (non-use)', 'natural resource')
# ('tri-allate', 'soil')
# ('triadimenol', 'soil')
# ('triasulfuron', 'soil')
# ('triazamate', 'soil')
# ('tribenuron', 'soil')
# ('tribenuron-methyl', 'soil')
# ('tribufos', 'soil')
# ('tributyltin compounds', 'water')
# ('trichlorfon', 'soil')
# ('trichloroethylene', 'air')
# ('trichlorosilane', 'air')
# ('trichlorosilane', 'water')
# ('triclopyr', 'soil')
# ('tridemorph', 'soil')
# ('triethylene glycol', 'water')
# ('trifloxystrobin', 'air')
# ('trifloxystrobin', 'soil')
# ('trifloxystrobin', 'water')
# ('triflumizole', 'soil')
# ('triflumuron', 'soil')
# ('trifluralin', 'air')
# ('trifluralin', 'soil')
# ('triflusulfuron-methyl', 'soil')
# ('triforine', 'soil')
# ('trimethylamine', 'air')
# ('trimethylamine', 'water')
# ('trinexapac-ethyl', 'soil')
# ('trioctyltin', 'water')
# ('triphenyltin', 'water')
# ('trisodium phosphate', 'air')
# ('triticonazole', 'soil')
# ('tungsten', 'air')
# ('tungsten', 'soil')
# ('tungsten', 'water')
# ('tungsten, in ground', 'natural resource')
# ('ulexite, in ground', 'natural resource')
# ('uranium', 'air')
# ('uranium alpha', 'air')
# ('uranium alpha', 'water')
# ('uranium, in ground', 'natural resource')
# ('uranium-234', 'air')
# ('uranium-234', 'water')
# ('uranium-235', 'air')
# ('uranium-235', 'water')
# ('uranium-238', 'air')
# ('uranium-238', 'water')
# ('urea', 'water')
# ('vamidothion', 'soil')
# ('vanadium', 'air')
# ('vanadium', 'soil')
# ('vanadium, in ground', 'natural resource')
# ('vanadium, ion', 'water')
# ('venting of argon, crude, liquid', 'social')
# ('venting of nitrogen, liquid', 'social')
# ('vermiculite, in ground', 'natural resource')
# ('vinclozolin', 'soil')
# ('voc, volatile organic compounds, unspecified origin', 'air')
# ('voc, volatile organic compounds, unspecified origin', 'water')
# ('volume occupied, final repository for low-active radioactive waste', 'natural resource')
# ('volume occupied, final repository for radioactive waste', 'natural resource')
# ('volume occupied, reservoir', 'natural resource')
# ('volume occupied, underground deposit', 'natural resource')
# ('water', 'air')
# ('water', 'water')
# ('water, cooling, unspecified natural origin', 'natural resource')
# ('water, in air', 'natural resource')
# ('water, lake', 'natural resource')
# ('water, river', 'natural resource')
# ('water, salt, ocean', 'natural resource')
# ('water, salt, sole', 'natural resource')
# ('water, turbine use, unspecified natural origin', 'natural resource')
# ('water, unspecified natural origin', 'natural resource')
# ('water, well, in ground', 'natural resource')
# ('wood, hard, standing', 'natural resource')
# ('wood, primary forest, standing', 'natural resource')
# ('wood, soft, standing', 'natural resource')
# ('wood, unspecified, standing', 'natural resource')
# ('xenon, in air', 'natural resource')
# ('xenon-131m', 'air')
# ('xenon-133', 'air')
# ('xenon-133m', 'air')
# ('xenon-135', 'air')
# ('xenon-135m', 'air')
# ('xenon-137', 'air')
# ('xenon-138', 'air')
# ('xylene', 'air')
# ('xylene', 'water')
# ('ytterbium, in ground', 'natural resource')
# ('yttrium, in ground', 'natural resource')
# ('yttrium-90', 'water')
# ('zeta-cypermethrin', 'air')
# ('zeta-cypermethrin', 'soil')
# ('zinc', 'air')
# ('zinc', 'soil')
# ('zinc, 9.0% in sulfide, zn 5.3%, pb, ag, cd, in, in ground', 'natural resource')
# ('zinc, in ground', 'natural resource')
# ('zinc, ion', 'water')
# ('zinc, zn 0.63%, in mixed ore, in ground', 'natural resource')
# ('zinc, zn 3.1%, in mixed ore, in ground', 'natural resource')
# ('zinc-65', 'air')
# ('zinc-65', 'water')
# ('zineb', 'soil')
# ('ziram', 'soil')
# ('zirconia, as baddeleyite, in ground', 'natural resource')
# ('zirconium', 'air')
# ('zirconium, 50% in zircon, 0.39% in crude ore, in ground', 'natural resource')
# ('zirconium, in ground', 'natural resource')
# ('zirconium-95', 'air')
# ('zirconium-95', 'water')
# ('zoxamide', 'soil')

# %%
gw = MarineEutrophication(data, biosphere)

# %%
gw.apply_strategies()
# Out:
# Applying strategy: fix_perspective_string
# Applying strategy: generic_reformat
# Applying strategy: split_synonyms
# Applying strategy: more_synonyms
# Applying strategy: fix_unit_string
# Applying strategy: name_matcher
# Applying strategy: add_water_category
# Applying strategy: drop_last_name_component
# Applying strategy: match_single
# Applied 9 strategies in 0.02 seconds

# %%
gw.data[0]
# Out:
# {'name': ('ReCiPe 2016', 'v1.1 (20180117)', 'Marine eutrophication'),
#  'unit': 'kg N-eq to marine water/kg',
#  'filename': 'ReCiPe2016_CFs_v1.1_20180117.xlsx',
#  'description': '',
#  'exchanges': [{'name': 'nitrogen',
#    'compartment': 'freshwater',
#    'amount': 0.29684210526315785,
#    'synonyms': [],
#    'categories': ('water', 'surface water'),
#    'input': ('biosphere3', 'ae70ca6c-807a-482b-9ddc-e449b4893fe3')},
#   {'name': 'ammonium, ion',
#    'compartment': 'freshwater',
#    'amount': 0.2303494736842105,
#    'synonyms': [],
#    'categories': ('water', 'surface water'),
#    'input': ('biosphere3', '13331e67-6006-48c4-bdb4-340c12010036')},
#   {'name': 'ammonia',
#    'compartment': 'freshwater',
#    'amount': 0.2444582043343653,
#    'synonyms': [],
#    'categories': ('water', 'surface water')},
#   {'name': 'nitric oxide',
#    'compartment': 'freshwater',
#    'amount': 0.13852631578947378,
#    'synonyms': [],
#    'categories': ('water', 'surface water')},
#   {'name': 'nitrogen dioxide',
#    'compartment': 'freshwater',
#    'amount': 0.09023999999999999,
#    'synonyms': [],
#    'categories': ('water', 'surface water'),
#    'input': ('biosphere3', '399b496b-b590-4c48-ba34-0e8f18b5baff')},
#   {'name': 'nitrate',
#    'compartment': 'freshwater',
#    'amount': 0.06708631578947367,
#    'synonyms': [],
#    'categories': ('water', 'surface water'),
#    'input': ('biosphere3', '7ce56135-2ca5-4fba-ad52-d62a34bfeb35')},
#   {'name': 'nitrogen oxides',
#    'compartment': 'freshwater',
#    'amount': 0.09023999999999999,
#    'synonyms': [],
#    'categories': ('water', 'surface water')},
#   {'name': 'nitrogen',
#    'compartment': 'agricultural soil',
#    'amount': 0.12631578947368421,
#    'synonyms': [],
#    'categories': ('soil', 'agricultural'),
#    'input': ('biosphere3', '7ce704ce-2a44-448b-b198-f00bf5928b4b')},
#   {'name': 'ammonium, ion',
#    'compartment': 'agricultural soil',
#    'amount': 0.09802105263157895,
#    'synonyms': [],
#    'categories': ('soil', 'agricultural')},
#   {'name': 'ammonia',
#    'compartment': 'agricultural soil',
#    'amount': 0.1040247678018576,
#    'synonyms': [],
#    'categories': ('soil', 'agricultural')},
#   {'name': 'nitric oxide',
#    'compartment': 'agricultural soil',
#    'amount': 0.05894736842105268,
#    'synonyms': [],
#    'categories': ('soil', 'agricultural')},
#   {'name': 'nitrogen dioxide',
#    'compartment': 'agricultural soil',
#    'amount': 0.038400000000000004,
#    'synonyms': [],
#    'categories': ('soil', 'agricultural')},
#   {'name': 'nitrate',
#    'compartment': 'agricultural soil',
#    'amount': 0.028547368421052634,
#    'synonyms': [],
#    'categories': ('soil', 'agricultural')},
#   {'name': 'nitrogen oxides',
#    'compartment': 'agricultural soil',
#    'amount': 0.038400000000000004,
#    'synonyms': [],
#    'categories': ('soil', 'agricultural')},
#   {'name': 'nitrogen',
#    'compartment': 'seawater',
#    'amount': 1.0,
#    'synonyms': [],
#    'categories': ('water', 'ocean'),
#    'input': ('biosphere3', '996829cc-2d40-418a-beda-7c50399952f9')},
#   {'name': 'ammonium, ion',
#    'compartment': 'seawater',
#    'amount': 0.776,
#    'synonyms': [],
#    'categories': ('water', 'ocean'),
#    'input': ('biosphere3', 'bc069d24-fbbd-4c05-8b6e-4089dc8249ae')},
#   {'name': 'ammonia',
#    'compartment': 'seawater',
#    'amount': 0.823529411764706,
#    'synonyms': [],
#    'categories': ('water', 'ocean')},
#   {'name': 'nitric oxide',
#    'compartment': 'seawater',
#    'amount': 0.466666666666667,
#    'synonyms': [],
#    'categories': ('water', 'ocean')},
#   {'name': 'nitrogen dioxide',
#    'compartment': 'seawater',
#    'amount': 0.304,
#    'synonyms': [],
#    'categories': ('water', 'ocean')},
#   {'name': 'nitrate',
#    'compartment': 'seawater',
#    'amount': 0.226,
#    'synonyms': [],
#    'categories': ('water', 'ocean'),
#    'input': ('biosphere3', '43c700bb-0b3b-4fb1-8bd1-3d1da82b6844')},
#   {'name': 'nitrogen oxides',
#    'compartment': 'seawater',
#    'amount': 0.304,
#    'synonyms': [],
#    'categories': ('water', 'ocean')}]}

# %%
gw.write_excel("marine_eutrophication")
# Out:
# Wrote matching file to:
# /Users/cmutel/Library/Application Support/Brightway3/default.c21f969b/output/lcia-matching-marine_eutrophication.xlsx

# %%
gw.statistics()
# Out:
# 1 methods
# 21 cfs
# 13 unlinked cfs
# (1, 21, 13)

# %%
for x in gw.unlinked:
    print(x['name'])
# Out:
# ammonia
# nitric oxide
# nitrogen oxides
# ammonium, ion
# ammonia
# nitric oxide
# nitrogen dioxide
# nitrate
# nitrogen oxides
# ammonia
# nitric oxide
# nitrogen dioxide
# nitrogen oxides

# %%
comp = gw.compare_to_previous()

# %%
import bw2data

for flow, cf in bw2data.Method(gw.previous_reference).load():
    print(bw2data.get_activity(flow))
# Out:
# 'Ammonia' (kilogram, None, ('air', 'low population density, long-term'))
# 'Ammonia' (kilogram, None, ('air', 'lower stratosphere + upper troposphere'))
# 'Ammonia' (kilogram, None, ('air', 'non-urban air or from high stacks'))
# 'Ammonia' (kilogram, None, ('air',))
# 'Ammonia' (kilogram, None, ('air', 'urban air close to ground'))
# 'Ammonium, ion' (kilogram, None, ('water', 'ground-'))
# 'Ammonium, ion' (kilogram, None, ('water', 'ground-, long-term'))
# 'Ammonium, ion' (kilogram, None, ('water', 'ocean'))
# 'Ammonium, ion' (kilogram, None, ('water', 'surface water'))
# 'Ammonium, ion' (kilogram, None, ('water',))
# 'Cyanide' (kilogram, None, ('water', 'ground-'))
# 'Cyanide' (kilogram, None, ('water', 'ground-, long-term'))
# 'Cyanide' (kilogram, None, ('water', 'ocean'))
# 'Cyanide' (kilogram, None, ('water', 'surface water'))
# 'Cyanide' (kilogram, None, ('water',))
# 'Nitrate' (kilogram, None, ('air', 'low population density, long-term'))
# 'Nitrate' (kilogram, None, ('air', 'lower stratosphere + upper troposphere'))
# 'Nitrate' (kilogram, None, ('air', 'non-urban air or from high stacks'))
# 'Nitrate' (kilogram, None, ('air',))
# 'Nitrate' (kilogram, None, ('air', 'urban air close to ground'))
# 'Nitrate' (kilogram, None, ('water', 'ground-'))
# 'Nitrate' (kilogram, None, ('water', 'ground-, long-term'))
# 'Nitrate' (kilogram, None, ('water', 'ocean'))
# 'Nitrate' (kilogram, None, ('water', 'surface water'))
# 'Nitrate' (kilogram, None, ('water',))
# 'Nitric oxide' (kilogram, None, ('air',))
# 'Nitrite' (kilogram, None, ('water', 'ground-'))
# 'Nitrite' (kilogram, None, ('water', 'ground-, long-term'))
# 'Nitrite' (kilogram, None, ('water', 'ocean'))
# 'Nitrite' (kilogram, None, ('water', 'surface water'))
# 'Nitrite' (kilogram, None, ('water',))
# 'Nitrogen' (kilogram, None, ('water', 'ground-'))
# 'Nitrogen' (kilogram, None, ('water', 'ground-, long-term'))
# 'Nitrogen' (kilogram, None, ('water', 'ocean'))
# 'Nitrogen' (kilogram, None, ('water', 'surface water'))
# 'Nitrogen' (kilogram, None, ('water',))
# 'Nitrogen oxides' (kilogram, None, ('air', 'low population density, long-term'))
# 'Nitrogen oxides' (kilogram, None, ('air', 'lower stratosphere + upper troposphere'))
# 'Nitrogen oxides' (kilogram, None, ('air', 'non-urban air or from high stacks'))
# 'Nitrogen oxides' (kilogram, None, ('air',))
# 'Nitrogen oxides' (kilogram, None, ('air', 'urban air close to ground'))
# 'Nitrogen, organic bound' (kilogram, None, ('water', 'ground-'))
# 'Nitrogen, organic bound' (kilogram, None, ('water', 'ground-, long-term'))
# 'Nitrogen, organic bound' (kilogram, None, ('water', 'ocean'))
# 'Nitrogen, organic bound' (kilogram, None, ('water', 'surface water'))
# 'Nitrogen, organic bound' (kilogram, None, ('water',))

# %%
[(key, len(comp[key])) for key in comp]
# Out:
# [('found', 3), ('missing', 3), ('reference', 3)]

# %% [markdown]
# Present in previous ReCiPe, missing here

# %%
comp['reference']
# Out:
# {'phosphate', 'phosphoric acid', 'phosphorus'}

# %%
comp['found']
# Out:
# {'phosphate', 'phosphoric acid', 'phosphorus'}

# %%
sorted(comp['reference'].difference(comp['found']))
# Out:
# []

# %%
c['found']

# %%
c['missing']

# %%
gw.drop_unlinked()
# Out:
# Applying strategy: drop_unlinked_cfs
# Applied 1 strategies in 0.00 seconds

# %%
gw.write_methods(overwrite=True)
# Out:
# Wrote 1 LCIA methods with 8 characterization factors

# %%
gw.data[0]['name']
# Out:
# ('ReCiPe 2016', 'v1.1 (20180117)', 'Marine eutrophication')

# %% [markdown]
# # Compare to previous ReCiPe method

# %%
# %matplotlib inline

# %%
import bw2data, bw2calc
import pyprind
import seaborn as sb
import numpy as np

# %%
keys = sorted([x.key for x in bw2data.Database("ecoinvent 3.6 cutoff")])

# %%
results_reference, results_2016 = [], []

# %%
lca = bw2calc.LCA({keys[0]: 1}, gw.previous_reference)
lca.lci()
lca.lcia()

# %%
reference_cm = lca.characterization_matrix.copy()

# %%
lca.switch_method(('ReCiPe 2016', 'v1.1 (20180117)', 'Marine eutrophication'))

# %%
lca.characterization_matrix.sum(), reference_cm.sum()
# Out:
# (2.6865179166197777, 18.663999997079372)

# %%
new_cm = lca.characterization_matrix.copy()

# %%
for key in pyprind.prog_bar(keys):
    lca.redo_lci({key: 1})
    results_reference.append((reference_cm * lca.inventory).sum())
    results_2016.append((new_cm * lca.inventory).sum())
# Out:
# 0% [##############################] 100% | ETA: 00:00:00
# Total time elapsed: 00:04:58

# %%
sb.scatterplot(np.log10(np.array(results_reference)), np.log10(np.array(results_2016)))
# Out:
# /Users/cmutel/miniconda3/envs/bw2dev/lib/python3.7/site-packages/ipykernel_launcher.py:1: RuntimeWarning: divide by zero encountered in log10
#   """Entry point for launching an IPython kernel.

# %%
def masked_ratio(a, b):
    a, b = np.array(a), np.array(b)
    mask = (a != 0) * (b != 0)
    return a / b

# %%
sb.distplot(masked_ratio(results_2016, results_reference))
# Out:
# /Users/cmutel/miniconda3/envs/bw2dev/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: divide by zero encountered in true_divide
#   after removing the cwd from sys.path.
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# <ipython-input-23-2a222fdd991d> in <module>
# ----> 1 sb.distplot(masked_ratio(results_2016, results_reference))
#
# ~/miniconda3/envs/bw2dev/lib/python3.7/site-packages/seaborn/distributions.py in distplot(a, bins, hist, kde, rug, fit, hist_kws, kde_kws, rug_kws, fit_kws, color, vertical, norm_hist, axlabel, label, ax)
#     213     if hist:
#     214         if bins is None:
# --> 215             bins = min(_freedman_diaconis_bins(a), 50)
#     216         hist_kws.setdefault("alpha", 0.4)
#     217         hist_kws.setdefault("density", norm_hist)
#
# ~/miniconda3/envs/bw2dev/lib/python3.7/site-packages/seaborn/distributions.py in _freedman_diaconis_bins(a)
#      33         return int(np.sqrt(a.size))
#      34     else:
# ---> 35         return int(np.ceil((a.max() - a.min()) / h))
#      36
#      37
#
# OverflowError: cannot convert float infinity to integer

# %%
def abnormal_ratio(a, b):
    if not a or not b:
        return
    ratio = abs(a / b)
    if 0.8 < ratio < 1.25:
        return
    return ratio

# %%
exceptions = sorted([
    (abnormal_ratio(results_2016[i], results_reference[i]), bw2data.get_activity(key)) 
    for i, key in enumerate(keys) 
    if abnormal_ratio(results_2016[i], results_reference[i])
], reverse=True)

# %%
len(exceptions)

# %%
exceptions[:10]

# %%
lca.redo_lci({exceptions[0][1]: 1})
lca.characterized_inventory = new_cm * lca.inventory
