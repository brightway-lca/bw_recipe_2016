# %%
from bw_recipe_2016 import (
    FreshwaterEcotoxicity,
    get_biosphere_database, 
    extract_recipe,
)
from bw_recipe_2016.chemidplus import ChemIDPlus, Multiple, Missing

# %%
c = ChemIDPlus()

# %%
data = extract_recipe()[12]

# %%
biosphere = get_biosphere_database()

# %%
gw = FreshwaterEcotoxicity(data, biosphere)

# %%
gw.apply_strategies()
# Out:
# Applying strategy: generic_reformat
# Applying strategy: fix_unit_string
# Applying strategy: name_matcher
# Applying strategy: set_toxicity_categories
# Applying strategy: complete_method_name
# Applying strategy: match_multiple
# Applying strategy: match_cas_number
# Applying strategy: chemid_name_mapping
# Applying strategy: match_multiple
# Applying strategy: chemid_cas_to_name_mapping
# Applying strategy: match_multiple
# Applied 11 strategies in 20.37 seconds

# %%
gw.write_excel("freshwater-ecotoxicity")
# Out:
# Wrote matching file to:
# /Users/cmutel/Library/Application Support/Brightway3/default.c21f969b/output/lcia-matching-freshwater-ecotoxicity.xlsx

# %%
gw.statistics()
# Out:
# 3 methods
# 57838 cfs
# 50202 unlinked cfs
# (3, 57838, 50202)

# %%
r_names = {x['name'].lower() for x in gw.unlinked}

for x in sorted(r_names):
    print(x)
# Out:
# (1r,4r)-(+)-camphor
# (4-chloro-2-methylphenoxy)acetic acid compd. with n-methylmethanamine (1:1)
# 1,1'-dimethyl-4,4'-bipyridinium bis(methyl sul*)
# 1,1,1,2-tetrachloroethane
# 1,1,1,3,3,3-hexafluoropropan-2-ol
# 1,1,1-tris(hydroxymethyl)propane
# 1,1,2,2-tetrachloroethane
# 1,1,3-trimethylcyclohexane
# 1,1-bis(4-ethoxyphenyl)-2-nitropropane
# 1,1-dichloro-2,2-bis(ethylphenyl)ethane
# 1,1-dichloroethylene
# 1,1-dichloropropane
# 1,1-dimethyl cyclohexane
# 1,1-dimethyl hydrazine
# 1,2,3,4,5,6-hexachlorocyclohexane
# 1,2,3,4,7,7-hexachloro-2,5-norbornadiene
# 1,2,3,4-tetrachlorobenzene
# 1,2,3,5-tetrachlorobenzene
# 1,2,3,6,7,8-hexachlorodibenzo-p-dioxin
# 1,2,3,7,8-pentachlorodibenzo-p-dioxin
# 1,2,3-trichloro-4-methoxybenzene
# 1,2,3-trichlorobenzene
# 1,2,3-trichloropropane
# 1,2,4,5-tetrachlorobenzene
# 1,2,4,5-tetramethylbenzene
# 1,2,4-triazin-3-amine, 5,6-dimethyl-
# 1,2,4-trichlorobenzene
# 1,2,4-trimethylbenzene
# 1,2,6-hexanetriol
# 1,2-benzenediamine
# 1,2-benzenedicarboxylic acid, heptyl nonyl ester, branched and linear
# 1,2-benzenediol, 4-methyl-
# 1,2-benzisothiazol-3(2h)-one
# 1,2-diaminoethane
# 1,2-diaminopropane
# 1,2-dibenzoyl-1-tert-butylhydrazine
# 1,2-dibromo-3-chloropropane
# 1,2-dichlorocyclohexane -trans
# 1,2-dichloroethene (trans)
# 1,2-dichloroethylene
# 1,2-dichloropropane
# 1,2-dichloropropane & 1,3-dichloropropene
# 1,2-dicyanobenzene
# 1,2-dihydronaphthalene
# 1,2-dimethyl-3-nitrobenzene
# 1,2-dimethyl-4-nitrobenzene
# 1,2-dimethylcyclohexane
# 1,2-dimethylcyclohexane (cis)
# 1,2-dimethylcyclohexane (trans)
# 1,2-ethanediol, monoacetate
# 1,2-naphthalenedione
# 1,2-propanediol
# 1,3,5,-trinitrohexahydro-1,3,5-triazine
# 1,3,5-trichlorobenzene
# 1,3,5-trimethylbenzene
# 1,3,5-trinitrobenzene
# 1,3,5-trioxane
# 1,3-benzenediol, 2,4,6-trinitro-, lead(2+) salt (1:1)
# 1,3-benzenediol, 4,6-dichloro-
# 1,3-butanedione, 1-phenyl-
# 1,3-dibromopropane
# 1,3-dichloro-2-propanol
# 1,3-dichlorobenzene
# 1,3-dichloropropane
# 1,3-dichloropropene
# 1,3-dichloropropene, (z)
# 1,3-dicyanobenzene
# 1,3-dimethoxy-2-methylbenzene
# 1,3-dimethylcyclohexane
# 1,3-dimethylnapthalene
# 1,3-dinitrobenzene
# 1,3-dioxalane
# 1,3-propanediamine
# 1,3-propanediamine, n,n,n',n'-tetramethyl-
# 1,3-propanediamine, n-9-octadecenyl-, (z)-
# 1,3-propanediol
# 1,3-propanediol, 2-bromo-2-nitro-
# 1,4-benzenediol, 2-(1,1-dimethylethyl)-
# 1,4-benzodioxan
# 1,4-benzoquinone
# 1,4-diazabicyclo(2,2,2)octane  (dabco)
# 1,4-dichlorobenzene
# 1,4-dichlorobutane
# 1,4-dihydroxy-9,10-anthracenedione
# 1,4-dimethylcyclohexane
# 1,4-dioxane
# 1,4-dithiane
# 1,4-dithiothreitol
# 1,4-naphthalenedione, 5-hydroxy-2-methyl-
# 1,4-naphthoquinone
# 1,4-piperazinedipropanamine
# 1,5,9-cyclododecatriene
# 1,5-diaminonaphthalene
# 1,5-dichloropentane
# 1,5-dimethylnaphthalene
# 1,5-hexadien-3-ol
# 1,6-hexanediamine, n,n,n',n'-tetramethyl-
# 1,8-cineole
# 1,8-naphthalenediamine
# 1,9-decadiene
# 1-(2-naphthalenyl)ethanone
# 1-amino-2-propanol
# 1-bromo-n-nonane
# 1-bromobutane
# 1-bromodecane
# 1-bromoheptane
# 1-bromohexane
# 1-bromooctane
# 1-chloro-2-nitro-propane
# 1-chloro-2-propanol
# 1-chloro-3-bromopropane
# 1-chlorobutane
# 1-chlorododecane
# 1-chloronaphthalene
# 1-decanol
# 1-ethoxy-naphthalin
# 1-ethynyl cyclohexanol
# 1-heptadecanamine
# 1-heptanol
# 1-heptanol, 6-methyl-
# 1-heptene
# 1-hexadecanamine, n,n-dimethyl-
# 1-hexadecanol, hydrogen sulfate, sodium salt
# 1-hexanamine, n-hexyl-
# 1-hexanol
# 1-hexen-3-ol
# 1-hydroxy-2(1h)-pyridinethione sodium salt
# 1-iodohexadecane
# 1-methyl-pyrrolidine
# 1-methylnapthalene
# 1-naphthalenamine, n-ethyl-
# 1-naphthalenecarbonitrile
# 1-naphthalenemethanol
# 1-naphthol
# 1-nitro-4-cyanobenzene
# 1-nitronaphthalene
# 1-nitroso-2-naphthol
# 1-nonanol
# 1-octanamine, n,n-dimethyl-
# 1-octanamine, n-methyl-n-octyl-
# 1-octanol
# 1-pentanal
# 1-pentanamine, n,n-dipentyl-
# 1-phenyl-3-ethyl thiourea
# 1-piperazineethanamine
# 1-piperazineethanol
# 1-piperidinyloxy, 2,2,6,6-tetramethyl-4-oxo-
# 1-piperoyl-(e,e)-piperidine
# 1-propanethiol
# 1-propanone, 1-(4-aminophenyl)-
# 1-tetradecanamine
# 1-tetradecanol, hydrogen sulfate, sodium salt
# 1-tridecanamine
# 1-tridecanol
# 1-undecanol
# 1h-benzimidazole, 5-nitro-
# 1h-imidazole, 1-(phenylmethyl)-
# 1h-imidazole, 2-methyl-
# 1h-imidazole-5-carboxylic acid, 1-(1-phenylethyl
# 1h-indazol-5-amine
# 1h-indazole, 5-nitro-
# 1h-indole-3-propanoic acid
# 1h-purin-6-amine, n-(phenylmethyl)-
# 2(2-butoxyethoxy)ethylthiocyanate
# 2,2,2-trichloroethanol
# 2,2,2-trifluoroethanol
# 2,2,5,5-tetramethyl-tetrahydrofuran
# 2,2-bis(4-hydroxy-3,5-dibromophenyl)propane
# 2,2-dibromo-2-cyanoacetamide
# 2,2-dimethyl butyric acid
# 2,2-dimethyl propanoic acid
# 2,2-dimethyl-1-propylamin
# 2,3',4,4',5-pentachlorodiphenyl ether
# 2,3,3',4,4'-pentachlorodiphenylether
# 2,3,4'-trichlorobiphenyl
# 2,3,4,5,6-pentachlorpyridine
# 2,3,4,5,6-pentafluoroaniline
# 2,3,4,5-tetrachloroaniline
# 2,3,4,5-tetrachlorophenol
# 2,3,4,6-tetrachlorophenol
# 2,3,4-trichloroaniline
# 2,3,4-trichlorophenol
# 2,3,4-trimethoxyacetophenone
# 2,3,5,6-tetrachloroaniline
# 2,3,5,6-tetrachloronitrobenzene
# 2,3,5,6-tetrachlorophenol
# 2,3,5-trichlorophenol
# 2,3,5-trimethylnaphthalene
# 2,3,5-trimethylphenol
# 2,3,6-trichloroanisole
# 2,3,6-trichlorobenzoic acid
# 2,3,6-trichlorophenol
# 2,3,6-trichlorophenylacetic acid, sodium salt
# 2,3,6-trimethylphenol
# 2,3,7,8-tetracdf
# 2,3-dibromo-1-propanol
# 2,3-dichloronitrobenzene
# 2,3-dichlorophenol
# 2,3-dichloropropene
# 2,3-dihydrobenzofuran
# 2,3-dimethyl-1,3-butadiene
# 2,3-dimethylaniline
# 2,3-dimethylnapthalene
# 2,3-dimethylphenol
# 2,3-dinitrotoluene
# 2,3-naphthalenediamine
# 2,4'-dichloroacetophenone
# 2,4'-dichlorobiphenyl
# 2,4,5,2',5'-pentachlorobiphenyl
# 2,4,5-t triethylammonium salt
# 2,4,5-t, butoxyethyl ester
# 2,4,5-t, isooctyl ester
# 2,4,5-t, isopropyl ester
# 2,4,5-t, n-butyl ester
# 2,4,5-tribromoimidazole
# 2,4,5-trichloroaniline
# 2,4,5-trichlorophenol
# 2,4,5-trichlorophenoxyacetic acid
# 2,4,6-tri(tert-butyl)phenol
# 2,4,6-tribromophenol
# 2,4,6-trichloro-3-methylphenol
# 2,4,6-trichloroaniline
# 2,4,6-trichloroanisole
# 2,4,6-trichlorophenol
# 2,4,6-triiodophenol
# 2,4,6-trimethylphenol
# 2,4,6-trinitroresorcinol
# 2,4,6-trinitrotoluene
# 2,4-d, 2-ethylhexyl ester
# 2,4-d, butoxyethyl ester
# 2,4-d, butoxypropyl ester
# 2,4-d, butyl ester
# 2,4-d, ethyl ester
# 2,4-d, isooctyl ester
# 2,4-d, isopropyl ester
# 2,4-d, propylene glycol butylether ester
# 2,4-d, sodium salt
# 2,4-diaminoazobenzene
# 2,4-diaminotoluene
# 2,4-dichloro-6-nitrophenol
# 2,4-dichloroaniline
# 2,4-dichlorobenzaldehyde
# 2,4-dichlorodiphenyl ether
# 2,4-dichloronitrobenzene
# 2,4-dimethoxy-6-hydroxy-benzaldehyd
# 2,4-dimethoxybenzaldehyd
# 2,4-dimethyl-3-pentanol
# 2,4-dimethylaniline
# 2,4-dimethylphenol
# 2,4-dinitro-5-methylphenol
# 2,4-dinitroaniline
# 2,4-dinitrochlorobenzene
# 2,4-dinitrophenol
# 2,4-dinitrotoluene
# 2,4-hexadiene
# 2,4-imidazolidinedione, 5,5-dimethyl-
# 2,4-pentadienenitrile
# 2,4-pentanedione
# 2,4-toluene diisocyanate
# 2,5-diaminotoluene
# 2,5-dichloroaniline
# 2,5-dichloronitrobenzene
# 2,5-dichlorophenol
# 2,5-dimethyl-2,4-hexadiene
# 2,5-dimethylphenol
# 2,5-dinitrophenol
# 2,5-dinitrotoluene
# 2,5-thiophenyl-thiophene
# 2,6-di-t-butyl-4-methylphenol (bht)
# 2,6-dichloro-4-nitroaniline
# 2,6-dichloroaniline
# 2,6-dichlorobenzamide
# 2,6-dichlorobenzoic acid
# 2,6-dichlorophenol
# 2,6-dimethyl-1,3-dioxan-4-ol acetate
# 2,6-dimethylnaphthalene
# 2,6-dimethylphenol
# 2,6-dimethylquinoline
# 2,6-dinitroaniline
# 2,6-dinitrophenol
# 2,6-dintrotoluene
# 2,6-diphenylpyridine
# 2,6-naphthalenediol
# 2,6-xylidine
# 2,7-naphthalenediol
# 2-(1,3-dihydro-3-oxo-2h-indol-2-ylidene)-1,2-di*
# 2-(1-methylethyl)-4,6-dinitrophenol
# 2-(bis(1-methylethyl)amino)ethanol
# 2-(chloromethyl)-3-chloro-1-propene
# 2-(diethylamino)-ethanol
# 2-(dimethylamino)ethyl 2-methyl-2-propenoate
# 2-acetylaminofluorene
# 2-allyl-4-chloro-phenol
# 2-amino-1,3,4-thiadiazole
# 2-amino-4,6-dinitrophenol
# 2-amino-4,7(3h,8h)-pteridinedione
# 2-amino-4-nitroaniline
# 2-amino-5-methylbenzenesulfonic acid
# 2-aminobenzimidazole
# 2-aminopyridine
# 2-anthracenesulfonic acid, 1-amino-9,10-dihydro-9,10-dioxo-4-(phenylamino)-, monosodium salt
# 2-benzylpyridine
# 2-butanone oxime
# 2-butenedioic acid (e)-, dibutyl ester
# 2-butenedioic acid (e)-, diethyl ester
# 2-butyn-1-ol
# 2-butyne-1,4-diol
# 2-chloro-1-nitrobenzene
# 2-chloro-4,6-diamino-s-triazine
# 2-chloro-4-nitroaniline
# 2-chloro-4-nitrotoluene
# 2-chloro-n,n-diallylacetamide
# 2-chloroacetophenone
# 2-chloroaniline
# 2-chloroethanol
# 2-chloroethyl vinyl ether
# 2-chlorophenol
# 2-chloropyridine
# 2-cyanopyridine
# 2-cyclohexyl-4,6-dinitrophenol
# 2-decanone
# 2-dibutylaminoethanol
# 2-dimethylaminopyridine
# 2-ethoxyethyl methacrylate
# 2-ethyl-1,3-hexandiol
# 2-ethyl-1-hexanol
# 2-ethylbutyric acid
# 2-ethylhexyl acrylate
# 2-ethylhexyl diphenyl phosphate
# 2-ethylhexylamine
# 2-ethylpyridine
# 2-furaldehyde, 5-hydroxymethyl-
# 2-heptadecyl-2-imidazoline acetate
# 2-heptanone
# 2-hexanol
# 2-hexanone
# 2-hydroxy-4-methoxy-acetophenon
# 2-hydroxy-propionic acid isopropyl ester
# 2-hydroxyanthraquinone
# 2-hydroxyethyl acrylate
# 2-hydroxyethyl methacrylate
# 2-hydroxymethylfuran
# 2-hydroxypropanenitrile
# 2-hydroxypropyl acrylate
# 2-hydroxypyridine
# 2-imidazolidinone
# 2-iodobutane
# 2-mercaptobenzothiazole
# 2-methoxyethanol
# 2-methoxyethyl acetate
# 2-methyl-1,4-naphthoquinone
# 2-methyl-2,4-pentanediol
# 2-methyl-2-butanol
# 2-methyl-3-butyn-2-ol
# 2-methyl-4-chlorophenol
# 2-methyl-6-chlorophenol
# 2-methyl-6-nitrobenzeneamine
# 2-methylanthracene
# 2-methylbutanal
# 2-methylcyclohexanone
# 2-methylfuran
# 2-methylnaphthalene
# 2-methylpentaldehyde
# 2-methylpyridine
# 2-methylquinoline
# 2-naphthalenamine, 1-(phenylazo)-
# 2-naphthalenesulfonic acid, sodium salt
# 2-naphthol
# 2-nitro-p-toluidine
# 2-nitroaniline
# 2-nitroanisole
# 2-nitrophenol
# 2-nonanone
# 2-nonynoic acid
# 2-octanol
# 2-octanone
# 2-pentanamine, 2,4,4-trimethyl-
# 2-pentanone
# 2-phenethylisothiocyanate
# 2-phenoxyethanol
# 2-phenylphenol, sodium salt
# 2-phenylpyridine
# 2-propanol, 1,1'-oxybis-
# 2-propanol, 1-chloro-, phosphate (3:1)
# 2-propanone, oxime
# 2-propenoic acid, 1,1-dimethylethyl ester
# 2-propenoic acid, 2-(dimethylamino)ethyl ester
# 2-propenoic acid, hexyl ester
# 2-propynoic acid
# 2-pyridinamine, 5-nitro-
# 2-pyridinecarboxyaldehyde
# 2-pyridineethanol
# 2-pyridinemethanol
# 2-pyridinemethanol, 6-[2-(5-nitro-2-furanyl)ethe
# 2-thiouracil
# 2-tridecanone
# 3,3',4,4'-tetrachlorobiphenyl ether
# 3,3'-dichlorobenzidine
# 3,3'-dimethylbenzidine
# 3,3-dimethyl-2-butanol
# 3,3-dimethyl-2-butanone
# 3,4,5-trichloro-2-methoxyphenol
# 3,4,5-trichlorocatechol
# 3,4,5-trichlorophenol
# 3,4,5-tricl-2,6-meo phenol
# 3,4-dichloro-1-butene
# 3,4-dichloroaniline
# 3,4-dichlorobenzyl methylcarbamate
# 3,4-dichloronitrobenzene
# 3,4-dichlorophenol
# 3,4-dichlorotoluene
# 3,4-dimephenyl n-methylcarbamate
# 3,4-dimethylphenol
# 3,4-dinitrotoluene
# 3,4-xylidine
# 3,5,6-trichloro-2-pyridinol
# 3,5-bis(tert-butyl)phenol methylcarbamate
# 3,5-dibromsalicylaldehyd
# 3,5-dichloroaniline
# 3,5-dichloroanisole
# 3,5-dichlorophenol
# 3,5-dichloropyridine
# 3,5-dimethoxyphenol
# 3,5-dimethylaniline
# 3,5-dimethylphenol
# 3,5-dinitroaniline
# 3,5-dinitrotoluene
# 3,6-diamino-10-methyl-acridinium chloride
# 3,6-dithiaoctane
# 3-(hexahydro-4,7-methanoindan-5-yl)-1,1-dimethy*
# 3-amino-2,5-dichlorobenzoic acid
# 3-aminobenzoylhydrazine
# 3-aminopyridine
# 3-aminoquinoline
# 3-benzylpyridine
# 3-bromo-1-propene
# 3-bromo-d-camphor
# 3-bromothiophene
# 3-buten-2-one, 4-(2,6,6-trimethyl-1-cyclohexen-1-yl)-, (e)-
# 3-butenenitrile
# 3-butyn-1-ol
# 3-butyn-2-ol
# 3-butyn-2-one
# 3-chloro-1,2-propanediol
# 3-chloro-1-propanol
# 3-chloro-2-methylpropene
# 3-chloro-4-methylacetanilide
# 3-chloro-dimethyl parathion
# 3-chloro-nitrobenzene
# 3-chloro-p-toluidine
# 3-chloroaniline
# 3-chlorophenol
# 3-chloropropionic acid
# 3-chloropyridine
# 3-cyano-1-nitrobenzene
# 3-cyanopyridine
# 3-ethyl-5-methylphenol
# 3-formylpyridine
# 3-hexanol
# 3-hexen-1-ol, (z)-
# 3-hydroxyflavone
# 3-hydroxymethylfuran
# 3-hydroxypyridine
# 3-i-pr-5-mephenyl-n-me carbamate
# 3-indolebutyric acid
# 3-isothiocyanato-1-propene
# 3-me-4'-no2-diphenyl ether
# 3-methyl-1-butanal
# 3-methyl-2-butanamine
# 3-methyl-2-butanone
# 3-methyl-2-nitrophenol
# 3-methyl-3-pentanol
# 3-methyl-4-chlorophenol
# 3-methyl-4-nitrophenol
# 3-methyl-dimethyl para-oxon
# 3-methylbenzenethiol
# 3-methylcholanthrene
# 3-methylindole
# 3-nitro-4-toluidine
# 3-nitro-o-toluidine
# 3-nitroaniline
# 3-nitrophenol
# 3-nitrotoluene
# 3-octanone
# 3-pentanol
# 3-pentanone
# 3-phenoxybenzaldehyde
# 3-phenyl-n-butyric acid
# 3-phenylpyridine
# 3-pyridinecarboxamide, n-[(phenylamino)carbonyl]
# 3-pyridinemethanol
# 3-pyridinepropanol
# 3-trifluoromethyl-4-nitrophenol
# 3-trifluoromethylaniline
# 4(1h)-pyrimidinone, 6-methyl-2-(1-methylethyl)-
# 4,4'-biphenol
# 4,5,6-trichloroguaiacol
# 4,5-dichloro-2-methoxyphenol
# 4,5-dithiaoctane
# 4,6-dichloro-o-cresol
# 4-(tert-butyl)pyridine
# 4-acetylpyridine
# 4-aminoacetophenone
# 4-aminoazobenzene
# 4-aminodiphenylamine
# 4-aminopyridine
# 4-aminoquinoline-1-oxide
# 4-benzoylpyridine
# 4-benzylpyridine
# 4-bromo-1-nitrobenzene
# 4-bromobenzonitrile
# 4-bromophenyl phenyl ether
# 4-chlorcatechol
# 4-chloro-2-methyl-1-nitro-benzene
# 4-chloro-2-nitroaniline
# 4-chloro-3,5-dimethyl phenol
# 4-chloroaniline
# 4-chloroanisole
# 4-chlorobenzaldehyde
# 4-chlorophenol
# 4-chlorophenyl benzenesulfonate
# 4-chlorophenyl phenyl ether
# 4-chlororesorcinol
# 4-cyanopyridine
# 4-decylaniline
# 4-dimethylaminopyridine
# 4-ethylbenzyl alcohol
# 4-ethylnitrobenzene
# 4-ethylpyridine
# 4-fluoroaniline
# 4-fluoronitrobenzene
# 4-formylpyridine
# 4-hydroxy-3-methoxybenzoic acid
# 4-hydroxy-4-methyl-2-pentanone
# 4-hydroxypyridine
# 4-iodophenol
# 4-methyl-2,6-dichlorophenol
# 4-methyl-2-methoxyphenol
# 4-methyl-2-nitrophenol
# 4-methyl-2-pentyl acetate
# 4-methylbenzonitrile
# 4-methyloxazol
# 4-methylpentanoic acid
# 4-methylpyridine
# 4-morpholineethanol
# 4-nitro diphenyl ether
# 4-nitro-2-toluidine
# 4-nitroaniline
# 4-nitrobenzaldehyde
# 4-nitrobenzamide
# 4-nitrophenol
# 4-nitropyridine
# 4-nitrotoluene
# 4-octylaniline
# 4-pentenoic acid
# 4-pentylphenol
# 4-pentynoic acid
# 4-phenylbutyric acid
# 4-phenylpyridine
# 4-propylphenol
# 4-pyridinealdoxime
# 4-pyridinemethanol
# 4-tert-butylbenzamide
# 4-tert-butylbenzyl alcohol
# 4-vinylpyridine
# 5,5-dimethyl-1,3-cyclohexanedione
# 5-aminoindole
# 5-aminoquinoline
# 5-chloro-2-(2,4-dichlorophenoxy)phenol
# 5-chlorouracil
# 5-ethyl-2-methylpyridine
# 5-fluorouracil
# 5-hepten-2-one, 6-methyl-
# 5-hydroxy-1,4-naphthoquinone
# 5-methyl-2-hexanone
# 5-methyl-2-nitrophenol
# 5-nitro-o-toluidine
# 5-nitrobenzotriazole
# 5-nitroquinoline
# 5-nonanone
# 5-phenylpentanoic acid
# 5-pyrimidinemethanol, ,alpha,-(2-chlorophenyl)-,
# 5-quinolinamine, 6-nitro-
# 6,8-dimethylquinoline
# 6-chloro-2-nitrophenol
# 6-chloro-2-picoline
# 6-chloropicolinic acid
# 6-nitroquinoline
# 6-nonenamide, n- (4-hydroxy-3-methoxyphenyl)meth
# 6-phenylcaproic acid
# 6-purinethiol hydrate
# 7-dodecen-1-ol (z)
# 7-oxabicyclo[2,2,1]heptane-2,3-dicarboxylic acid, dipotassium salt
# 9,10-anthracenedione, 1,8-dihydroxy-
# 9,10-dihydroanthracene
# 9,10-dihydrophenanthrene
# 9,10-phenanthrenedione
# 9-aminoacridine
# 9-methylanthracene
# 9-octadecen-1-amine, (z)-
# 9h-fluoren-9-ol
# 9h-fluorene-9-carboxylic aicd, 2-chloro-9-hydrox
# 9h-thioxanthen-9-one
# 9h-xanthen-9-one
# 9h-xanthene
# a,a,a-trifluor-m-tolunitril
# a,a,a-trifluor-o-tolunitril
# a-brom-2,5-dimethoxy-acetophenon
# a-endosulfan
# abate
# abietic acid
# acetaldehyde ammonia
# acetaldehyde oxime
# acetamide, 2,2-dichloro-
# acetamide, n-(4-hydroxyphenyl)
# acetanilide
# acetic acid, 1-(3,4-dichlorophenyl)-2,2,2-trichl
# acetic acid, 2,2'-oxybis-
# acetic acid, ammonium salt
# acetic acid, dibromo-
# acetic acid, sodium salt
# acetic acid, sulfo-
# acetic anhydride
# acetimidoylphosphoramidothioic acid, o,o-bis(p-chlorophenyl) ester
# acetoacetic ester
# acetone cyanohydrin
# acetophenone
# acetyl bromide
# acid black 52
# acid blue 113
# acridine
# acriflavine
# acrylamide
# adiponitrile
# aflatoxin b1
# alcohols, c12-14, ethoxylated
# aldicarb sulfone
# aldicarb sulfoxide
# alizarin cyanine green f
# alizarine
# alkane sulfonic acids (sodium salt)
# alkylbenzenesulfonic acid, sodium salt c10-c13
# allyl alcohol
# allyl methacrylate
# allylamine
# allylthiourea
# alpha-cedrene
# alpha-hch
# alpha-naphthyl methyl ketone
# alpha-naphthylamine
# alpha-phenylpropionic acid
# alpha-pinene
# amantadine
# aminocarb
# amitrole
# ammonium oxalate
# amobarbital
# amoxicillin
# ampicillin
# amprolium
# amycin hydrochloride
# amyl lactate
# ancymidol
# androstenedione
# anthrarobin
# antimycin a
# aphidan
# aramite
# aretan
# aroclor 1016
# aroclor 1221
# aroclor 1232
# aroclor 1242
# aroclor 1248
# aroclor 1254
# aroclor 1260
# aureomycin
# avermectin b1a
# azamethiphos
# azinphos ethyl
# aziridine
# azobenzene
# azocyclotin
# azulene
# b,b,b-trichloro-t-butanol
# barban
# basic yellow 2
# bendiocarb
# benfuracarb
# bensulide
# benz(a)acridine
# benz(c)acridine
# benzalacetophenone
# benzaldehyde, 2,4-dihydroxy-
# benzaldehyde, 2-hydroxy-, oxime
# benzaldehyde, 3-ethoxy-4-hydroxy-
# benzaldehyde, 4-(1-methylethyl)-
# benzaldehyde, 4-(diethylamino)-
# benzaldehyde, 4-(diethylamino)-2-hydroxy-
# benzaldehyde, 4-bromo-
# benzaldehyde, 4-ethoxy-
# benzaldehyde, 4-fluoro-
# benzaldehyde, 5-bromo-2-hydroxy-
# benzaldehyde, 5-chloro-2-hydroxy-
# benzamide
# benzamide, 2-amino-
# benzamide, 2-iodo-n-phenyl
# benzamide, 2-methyl-3,5-dinitro-
# benzenamine, 2,6-bis(1-methylethyl)-
# benzenamine, 2-chloro-4-methyl-
# benzenamine, 4-butyl-
# benzenamine, n-ethyl-3-methyl-
# benzene, (2-bromo-2-nitroethenyl)-
# benzene, (chloromethyl)ethenyl-
# benzene, 1,1'- sulfinylbis(methylene) bis-
# benzene, 1,1'-methylenebis-
# benzene, 1,2-dichloro-3-methoxy-
# benzene, 1,2-dimethoxy-4-methyl-
# benzene, 1,3-dichloro-2-methoxy-
# benzene, 1,3-dichloro-5-nitro-
# benzene, 1,4-bis(chloromethyl)-
# benzene, 1,4-diisothiocyanato-
# benzene, 1,5-dichloro-2,4-dinitro-
# benzene, 1-(1,1-dimethylethyl)-2-methoxy-4-methy
# benzene, 1-chloro-2-methyl-3-nitro-
# benzene, 1-chloro-4-methyl-2-nitro-
# benzene, 4-chloro-1-methyl-2-nitro-
# benzeneacetic acid, ,alpha,-ethyl-
# benzenemethanamine, n-(1-methylethyl)-
# benzenemethanamine, n-ethyl-
# benzenemethanol, ,alpha,-ethynyl-,alpha,-methyl-
# benzenemethanol, 2-chloro-
# benzenemethanol, 3-phenoxy-
# benzenemethanol, 4-(1-methylethyl)-
# benzenemethanol, 4-bromo-
# benzenemethanol, 4-fluoro-
# benzenepropanol, ,alpha,,,alpha,-dimethyl-
# benzenesulfonic acid
# benzenesulfonic acid, 4-amino-
# benzenesulfonic acid, 4-hydroxy-, monosodium salt
# benzenesulfonic acid, 5-(2h-naphtho[1,2-d]triazol-2-yl)-2-(2-phenylethenyl)-, sodium salt
# benzenesulfonic acid, dodecyloxydi-, disodium salt
# benzenesulfonyl chloride
# benzethonium chloride
# benzidine
# benzo(b)naphtho(1,2-d)thiophene
# benzo(b)thiophene
# benzo(b)thiophene s,s-dioxide
# benzo(f)quinoline
# benzo(h)quinoline
# benzo[b]thiophene, 5-methyl-
# benzofuran
# benzoic acid, 2,6-difluoro-
# benzoic acid, 2-[(aminomethoxyphosphinothioyl)ox
# benzoic acid, 4-(tert-butyl)-
# benzoic acid, sodium salt
# benzonitrile
# benzonitrile, 2-amino-5-chloro-
# benzonitrile, 4-chloro-
# benzonitrile, 4-fluoro-
# benzophenone
# benzothiazole
# benzotrichloride
# benzotrifluoride
# benzoyl chloride
# benzoyl isothiocyanate
# benzoylprop ethyl
# benzyl acetate
# benzyl benzoate
# benzyl chloride
# benzyl methacrylate
# benzyl trimethyl ammonium chloride
# benzylamine
# benzylisothiocyanate
# benzylmalonic acid, diethyl ester
# beta-cypermethrin isomer
# beta-hexachlorocyclohexane
# beta-phenylpropionic acid
# beta-pinene
# bicuculline
# bicyclo(2,2,1)hepta-2,5-diene
# bicyclo(2,2,1,)heptane
# bicyclo[2,2,1]-2-heptene
# bilanafos
# binapacryl
# bioresmethrin
# biphenyl
# bis (2-ethoxy ethyl)  ether
# bis(2-chloroethoxy)methane
# bis(2-chloroethyl)ether
# bis(2-ethylhexyl) sodium sulfosuccinate
# bis(2-ethylhexyl)adipate
# bis(2-ethylhexyl)phosphate
# bis(4-chlorophenyl) disulfide
# bis(8-quinolinolato-(n1,o8))copper
# bis(tri-n-butyltin) oxide
# bismark brown y
# bixin
# blasticidin-s
# bomyl
# borneol
# brilliant blue fcf
# brodifacoum
# bromoacetic acid
# bromobenzene
# bromochloromethane
# bromocyclohexane
# bromodichloromethane
# bromophos
# bromophos ethyl
# brucine
# bufencarb
# butachlor
# butamifos
# butanamide,2,2'-((3,3'-dicl(1,1'-biph)-4,4'-diyl)bis(azo)bis(n-4-cl-2,5-dimeoph)-3-oxo
# butane, 1,3-dibromo-
# butane, 1-iodo-3-methyl-
# butane, 1-isothiocyanato-
# butanedioc acid
# butanedioic acid, 2,2-dimethyl-
# butanedioic acid, dibutyl ester
# butanethiol
# butanoic acid, 2-methyl-, (,+-,)-
# butanoic acid, 3,3-dimethyl-
# butanoic acid, sodium salt
# butocarboxim
# butonate
# butyl acrylate
# butyl isocyanate
# butyl lactate
# butyl phenyl ether
# butyl trichloro tin
# butyl xanthate
# butylate
# butylated hydroxyanisole
# butylglycolyl butyl phthalate
# butyraldehyde
# butyric acid
# c,i, acid orange 24, monosodium salt
# c,i, acid violet 49, sodium salt
# c,i, basic green 4
# c,i, basic violet 1
# c,i, disperse blue 3
# c,i, vat blue 4
# cadmium stearate
# caffeine
# camphene
# caprolactam
# captafol
# carbamodithioic acid, dimethyl-, potassium salt
# carbazole
# carbofuran phenol
# carbonodithioic acid, o-(2-methylpropyl) ester, sodium salt
# carbonodithioic acid, o-ethyl ester, sodium salt
# carbonodithioic acid, o-pentyl ester, potassium salt
# carbophenothion-methyl
# carbophenthion
# carboxylic acids
# cartap
# catechol
# cellulose, nitrate
# cetrimonium bromide
# cetrimonium chloride
# chloramben, ammonium salt
# chloramben, methyl ester
# chloramine-b
# chloramine-t
# chloramphenicol
# chloranil
# chlordane
# chlordene
# chlordimeform
# chlorfenprop methyl
# chlorfenson
# chlormephos
# chlornitrofen
# chloroacetaldehyde
# chloroacetic acid, sodium salt
# chloroacetonitrile
# chlorobenzilate
# chlorocyclohexane
# chloromercuriphenol
# chloronaphthalene
# chlorothymol
# chlorotripropyl stannane
# chloroxuron
# chlorphoxim
# chlorpropham
# chlorthiamid
# chlorthiophos (main isomer)
# choral hydrate
# ci fluorescent brightener 260
# cis-chlordane
# cis-permethrin
# citric acid
# citrinin
# closantel
# cma
# coumachlor
# coumaphos
# coumarin
# cresol(s)
# cresyl diphenyl phosphate
# crotonaldehyde
# crotonic acid
# crotoxyphos
# crufomate
# crystal violet (basic violet 3)
# cumate
# cumene hydroperoxide
# cumylphenyl diphenyl phosphate
# curcumin
# cyanofenphos
# cyanophos
# cyclethrin
# cycloate
# cyclododecane
# cyclododecane, hexabromo-
# cycloheptane
# cycloheptatriene
# cycloheptene
# cyclohexanamine
# cyclohexanamine, n,n-diethyl-
# cyclohexane, iodo-
# cyclohexanol
# cyclohexanone
# cyclohexanone oxime
# cyclohexene
# cycloheximide
# cyclohexyl acetate
# cyclohexylmethylamine
# cycloocta-1,5-diene
# cyclooctane
# cyclopentanol
# cyclopentanone
# cyolane
# cyphenothrin
# cyprazine
# cyprofuram
# d-limonene
# dalapon
# dalapon (sodium salt)
# ddd
# dde
# decafluorobiphenyl
# decahydronaphthalene
# decanoic acid, na salt
# deet [n,n,-diet-3-me benzamide]
# delta-hexachlorocyclohexane
# demeton-s-methyl
# desethylatrazine
# desmetryne
# di(n-octyl) phthalate
# di-isobutylphthalate
# di-isopropyl ether
# di-n-butyl ether
# di-n-butyl phosphate
# di-n-butyl tin diacetate
# di-n-butyltin oxide
# di-n-octyl sodium sulfosuccinate
# di-n-pentylether
# di-n-propylsulfide
# diallate
# diallylamine
# diallylphthalate
# diazinon, o-analog
# dibenzofuran
# dibenzothiophene
# dibromoacetonitrile
# dibromochloromethane
# dibutyl dichloro tin
# dibutyl phenyl phosphate
# dibutylamine
# dibutyltin dilaurate
# dicamba sodium salt
# dicapthon
# dichlofenthion
# dichlone
# dichloroacetic acid
# dichlorobenzene
# dichloroethanes
# dichlorophenol
# dichlorprop-isooctyl
# dicoumarol
# dicyclohexyl
# dicyclohexylamine
# dicyclopentadiene
# didecyldimethylammonium chloride
# dieldrin
# diethyl disulfide
# diethyl maleate
# diethyl malonate
# diethyl sebacate
# diethyl succinate
# diethylacetamide
# diethylcarbamodithioic acid, sodium salt
# diethylene diglycol, dinitrate
# diethylene glycol mono-n-butyl ether
# diethylene glycol monomethyl ether
# diethylene glycol, monoethyl ether
# diethylenetriamine
# diethylenetriaminepentaacetic acid
# diethylenetriaminepentaacetic acid, penta sodiu*
# diethylhexanedioate
# diethylphthalate (dep)
# diethylstilbestrol
# difenacoum
# difenoxuron
# difenzoquat
# difenzoquat metilsulfate
# dihexyl phthalate
# diisobutylamine
# diisononyl phthalate
# diisopropanolamine
# diisopropyl paraoxon
# diisopropylamine
# dilan
# dimethamrtryne
# dimethirimol
# dimethoxon
# dimethoxymethane
# dimethrin
# dimethyl arsine
# dimethyl diethoxysilane
# dimethyl dioctadecylammonium chloride
# dimethyl phosphite
# dimethyl sulfate
# dimethyl sulfoxide
# dimethyl tetrachloroterephthalate
# dimethyldiallylammonium chloride
# dimethyldithiocarbamic acid, sodium salt
# dimethylnaphthalene (mixture of isomers)
# dimethylphenol phosphate (3:1)
# dimethylsulfide
# dimethyltin dichloride
# dimetilan
# dimite
# dinitramine
# dinitrophenol
# dinobuton
# dinoseb acetate
# dinoterb
# dioxacarb
# dioxathion
# dioxolane
# diphenamid
# diphenyl disulfide
# diphenyl nitrosamine
# diphenyl phthalate
# diphenyl sulfoxide
# diphenylamine
# diphenylchloroarsine
# diphenyltin dichloride
# dipropyl phthalate
# disodium 4,4'-bis(2-sulfostyryl)biphenyl
# disulfiram
# disulfoton sulfoxide
# diundecyl phthalate
# dmpa
# dodecanoic acid, pentachlorophenyl ester
# dodecyl 2-methyl-2-propenoate
# dodecyl benzenesulfonate
# dodecyl sulfate, sodium salt
# dodecyl sulfonate, sodium salt
# dodecylbenzene
# dodecylbenzenesulfonic acid
# dodecylbenzenesulfonic acid, calcium salt
# dodecylbenzenesulfonic acid, na salt
# dodecyltrimethylammonium chloride
# dopa
# edifenphos
# edta, sodium salt
# empenthrin
# endosulfan (beta)
# endosulfan sulfate
# endrin
# endrocide (endox) (coumatetralyl)
# enrofloxacin
# epn
# erbon
# eriochrome black t
# erythromycin
# erythrosine
# estradiol
# estrone
# ethanamine, 2-methoxy-
# ethanol, 2- ethyl(3-methylphenyl)amino -
# ethanol, 2-(ethylamino)-
# ethanol, 2-(ethylthio)-
# ethanol, 2-mercapto-
# ethanone, 1-(2,4-dichlorophenyl)-
# ethene, tribromo-
# ethidimuron
# ethinyl estradiol
# ethion
# ethopabate
# ethoxychlor
# ethoxyethylacetate
# ethoxyquin
# ethyl 2-hydroxybenzoate
# ethyl acrylate
# ethyl amylketone
# ethyl benzoate
# ethyl carbamate
# ethyl chloroacetate
# ethyl hexanoate
# ethyl isothiocyanate
# ethyl lactate
# ethyl mercuric phosphate
# ethyl methacrylate
# ethyl oxalate
# ethyl propionate
# ethyl ziram
# ethylbutyrate
# ethylcyclohexane
# ethylene dibromide
# ethylene glycol
# ethylene glycol diacetate
# ethylene glycol, monobutyl ether
# ethylenediamine tetraacetic acid
# ethylenethiourea
# ethylmercury chloride
# ethyrimol
# etofenprox
# etrimfos
# eugenol
# exo-norborneol
# fenac
# fenaminosulf
# fenarimol
# fenchlorazole-ethyl
# fensulfothion
# fenthion
# fenthoate
# fenuron
# fenvalerate
# ferbam
# ferrate(1-), [n-[2-[bis(carboxymethyl)amino]ethyl]-n-(2-hydroxyethyl)glycinato(3-)]-, sodium
# flamprop-methyl
# flavone
# fluazifop - butyl
# fluchloralin
# flucycloxuron,(e)-isomer
# flucythrinate
# flumequine
# fluorenone
# fluorescein sodium
# fluoroacetic acid
# fluorobenzene
# fluorodifen
# flurenol-butyl
# fluridone
# fluvalinate
# formamide, n,n-diphenyl-
# formothion
# fospirate
# fulenetil
# fumaric acid
# fumaryl chloride
# furan, 2,5-dimethyl-
# furazolidone
# gamma-decalactone
# geraniol
# glycerol
# glycine, n,n'-1,2-ethanediylbis[n-(carboxymethyl)-, diammonium salt
# glycine, n,n'-1,2-ethanediylbis[n-(carboxymethyl)-, tetraammonium salt
# glycine, n- 2- bis(carboxymethyl)amino ethyl -n-(2-hydroxyethyl)-
# glycydyltrimethylammonium chloride
# glyoxal
# glyphosate-isopropylammonium
# guaiacol
# guinea green b
# halothane
# haloxyfop-etotyl
# harmaline
# heptachlor
# heptachlor epoxide
# heptachloronorbornene
# heptanoic acid
# heptylamine
# hexabromobenzene
# hexachlorobutadiene
# hexachlorocyclopentadiene
# hexachloroprene
# hexamethylenetetramine
# hexamethylphosphoramide
# hexanal
# hexanedioic acid
# hexanedioic acid, dibutyl ester
# hexanoic acid
# hexanoic acid, 2-ethyl-
# hydrargaphen
# hydrazobenzene
# hydroquinone
# hydroxyurea
# i-nicotinamide
# i-nicotinic acid, methyl ester
# ibp (iprobenfos)
# imazamethabenz (isomer mix)
# imazapyr-isopropylammonium salt
# indan
# indazole
# indole
# indole, 5-nitro
# indole-3-acetic acid
# iodofenphos
# iodoform
# ioxynil-sodium
# ipt (isoprothiolane)
# irgarol 1051
# isoamyl acetate
# isobenzan
# isobutyl acrylate
# isobutyric acid
# isodecanol
# isodecyl diphenyl phosphate
# isodrin
# isofenphos
# isoflurophate
# isolan
# isoniazid
# isonicotinic acid
# isononyl alcohol
# isooctadecanol
# isooctyl alcohol
# isophorone
# isophorone diamine
# isopimaric acid
# isoprocarb
# isopropalin
# isopropyl acetate
# isopropyl disulfide
# isopropyl methacrylate
# isopropyl phenyl diphenyl phosphate
# isopropylxanthic acid, sodium salt
# isoquinoline
# isothioate
# isovaleric acid
# isoxathion
# kepone
# l-arabinose
# l-lactic acid
# leptophos
# lethane 60
# lignosulfonic acid, ammonium salt
# lignosulfonic acid, sodium salt
# limonene
# longifolene
# m-(trifluoromethyl)benzaldehyde
# m-bromobenzamide
# m-chloroanisole
# m-chlorobenzoic acid
# m-chlorobenzyl alcohol
# m-cresol
# m-diethylbenzene
# m-hydroxyacetanilide
# m-hydroxybenzoic acid
# m-methoxyaniline
# m-methoxyphenol
# m-nitrobenzaldehyde
# m-nitrobenzenesulfonic acid, sodium salt
# m-phenoxybenzoic acid
# m-t-butylphenyl n-methylcarbamate
# m-toluidine
# m-trifluoromethylphenol
# malaoxon
# maleic acid
# malonic acid
# malononitrile
# mcpa - sodium salt
# mcpa-thioethyl
# mcpb-ethyl
# mcpb-sodium
# mebendazole
# mecarbam
# mecoprop, potassium salt
# mefenacet
# melamine
# menthol (l)
# mercaptoacetic acid
# merphos
# metaldehyde (tetramer)
# metanil yellow
# methacrylic acid
# methacrylic acid, n-butyl ester
# metham (acid)
# methoproptryne
# methoxybenzene
# methoxychlor
# methoxyflurane
# methyl (3,4-dichlorophenyl)carbamate
# methyl 2,4-dihydroxybenzoate
# methyl 2,5-dichlorobenzoate
# methyl 4-chloro-2-nitrobenzoate
# methyl anthranilate
# methyl chloroacetate
# methyl decyl ketone
# methyl isothiocyanate
# methyl methacrylate
# methyl naphthalenes (mixture of isomers)
# methyl p-chlorobenzoate
# methyl p-nitrobenzoate
# methyl paraoxon
# methyl pentynol
# methyl propionate
# methylcyclohexane
# methylene bisthiocyanate
# methylene blue
# methyleugenol
# methylhydrazine
# methylmecaptophos
# methylmercury dicyandiamide
# methylsulfonyl chloride
# methylvinylketone
# metomidate
# metoxuron
# metronidazole
# mexacarbate
# mirex
# monuron
# mordant blue 13
# morpholine
# morpholine, 2,6-dimethyl-
# myristyltrimethylammonium bromide
# n,n'-dimethylformamide
# n,n'-dinitrosopiperazine
# n,n,4-trimethylaniline
# n,n,n-trimethylmethanaminium, chloride
# n,n-dibutylthiourea
# n,n-diethylaniline
# n,n-diethylthiourea
# n,n-dimethylaniline
# n,n-dimethylbenzylamine
# n,n-dimethyldodecylamine
# n,n-dimethylthiourea
# n-allyl-anilin
# n-butyl propionate
# n-butylamine
# n-butylbenzene
# n-butylbutyrate
# n-decane
# n-decylamine
# n-dodecylamine
# n-ethylaniline
# n-ethylthiourea
# n-hexadecylamine
# n-hexyl acetate
# n-hexylamine
# n-me-2-chlorophenylcarbamate
# n-me-3,4,5-trimephenyl carbamate
# n-methyl o-(3-iprphenyl)carbamate
# n-methyl o-sec-butyl phenyl carbamate
# n-methyl-m-tolylcarbamate
# n-methyl-n-nitrosourea
# n-methylaniline
# n-methylthiourea
# n-nitrosodiethylamine
# n-nitrosodimethylamine
# n-nonylamine
# n-nonylphenol
# n-octane
# n-octylamine
# n-pentylamine
# n-phenyl-2-naphthylamine
# n-phenylthiourea
# n-propylbenzene
# n-undecylamin
# nabam
# naphthalene, 2-methoxy-
# naphthalene-2-sulfonic acid
# naphthaleneacetic acid
# neotran
# nerolidol
# niclosamide
# niclosamide ethanolamine salt
# nicotinamide
# nicotine
# nicotine sulfate
# nicotinic acid
# nitralin
# nitrapyrin
# nitrilotriacetic acid
# nitrofen
# nitrofurazone
# nitroglycerin
# nonanoic acid
# nonanonitrile
# nonylphenol
# norea
# o,p'-ddt
# o-anisidine
# o-bromoaniline
# o-bromonitrobenzene
# o-bromophenol
# o-chloroanisole
# o-chlorobenzylidenemalononitrile
# o-cresol
# o-decylhydroxylamine
# o-dibromobenzene
# o-diethylbenzene
# o-dinitrobenzene
# o-ethyl o-(p-(methylthio)phenyl) methyl phospho*
# o-ethylaniline
# o-fluorotoluene
# o-hydroxyacetanilide
# o-hydroxybenzaldehyde
# o-hydroxybenzamide
# o-nitrobenzaldehyde
# o-phthalic acid
# o-sec-butylphenol
# o-t-butylphenol
# o-toluidine
# o-vanillin
# oct-2-ynoic acid
# octadecylamine
# octahydro-1,3,5,7-tetranitro-1,3,5,7-tetrazoc*
# octamethylpyrophosphoramide
# octamethyltetrasiloxane
# octanedinitrile
# octanohydroxamic acid
# octanoic acid, sodium salt
# octoxynol
# ohric
# oleic acid
# orange ii
# oxadiazon
# oxalic acid
# oxalic acid dihydrate
# oxirane,   (2-ethylhexyl)oxy methyl -
# oxirane,  (2-propenyloxy)methyl -
# oxiranemethanol
# oxolinic acid
# oxycarboxin
# oxychlordane
# oxytetracylcine
# oxythioquinox
# p,p'-dde
# p,p'-ddt
# p-(1,1,3,3-tetramethylbutyl)phenol
# p-(sec-butyl)phenol
# p-(t-butyl)toluene
# p-aminobenzoic acid, ethyl ester
# p-anisidine
# p-bromoaniline
# p-bromophenol
# p-chlorobenzyl alcohol
# p-chloronitrobenzene
# p-chlorophenoxyacetic acid
# p-chlorophenylurea
# p-chlorotoluene
# p-cresol
# p-cyanophenol
# p-cymene
# p-dibutylterephthalate
# p-dimethoxybenzene
# p-dinitrobenzene
# p-dodecylaniline
# p-ethylaniline
# p-ethylphenol
# p-fluorophenol
# p-hydroxyacetophenone
# p-hydroxybenzoic acid
# p-hydroxybenzyl alcohol
# p-isopropylphenol
# p-methoxyphenol
# p-methyl benzyl alcohol
# p-nitroanisole
# p-nitrophenetole
# p-nonylphenol
# p-phenylazophenol
# p-phenylenediamine
# p-phenylphenol
# p-t-butylyphenol
# p-tolualdehyde
# p-toluidine
# p-xylene
# paclobutrazol
# palustric acid
# paraoxon
# paraquat dichloride
# parathion-amino
# paromomycin
# pcb-1
# pcb-15
# pcb-155
# pcb-18
# pcb-2
# pcb-29
# pcb-3
# pcb-47
# pcb-7
# pcb-77 (3,3',4,4'-tetrachlorobiphenyl)
# pcbs
# pebulate
# pentabromophenol
# pentachloroaniline
# pentachloroanisole
# pentachlorobenzyl alcohol
# pentachloroethane
# pentachlorophenol, na salt
# pentadecylamine
# pentaerythritol
# pentaerythritol tetranitrate
# pentafluor-benzaldehyd
# pentafluorophenol
# pentafluorothiophenol
# pentanedioic acid, 3,3-dimethyl-
# pentanochlor
# pentanoic acid
# pentanoic acid, 2-methyl-
# pentobarbital sodium
# pentyl acetate
# pentylbenzene
# peracetic acid
# phenanthrene, 1-methyl-7-(1-methylethyl)-
# phenanthridine
# phenazine
# phenkapton
# phenobarbital
# phenol, 2,4-dichloro-, sodium salt
# phenol, 2-(2-propenyl)-
# phenol, 2-amino-4-methyl-
# phenol, 3-(1,1-dimethylethyl)-
# phenol, 3-amino-
# phenol, 4,4'-(1-methylethylidene)bis 2,6-dichloro-
# phenol, 4-amino-
# phenol, 4-amino-2-nitro-
# phenol, 4-dodecyl-
# phenol, 4-phenoxy-
# phenol,2,2'-methylenebis 4-chloro-
# phenopylate
# phenothrin
# phenyl 2-hydroxybenzoate
# phenyl acetate
# phenyl cyclohexane
# phenyl glydidyl ether
# phenyl hydrazine
# phenyl trimethyl ammonium iodide
# phenyl-4-aminosalicylate
# phenylacetic acid
# phenylarsonic acid
# phenyldiethanolamine
# phenylisothiocyanate
# phenylmercuric acetate
# phenyltin trichloride
# phenyltrichlorosilane
# phorone
# phosphamidon
# phosphonic acid, methyl-, diisopropyl ester
# phosphoric acid, diethyl ester
# phosphoric acid, dimethyl ester
# phosphoric acid, tris(2-methylpropyl) ester
# phosphoric acid,2-chloro-(2,4-dichlorophenyl)vin
# phosphorodithioic acid, o,o-diethyl ester
# phosphorodithioic acid, o,o-dimethyl ester
# phosphorodithioic acid, s-[2-(ethylsulfinyl)ethy
# phosphorodithioic acid, s-[2-(ethylsulfonyl)ethy
# phosphorous acid, triphenyl ester
# phoxim
# phthalazine
# phthalic anhydride
# phthalimide
# phthalthrin
# picloram, potassium salt
# picolinic acid
# picric acid
# picrotoxin
# pimaric acid
# pinane
# piperalin
# piperazine, 1-methyl-
# piperazine, 2-methyl-
# piperophos
# potassium ethylxanthate
# prallethrin
# praziquantel
# pretilchlor
# proclonol
# prometon
# propanamide, 2-methyl-n-[4-nitro-3-(trifluoromet
# propane, 2,2'-thiobis 2-methyl-
# propane, 2,2-dichloro-
# propane, 2-iodo-2-methyl-
# propanedinitrile,  (3-chlorophenyl)hydrazono -
# propanedioic acid, 1,3-dithiolan-2-ylidene-, bis
# propanedioic acid, chloro-, diethyl ester
# propanidid
# propanoic acid, 2-hydroxy-, 3-methylbutyl ester
# propanoic acid, 2-hydroxy-, octyl ester
# propaphos
# propargyl alcohol
# propazine
# propetamphos
# propionitrile
# propoxur
# propyl acetate
# propyl gallate
# propyl isome
# propylcyclopentane
# propylthiouracil
# prothiophos
# pulegone
# purpurin
# pyraclofos
# pyrazoxyfen
# pyrethrin i
# pyrethrin ii
# pyridaben
# pyridaphenthion
# pyridine
# pyridine-2,6-dicarboxylic acid
# pyridinium, 1-hexadecyl-, chloride
# pyrimethamine
# pyrimithate
# pyroquilon
# pyrrole
# pyrrolidone
# quinacrine
# quinalizarin
# quinalphos
# quinoline
# quinonamid
# resmethrin
# resorcinol
# retinoic acid
# rhodamine b
# robenidine
# ronnel
# rosaniline
# ryanodine
# s,s'-(2-(dimethylamino)-1,3-propanediyl) carbam*
# s-butylacetate
# saccharin
# salicylanilide
# salicylic acid
# salithion
# sec-butyl alcohol
# sec-butylacetate
# secbumeton
# secobarbital sodium
# semicarbazide
# silvex
# simetryn
# sodium 1-octanesulfonate
# sodium alizarinesulfonate
# sodium azide
# sodium cacodylate
# sodium citrate
# sodium cyclamate
# sodium dichlorocyanurate
# sodium dodecyltrioxyethylene sulfate
# sodium lauryl ether sulfate
# sodium octyl sulfate
# sodium oxalate
# sodium propionate
# sodium saccharin
# sodium salicylate
# sodium trichloroacetate
# spectinomycin
# spiro[isobenzofuran-1(3h),9'-[9h]xanthen]-3-one,
# stannane, tetrachloro-
# stannane, trichloromethyl-
# stannane,(benzoyloxy)tributyl
# stilbene
# strychnine
# styrene oxide
# sulcofuron-sodium
# sulfadiazine
# sulfallate
# sulfamic acid
# sulfamic acid, monoammonium salt
# sulfometuron (ph 5-7)
# sulfoxide
# sulfuric acid, monodecyl ester, sodium salt
# sulfuric acid, monododecyl ester, ammonium salt
# sulphenone
# sulprofos
# t-2 toxin
# t-butyl acetate
# t-butylbenzene
# t-butylphenyl diphenyl phosphate
# tamoxifen
# tannins
# tartaric acid, diethyl ester
# tartrazine
# tebuthiuron
# terbumeton
# terephthalic acid
# tert-butyl alcohol
# testosterone
# tetrabutyltin
# tetrachloro-1,2-benzenediol
# tetrachloroethanes
# tetrachloroguaiacol
# tetrachlorophenols
# tetrachlorophthalide
# tetracycline
# tetradifon
# tetraethyl ammonium chloride
# tetraethyl lead
# tetraethyl pyrophosphate
# tetraethyl tin
# tetrafluoroterephthalonitrile
# tetrahydrofuran
# tetrahydrofurfuryl alcohol
# tetrahydrofurfuryl methacrylate
# tetrahydrothiophene-1,1-dioxide
# tetralin
# tetramethyl lead
# tetramethyl stannane
# tetramethylenedisulfotetramine
# tetramethylthiourea
# tetramethylurea
# tetrapropyl thiopyrophosphorate
# tetrapropyl tin
# tetrapropylenebenzenesulfonic acid
# tetrasul
# thanite
# thiazafluron
# thimerosal
# thioacetamide
# thioanisole
# thiocarbanilide
# thiocyanic acid
# thiocyanic acid (-1 ion)
# thiofanox
# thiometon
# thionazin
# thiopental sodium
# thiophanate
# thiophene
# thiosemicarbazide
# thiourea
# thiourea, n,n-dimethyl-
# thymol
# tinopal 5bm
# tolclofos-methyl
# toxaphene (example isomer shown below)
# tranid
# trans-(+)-allethrin
# trans-bicylco[4,3,0]nonane
# trans-chlordane
# trans-nonachlor
# trans-permethrin
# tri n-butylamine
# tri-2-butoxyethyl phosphate
# tri-2-chloroethyl phosphate
# tri-m-cresyl phosphate
# tri-n-butyltin fluoride
# tri-o-cresyl phosphate
# triadimefon
# triazophos
# tribromomethane
# tributyl tin acetate
# tributyl tin hydroxide
# tributyl[(2-methyl-1-oxo-2-propenyl)oxy]stannane
# tributylchlorostannane
# tributylphosphate
# tributylstannane
# tricaine
# trichloroacetaldehyde
# trichloroacetic acid
# trichlorobenzenes
# trichloroethane
# trichloroethyl phosphate
# trichloronate
# trichlorophenol
# triclocarban
# triclopyr ester
# tricresyl phosphate
# tricyclazole
# tricyclene
# tricyclo[3,3,1,1]decane
# tridecylbenzenesulfonic acid, sodium salt
# trietazine
# triethanolamine
# triethyl phosphate
# triethylamine
# triethylchlorolead
# triethylenetetraamine
# triethyltin bromide
# trifenmorph
# trifluoroethyl acetate
# trimedlure
# trimethoprim
# trimethyl lead chloride
# trimethyl naphthalene
# trimethyl phosphate
# trimethyl thiourea
# trimethylamine, hydrochloride
# trimethylbenzenes
# trimethyltin chloride
# triphenylphosphate
# triphenylphosphine oxide
# triphenyltin chloride
# triphenyltin fluoride
# tripropylamine
# tripropynyl-amine
# tris (2,3-dibromopropyl) phosphate
# tris(1,3-dichloroisopropyl) phosphate
# tris(2-ethylhexyl) phosphate
# trisodium nitrilotriacetate
# undecanoic acid
# undecanone
# uniconazole
# urbacid
# urea,1-methyl-1-phenyl-2-thio
# validamycin
# valproic acid
# vanillin
# vernolate
# vinyl acetate
# warfarin
# yellow ob

# %%
comp = gw.compare_to_previous()

# %%
[(key, len(comp[key])) for key in comp]
# Out:
# [('found', 434), ('missing', 1814), ('reference', 455)]

# %%
comp['reference']
# Out:
# {'1-pentene',
#  '2-methyl pentane',
#  '2-methyl-1-propanol',
#  '2-methyl-2-butene',
#  '2-propanol',
#  '3-methyl-1-butanol',
#  '4-methyl-2-pentanone',
#  'acetaldehyde',
#  'acetic acid',
#  'acetone',
#  'aldehydes, unspecified',
#  'benzaldehyde',
#  'benzene',
#  'benzene, ethyl-',
#  'butadiene',
#  'butane',
#  'butanol',
#  'butyl acetate',
#  'carbon monoxide, fossil',
#  'carbon monoxide, from soil or biomass stock',
#  'carbon monoxide, non-fossil',
#  'chloroform',
#  'cumene',
#  'cyclohexane',
#  'cyclohexane (for all cycloalkanes)',
#  'diethyl ether',
#  'dimethyl carbonate',
#  'dimethyl ether',
#  'ethane',
#  'ethane, 1,1,1-trichloro-, hcfc-140',
#  'ethanol',
#  'ethene',
#  'ethene, tetrachloro-',
#  'ethene, trichloro-',
#  'ethyl acetate',
#  'ethylene',
#  'ethylene glycol monoethyl ether',
#  'ethyne',
#  'formaldehyde',
#  'formic acid',
#  'heptane',
#  'hexane',
#  'hydrocarbons, aliphatic, alkanes, cyclic',
#  'hydrocarbons, aromatic',
#  'hydrocarbons, chlorinated',
#  'isobutane',
#  'isoprene',
#  'm-xylene',
#  'methane',
#  'methane, dichloro-, hcc-30',
#  'methane, fossil',
#  'methane, from soil or biomass stock',
#  'methane, monochloro-, r-40',
#  'methane, non-fossil',
#  'methanol',
#  'methyl acetate',
#  'methyl ethyl ketone',
#  'methyl formate',
#  'nitrogen oxides',
#  'nmvoc, non-methane volatile organic compounds, unspecified origin',
#  'o-xylene',
#  'pentane',
#  'propanal',
#  'propane',
#  'propanol',
#  'propene',
#  'propionic acid',
#  'styrene',
#  'sulfur dioxide',
#  'sulfur oxides',
#  't-butyl methyl ether',
#  'toluene',
#  'trichloroethylene'}

# %%
comp['found']
# Out:
# {'1,4-butanediol',
#  '1-pentanol',
#  '2,4-d',
#  '2,4-d amines',
#  '2,4-db',
#  '2-methyl-1-propanol',
#  '2-propanol',
#  '3-methyl-1-butanol',
#  '4-methyl-2-pentanone',
#  'acenaphthene',
#  'acephate',
#  'acetaldehyde',
#  'acetamide',
#  'acetic acid',
#  'acetone',
#  'acetonitrile',
#  'acetyl chloride',
#  'acibenzolar-s-methyl',
#  'acifluorfen',
#  'acrolein',
#  'acrylic acid',
#  'acrylonitrile',
#  'alachlor',
#  'aldehydes, unspecified',
#  'ametryn',
#  'amine oxide',
#  'aniline',
#  'anthracene',
#  'anthranilic acid',
#  'antimony',
#  'arsenic',
#  'atrazine',
#  'azinphos-methyl',
#  'azoxystrobin',
#  'barium',
#  'bensulfuron methyl ester',
#  'bentazone',
#  'benz(a)anthracene',
#  'benzaldehyde',
#  'benzene',
#  'benzene, chloro-',
#  'benzene, dichloro',
#  'benzene, ethyl-',
#  'benzene, hexachloro-',
#  'benzene, pentachloro-',
#  'benzo(a)pyrene',
#  'beryllium',
#  'bisphenol a',
#  'bromopropane',
#  'bromopropylate',
#  'bromoxynil',
#  'butadiene',
#  'butanol',
#  'butyl acetate',
#  'butylcarbamate, iodopropynyl',
#  'butyrolactone',
#  'cadmium',
#  'calcium cyanamide',
#  'carbaryl',
#  'carbon disulfide',
#  'carbosulfan',
#  'carfentrazone-ethyl',
#  'chloramine',
#  'chloroacetic acid',
#  'chloroform',
#  'chlorosulfonic acid',
#  'chlorotoluron',
#  'chlorpyrifos',
#  'chromium',
#  'clay, bentonite, in ground',
#  'clethodim',
#  'clopyralid',
#  'cobalt',
#  'copper, 0.99% in sulfide, cu 0.36% and mo 8.2e-3% in crude ore, in ground',
#  'cumene',
#  'cyclohexane',
#  'cyclopentane',
#  'cyfluthrin',
#  'cyhexatin',
#  'cypermethrin',
#  'cyprodinil',
#  'dazomet',
#  'dibenz(a,h)anthracene',
#  'dicamba',
#  'dichlobenil',
#  'dichlorprop',
#  'diethofencarb',
#  'diethyl ether',
#  'diethylamine',
#  'diethylene glycol',
#  'diflubenzuron',
#  'diisobutyl ketone',
#  'dimethenamid',
#  'dimethyl malonate',
#  'dimethylamine',
#  'dioxins, measured as 2,3,7,8-tetrachlorodibenzo-p-dioxin',
#  'diphenylether-compound',
#  'dipropylamine',
#  'dithianon',
#  'dnoc',
#  'endothall',
#  'epichlorohydrin',
#  'epoxiconazole',
#  'esfenvalerate',
#  'ethane thiol',
#  'ethane, 1,1,1,2-tetrafluoro-, hfc-134a',
#  'ethane, 1,1,1-trichloro-, hcfc-140',
#  'ethane, 1,1,2-trichloro-',
#  'ethane, 1,1,2-trichloro-1,2,2-trifluoro-, cfc-113',
#  'ethane, 1,1-dichloro-1-fluoro-, hcfc-141b',
#  'ethane, 1,2-dichloro-',
#  'ethane, 2,2-dichloro-1,1,1-trifluoro-, hcfc-123',
#  'ethane, 2-chloro-1,1,1,2-tetrafluoro-, hcfc-124',
#  'ethane, hexachloro-',
#  'ethanol',
#  'ethene, chloro-',
#  'ethene, tetrachloro-',
#  'ethephon',
#  'ethoprop',
#  'ethyl acetate',
#  'ethylamine',
#  'ethylene glycol monoethyl ether',
#  'ethylene oxide',
#  'etridiazole',
#  'fenoxaprop ethyl ester',
#  'fenoxaprop-p ethyl ester',
#  'fentin hydroxide',
#  'fluazifop-p-butyl',
#  'flufenacet',
#  'flumetsulam',
#  'flumiclorac-pentyl',
#  'flumioxazin',
#  'fluoranthene',
#  'fluorene',
#  'fomesafen',
#  'fonofos',
#  'formaldehyde',
#  'formamide',
#  'formic acid',
#  'furan',
#  'furfural',
#  'glutaraldehyde',
#  'glyphosate',
#  'heptane',
#  'hexane',
#  'hydrocarbons, aliphatic, alkanes, cyclic',
#  'hydrocarbons, aromatic',
#  'hydrocarbons, chlorinated',
#  'hymexazol',
#  'imazalil',
#  'imazamox',
#  'imazethapyr',
#  'indoxacarb',
#  'iprodion',
#  'isoprene',
#  'isopropylamine',
#  'kresoxim-methyl',
#  'lambda-cyhalothrin',
#  'lauric acid',
#  'lead',
#  'lindane',
#  'm-xylene',
#  'mcpa',
#  'mcpb',
#  'mercury',
#  'metalaxil',
#  'metam-sodium',
#  'methamidophos',
#  'methane, bromo-, halon 1001',
#  'methane, chloro-fluoro-, hcfc-31',
#  'methane, chlorodifluoro-, hcfc-22',
#  'methane, dichloro-, hcc-30',
#  'methane, dichlorodifluoro-, cfc-12',
#  'methane, monochloro-, r-40',
#  'methane, tetrachloro-, r-10',
#  'methane, trichlorofluoro-, cfc-11',
#  'methanol',
#  'methomyl',
#  'methyl acetate',
#  'methyl acrylate',
#  'methyl ethyl ketone',
#  'methyl formate',
#  'methyl lactate',
#  'methyl parathion',
#  'methylamine',
#  'metolachlor',
#  'metribuzin',
#  'mevinfos',
#  'molybdenum',
#  'monochloroethane',
#  'monocrotophos',
#  'monoethanolamine',
#  'naphthalene',
#  'napropamide',
#  'nickel',
#  'nitrobenzene',
#  'o-nitrotoluene',
#  'o-xylene',
#  'oxydemeton-methyl',
#  'pah, polycyclic aromatic hydrocarbons',
#  'paraquat',
#  'pendimethalin',
#  'pentane',
#  'permethrin',
#  'phenanthrene',
#  'phenol',
#  'phenol, 2,4-dichloro',
#  'phenol, pentachloro-',
#  'phthalate, butyl-benzyl-',
#  'phthalate, dibutyl-',
#  'phthalate, dimethyl-',
#  'phthalate, dioctyl-',
#  'prometryn',
#  'propanal',
#  'propanol',
#  'propene',
#  'propham',
#  'propiconazole',
#  'propineb',
#  'propionic acid',
#  'propylamine',
#  'propylene oxide',
#  'pyrene',
#  'pyrithiobac sodium salt',
#  'quintozene',
#  'quizalofop-ethyl',
#  'rabon',
#  'selenium',
#  'sethoxydim',
#  'silver, ag 4.6e-5%, au 1.3e-4%, in ore, in ground',
#  'sodium formate',
#  'starane',
#  'styrene',
#  'sulfentrazone',
#  'sulfotep',
#  'sulfuric acid',
#  't-butyl methyl ether',
#  't-butylamine',
#  'tcmtb',
#  'tebuconazole',
#  'tebupirimphos',
#  'tefluthrin',
#  'tepraloxydim',
#  'terbuthylazin',
#  'thallium',
#  'thifensulfuron-methyl',
#  'thiodicarb',
#  'thiophanat-methyl',
#  'tin',
#  'toluene',
#  'toluene, 2-chloro',
#  'tri-allate',
#  'tribufos',
#  'trichlorfon',
#  'trichloroethylene',
#  'trifluralin',
#  'trimethylamine',
#  'vanadium',
#  'xylene',
#  'zinc'}

# %%
sorted(comp['reference'].difference(comp['found']))
# Out:
# ['abamectin',
#  'amidosulfuron',
#  'ammonium carbonate',
#  'bromate',
#  'bromine',
#  'cadmium',
#  'carboxylic acids, unspecified',
#  'chlorimuron-ethyl',
#  'chlorine',
#  'chromium',
#  'copper',
#  'copper, ion',
#  'cyanide',
#  'cyclohexane (for all cycloalkanes)',
#  'dichlorprop-p',
#  'dimethenamid',
#  'dimethipin',
#  'ethene, trichloro-',
#  'ethylene diamine',
#  'fenbuconazole',
#  'fipronil',
#  'fluorochloridone',
#  'fomesafen',
#  'glutaraldehyde',
#  'gold',
#  'imazaquin',
#  'imazethapyr',
#  'iodine',
#  'lactofen',
#  'manganese',
#  'metaldehyde',
#  'methyl amine',
#  'nickel',
#  'norflurazon',
#  'o-dichlorobenzene',
#  'polychlorinated biphenyls',
#  'pyrethrin',
#  'pyrethrine',
#  'quizalofop ethyl ester',
#  'silver',
#  'terbacil',
#  'tin',
#  'tin, ion',
#  'tributyltin compounds',
#  'vanadium',
#  'zinc']

# %%
comp['found']
# Out:
# {'1-pentanol',
#  '2,4-d',
#  '2,4-d amines',
#  '2,4-db',
#  '2-amino-3-chloro-1,4-naphthoquinone',
#  '2-chlorobenzaldehyde',
#  '2-methyl-1-propanol',
#  '2-phenylphenol',
#  '2-propanol',
#  '4-methyl-2-pentanol',
#  '4-methyl-2-pentanone',
#  '8-quinolinol',
#  'acenaphthene',
#  'acephate',
#  'acetaldehyde',
#  'acetamide',
#  'acetic acid',
#  'acetone',
#  'acetonitrile',
#  'acetyl chloride',
#  'aclonifen',
#  'acrolein',
#  'acrylic acid',
#  'acrylonitrile',
#  'alachlor',
#  'aldehydes, unspecified',
#  'aldicarb',
#  'aldrin',
#  'allethrin',
#  'allyl chloride',
#  'alpha-cypermethrin',
#  'ametryn',
#  'amitraz',
#  'anilazine',
#  'aniline',
#  'anthracene',
#  'anthraquinone',
#  'antimony',
#  'arsenic',
#  'asulam',
#  'atrazine',
#  'azaconazol',
#  'azadirachtin',
#  'azinphos-methyl',
#  'aziprotryne',
#  'azoxystrobin',
#  'barium',
#  'benazolin',
#  'benfluralin',
#  'benomyl',
#  'bensultap',
#  'bentazone',
#  'benz(a)anthracene',
#  'benzaldehyde',
#  'benzene',
#  'benzene, chloro-',
#  'benzene, dichloro',
#  'benzene, ethyl-',
#  'benzene, hexachloro-',
#  'benzene, pentachloro-',
#  'benzo(a)pyrene',
#  'benzoic acid',
#  'benzoximate',
#  'benzthiazuron',
#  'benzyl alcohol',
#  'beryllium',
#  'bifenox',
#  'bifenthrin',
#  'bisphenol a',
#  'bitertanol',
#  'bromacil',
#  'bromofenoxim',
#  'bromopropane',
#  'bromopropylate',
#  'bromoxynil',
#  'bromoxynil octanoate',
#  'bromuconazole',
#  'bupirimate',
#  'buprofezin',
#  'butanol',
#  'butoxycarboxim',
#  'butyl acetate',
#  'butylcarbamate, iodopropynyl',
#  'cadmium',
#  'captan',
#  'carbaryl',
#  'carbendazim',
#  'carbetamide',
#  'carbofuran',
#  'carbon disulfide',
#  'carbosulfan',
#  'carboxin',
#  'carfentrazone-ethyl',
#  'chloramine',
#  'chlorbromuron',
#  'chlorbufam',
#  'chlorfenvinphos',
#  'chloridazon',
#  'chlormequat chloride',
#  'chloroacetic acid',
#  'chloroform',
#  'chloropicrin',
#  'chlorosulfonic acid',
#  'chlorothalonil',
#  'chlorotoluron',
#  'chlorpyrifos',
#  'chlorpyrifos methyl',
#  'chlorsulfuron',
#  'chromium',
#  'clay, bentonite, in ground',
#  'clodinafop-propargyl',
#  'clomazone',
#  'clopyralid',
#  'cloquintocet-mexyl',
#  'cobalt',
#  'copper',
#  'cumene',
#  'cyanazine',
#  'cyclohexane',
#  'cyclopentane',
#  'cycloxydim',
#  'cyfluthrin',
#  'cyhalothrin',
#  'cyhexatin',
#  'cymoxanil',
#  'cypermethrin',
#  'cyproconazole',
#  'cyromazine',
#  'daminozide',
#  'dazomet',
#  'decanoic acid',
#  'deltamethrin',
#  'desmedipham',
#  'dialifor',
#  'diazinon',
#  'dibenz(a,h)anthracene',
#  'dicamba',
#  'dichlobenil',
#  'dichlofluanid',
#  'dichlorprop',
#  'dichlorvos',
#  'diclofop-methyl',
#  'dicofol',
#  'dicrotophos',
#  'dienochlor',
#  'diethanolamine',
#  'diethofencarb',
#  'diethyl ether',
#  'diethylamine',
#  'diethylene glycol',
#  'difenoconazole',
#  'diflubenzuron',
#  'diflufenican',
#  'diisobutyl ketone',
#  'dimethachlor',
#  'dimethoate',
#  'dimethomorph',
#  'dimethylamine',
#  'dinocap',
#  'dinoseb',
#  'dioxins, measured as 2,3,7,8-tetrachlorodibenzo-p-dioxin',
#  'diphenylether-compound',
#  'diquat',
#  'diquat dibromide',
#  'disulfoton',
#  'dithianon',
#  'diuron',
#  'dnoc',
#  'dodecanol',
#  'dodemorph',
#  'dodine',
#  'dsma',
#  'endosulfan',
#  'endothall',
#  'epichlorohydrin',
#  'epoxiconazole',
#  'eptc',
#  'esfenvalerate',
#  'ethane thiol',
#  'ethane, 1,1,1-trichloro-, hcfc-140',
#  'ethane, 1,1,2-trichloro-',
#  'ethane, 1,2-dichloro-',
#  'ethane, hexachloro-',
#  'ethanol',
#  'ethene, tetrachloro-',
#  'ethephon',
#  'ethiofencarb',
#  'ethofumesate',
#  'ethoprop',
#  'ethyl acetate',
#  'ethylamine',
#  'ethylene oxide',
#  'etridiazole',
#  'fenamiphos',
#  'fenbutatin oxide',
#  'fenfuram',
#  'fenitrothion',
#  'fenoxaprop-p ethyl ester',
#  'fenoxycarb',
#  'fenpiclonil',
#  'fenpropathrin',
#  'fenpropimorph',
#  'fentin acetate',
#  'fentin hydroxide',
#  'fluazifop-p-butyl',
#  'fluazinam',
#  'fludioxonil',
#  'flufenacet',
#  'fluometuron',
#  'fluoranthene',
#  'fluorene',
#  'flurochloridone',
#  'fluroxypyr',
#  'flutolanil',
#  'folpet',
#  'fonofos',
#  'formaldehyde',
#  'formic acid',
#  'fosetyl-aluminium',
#  'fuberidazole',
#  'furalaxyl',
#  'furan',
#  'furfural',
#  'glufosinate ammonium',
#  'glyphosate',
#  'heptane',
#  'heptenophos',
#  'hexane',
#  'hexazinone',
#  'hexythiazox',
#  'hydramethylnon',
#  'hydrazine',
#  'hydrocarbons, aliphatic, alkanes, cyclic',
#  'hydrocarbons, aromatic',
#  'hydrocarbons, chlorinated',
#  'hymexazol',
#  'imazalil',
#  'imazapyr',
#  'imidacloprid',
#  'indoxacarb',
#  'ioxynil',
#  'iprodion',
#  'isoprene',
#  'isopropylamine',
#  'isoproturon',
#  'isoxaflutole',
#  'kresoxim-methyl',
#  'lambda-cyhalothrin',
#  'lauric acid',
#  'lead',
#  'lenacil',
#  'lindane',
#  'linuron',
#  'm-xylene',
#  'malathion',
#  'maleic anhydride',
#  'maleic hydrazide',
#  'mancozeb',
#  'maneb',
#  'mcpa',
#  'mcpb',
#  'mecoprop',
#  'mecoprop-p',
#  'mepiquat chloride',
#  'mercury',
#  'metalaxil',
#  'metalaxyl-m',
#  'metam-sodium',
#  'metamitron',
#  'metazachlor',
#  'methabenzthiazuron',
#  'methamidophos',
#  'methane, bromo-, halon 1001',
#  'methane, dichloro-, hcc-30',
#  'methane, monochloro-, r-40',
#  'methane, tetrachloro-, r-10',
#  'methanol',
#  'methidathion',
#  'methiocarb',
#  'methomyl',
#  'methoprene',
#  'methoxyfenozide',
#  'methyl acetate',
#  'methyl acrylate',
#  'methyl ethyl ketone',
#  'methyl lactate',
#  'methyl parathion',
#  'methylamine',
#  'metiram',
#  'metobromuron',
#  'metolachlor',
#  'metribuzin',
#  'metsulfuron-methyl',
#  'mevinfos',
#  'molinate',
#  'molybdenum',
#  'monocrotophos',
#  'monoethanolamine',
#  'monolinuron',
#  'msma',
#  'myclobutanil',
#  'naled',
#  'naphthalene',
#  'napropamide',
#  'neburon',
#  'nickel',
#  'nicosulfuron',
#  'nitrobenzene',
#  'nitrothal-isopropyl',
#  'o-nitrotoluene',
#  'o-xylene',
#  'octanoic acid',
#  'orbencarb',
#  'oryzalin',
#  'oxadixyl',
#  'oxamyl',
#  'oxydemeton-methyl',
#  'oxyfluorfen',
#  'p-tert-amylphenol',
#  'pah, polycyclic aromatic hydrocarbons',
#  'paraquat',
#  'parathion',
#  'penconazole',
#  'pencycuron',
#  'pendimethalin',
#  'pentane',
#  'permethrin',
#  'phenanthrene',
#  'phenmedipham',
#  'phenol',
#  'phenol, 2,4-dichloro',
#  'phenol, pentachloro-',
#  'phorate',
#  'phosalone',
#  'phosmet',
#  'phthalate, butyl-benzyl-',
#  'phthalate, dibutyl-',
#  'phthalate, dimethyl-',
#  'phthalate, dioctyl-',
#  'picloram',
#  'piperonyl butoxide',
#  'pirimicarb',
#  'pirimiphos methyl',
#  'prochloraz',
#  'procymidone',
#  'profenofos',
#  'prometryn',
#  'pronamide',
#  'propachlor',
#  'propamocarb',
#  'propamocarb hcl',
#  'propanal',
#  'propanil',
#  'propanol',
#  'propaquizafop',
#  'propargite',
#  'propham',
#  'propiconazole',
#  'propionic acid',
#  'propylamine',
#  'propylene oxide',
#  'prosulfocarb',
#  'pyrazophos',
#  'pyrene',
#  'pyrethrum',
#  'pyridate',
#  'pyrifenox',
#  'pyrimethanil',
#  'pyriproxyfen',
#  'quinmerac',
#  'quintozene',
#  'quizalofop-ethyl',
#  'rabon',
#  'rimsulfuron',
#  'rotenone',
#  's-metolachlor',
#  'selenium',
#  'sethoxydim',
#  'silver, 0.007% in sulfide, ag 0.004%, pb, zn, cd, in, in ground',
#  'simazine',
#  'sodium formate',
#  'starane',
#  'styrene',
#  'sulfotep',
#  'sulfuric acid',
#  't-butyl methyl ether',
#  't-butylamine',
#  'tau-fluvalinate',
#  'tcmtb',
#  'tebuconazole',
#  'tebufenozide',
#  'teflubenzuron',
#  'tepraloxydim',
#  'terbufos',
#  'terbuthylazin',
#  'terbutryn',
#  'thallium',
#  'thiabendazole',
#  'thidiazuron',
#  'thiobencarb',
#  'thiodicarb',
#  'thiophanat-methyl',
#  'thiram',
#  'tin',
#  'toluene',
#  'toluene, 2-chloro',
#  'tolylfluanid',
#  'tralomethrin',
#  'tri-allate',
#  'triadimenol',
#  'triasulfuron',
#  'tribenuron-methyl',
#  'tribufos',
#  'trichlorfon',
#  'trichloroethylene',
#  'triclopyr',
#  'tridemorph',
#  'triethylene glycol',
#  'triflumizole',
#  'triflumuron',
#  'trifluralin',
#  'triflusulfuron-methyl',
#  'triforine',
#  'trinexapac-ethyl',
#  'urea',
#  'vamidothion',
#  'vanadium',
#  'vinclozolin',
#  'xylene',
#  'zinc, zn 3.1%, in mixed ore, in ground',
#  'zineb',
#  'ziram'}

# %%
c['missing']

# %%
gw.drop_unlinked()
# Out:
# Applying strategy: drop_unlinked_cfs
# Applied 1 strategies in 0.03 seconds

# %%
gw.write_methods(overwrite=True)
# Out:
# Wrote 3 LCIA methods with 7636 characterization factors

# %%
gw.data[2]['name']
# Out:
# ('ReCiPe 2016', 'v1.1 (20180117)', 'ETPfw', 'E')

# %% [markdown]
# # Compare to previous ReCiPe method

# %%
# %matplotlib inline

# %%
import bw2data, bw2calc
import pyprind
import seaborn as sb
import numpy as np

# %%
keys = sorted([x.key for x in bw2data.Database("ecoinvent 3.6 cutoff")])

# %%
results_reference, results_2016 = [], []

# %%
lca = bw2calc.LCA({keys[0]: 1}, gw.previous_reference)
lca.lci()
lca.lcia()

# %%
reference_cm = lca.characterization_matrix.copy()

# %%
lca.switch_method(('ReCiPe 2016', 'v1.1 (20180117)', 'ETPfw', 'E'))

# %%
lca.characterization_matrix.sum(), reference_cm.sum()
# Out:
# (413104.1747880711, 50099.07224550034)

# %%
new_cm = lca.characterization_matrix.copy()

# %%
for key in pyprind.prog_bar(keys):
    lca.redo_lci({key: 1})
    results_reference.append((reference_cm * lca.inventory).sum())
    results_2016.append((new_cm * lca.inventory).sum())
# Out:
# 0% [##############################] 100% | ETA: 00:00:00
# Total time elapsed: 00:06:54

# %%
sb.scatterplot(np.log10(np.array(results_reference)), np.log10(np.array(results_2016)))
# Out:
# /Users/cmutel/miniconda3/envs/bw2dev/lib/python3.7/site-packages/ipykernel_launcher.py:1: RuntimeWarning: divide by zero encountered in log10
#   """Entry point for launching an IPython kernel.

# %%
def abnormal_ratio(a, b):
    if not a or not b:
        return
    ratio = abs(a / b)
    if 0.8 < ratio < 1.25:
        return
    return ratio

# %%
exceptions = sorted([
    (abnormal_ratio(results_2016[i], results_reference[i]), bw2data.get_activity(key)) 
    for i, key in enumerate(keys) 
    if abnormal_ratio(results_2016[i], results_reference[i])
], reverse=True)

# %%
len(exceptions)

# %%
exceptions[:10]

# %%
lca.redo_lci({exceptions[0][1]: 1})
lca.characterized_inventory = new_cm * lca.inventory
